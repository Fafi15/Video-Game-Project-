# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("dfinal.csv", delimiter=",")
df.head()
# Out:
#    Unnamed: 0               Name  Index Platform    Year     Genre Publisher  \
# 0           0         Wii Sports      1      Wii  2006.0    Sports  Nintendo
# 1           2  Super Mario Bros.      2      NES  1985.0  Platform  Nintendo
# 2           4  Super Mario Bros.      2       GB  1999.0  Platform  Nintendo
# 3           6     Mario Kart Wii      3      Wii  2008.0    Racing  Nintendo
# 4           8  Wii Sports Resort      4      Wii  2009.0    Sports  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.49     29.02      3.77         8.46         82.74          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2      3.40      1.30      0.15         0.22          5.07           NaN
# 3     15.85     12.88      3.79         3.31         35.82          82.0
# 4     15.75     11.01      3.28         2.96         33.00          80.0
#
#    Critic_Count Developer User_Score  User_Count Rating
# 0          51.0  Nintendo          8       322.0      E
# 1           NaN  Nintendo        8.3       138.0      E
# 2           NaN  Nintendo        8.3       138.0      E
# 3          73.0  Nintendo        8.3       709.0      E
# 4          73.0  Nintendo          8       192.0      E

# %%
print(df.info())
print("---------------------------")
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16730 entries, 0 to 16729
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    16730 non-null  int64
#  1   Name          16730 non-null  object
#  2   Index         16730 non-null  int64
#  3   Platform      16682 non-null  object
#  4   Year          16541 non-null  float64
#  5   Genre         16730 non-null  object
#  6   Publisher     16676 non-null  object
#  7   NA_Sales      16730 non-null  float64
#  8   EU_Sales      16730 non-null  float64
#  9   JP_Sales      16730 non-null  float64
#  10  Other_Sales   16730 non-null  float64
#  11  Global_Sales  16730 non-null  float64
#  12  Critic_Score  8448 non-null   float64
#  13  Critic_Count  8448 non-null   float64
#  14  Developer     10825 non-null  object
#  15  User_Score    10698 non-null  object
#  16  User_Count    8729 non-null   float64
#  17  Rating        10688 non-null  object
# dtypes: float64(9), int64(2), object(7)
# memory usage: 2.3+ MB
# None
# ---------------------------
#          Unnamed: 0         Index          Year      NA_Sales     EU_Sales  \
# count  16730.000000  16730.000000  16541.000000  16730.000000  16730.00000
# mean   27401.312851   7249.658936   2006.418294      0.263353      0.14626
# std    12359.299276   4932.533046      5.867619      0.813765      0.50398
# min        0.000000      1.000000   1977.000000      0.000000      0.00000
# 25%    17894.750000   2836.250000   2003.000000      0.000000      0.00000
# 50%    29960.500000   6732.500000   2007.000000      0.080000      0.02000
# 75%    38246.750000  11413.750000   2010.000000      0.240000      0.11000
# max    43669.000000  19423.000000   2020.000000     41.490000     29.02000
#
#            JP_Sales   Other_Sales  Global_Sales  Critic_Score  Critic_Count  \
# count  16730.000000  16730.000000  16730.000000   8448.000000   8448.000000
# mean       0.077244      0.047912      0.535046     69.735204     30.072680
# std        0.308142      0.188006      1.549904     14.212665     20.444954
# min        0.000000      0.000000      0.010000     19.000000      4.000000
# 25%        0.000000      0.000000      0.060000     61.000000     14.000000
# 50%        0.000000      0.010000      0.170000     72.000000     26.000000
# 75%        0.040000      0.030000      0.470000     80.000000     42.000000
# max       10.220000     10.570000     82.740000     98.000000    113.000000
#
#          User_Count
# count   8729.000000
# mean     187.025776
# std      630.791085
# min        4.000000
# 25%       12.000000
# 50%       31.000000
# 75%      104.000000
# max    10179.000000

# %% [markdown]
# # Nettoyage/Cleaning

# %%
df.drop(columns=["Unnamed: 0"], inplace=True)
df.head()
# Out:
#                 Name  Index Platform    Year     Genre Publisher  NA_Sales  \
# 0         Wii Sports      1      Wii  2006.0    Sports  Nintendo     41.49
# 1  Super Mario Bros.      2      NES  1985.0  Platform  Nintendo     29.08
# 2  Super Mario Bros.      2       GB  1999.0  Platform  Nintendo      3.40
# 3     Mario Kart Wii      3      Wii  2008.0    Racing  Nintendo     15.85
# 4  Wii Sports Resort      4      Wii  2009.0    Sports  Nintendo     15.75
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  Critic_Count  \
# 0     29.02      3.77         8.46         82.74          76.0          51.0
# 1      3.58      6.81         0.77         40.24           NaN           NaN
# 2      1.30      0.15         0.22          5.07           NaN           NaN
# 3     12.88      3.79         3.31         35.82          82.0          73.0
# 4     11.01      3.28         2.96         33.00          80.0          73.0
#
#   Developer User_Score  User_Count Rating
# 0  Nintendo          8       322.0      E
# 1  Nintendo        8.3       138.0      E
# 2  Nintendo        8.3       138.0      E
# 3  Nintendo        8.3       709.0      E
# 4  Nintendo          8       192.0      E

# %%
# Affichage des valeurs manquantes
print(df.isna().sum())
print("--------------------------")
# Affichage des doublons
print(df.duplicated().sum())
# Out:
# Name               0
# Index              0
# Platform          48
# Year             189
# Genre              0
# Publisher         54
# NA_Sales           0
# EU_Sales           0
# JP_Sales           0
# Other_Sales        0
# Global_Sales       0
# Critic_Score    8282
# Critic_Count    8282
# Developer       5905
# User_Score      6032
# User_Count      8001
# Rating          6042
# dtype: int64
# --------------------------
# 0

# %% [markdown]
# ## Affichage valeurs manquantes dans "Year"

# %%
# Identifier les valeurs manquantes dans la colonne Year

year_manquantes = df[df["Year"].isna()]
colonne_year = "Year"

# Boucle pour afficher les lignes contenant des valeurs manquantes

for index, row in year_manquantes.iterrows():
    print(f"Index: {index}, Ligne complète: \n{row}\n")
# Out:
# Index: 2374, Ligne complète:
# Name                      LEGO Harry Potter: Years 5-7
# Index                                             1434
# Platform                                           PSP
# Year                                               NaN
# Genre                                           Action
# Publisher       Warner Bros. Interactive Entertainment
# NA_Sales                                           0.1
# EU_Sales                                          0.11
# JP_Sales                                           0.0
# Other_Sales                                       0.06
# Global_Sales                                      0.27
# Critic_Score                                      76.0
# Critic_Count                                       8.0
# Developer                            Traveller's Tales
# User_Score                                         7.8
# User_Count                                        13.0
# Rating                                            E10+
# Name: 2374, dtype: object
#
# Index: 2377, Ligne complète:
# Name                      LEGO Harry Potter: Years 5-7
# Index                                             1434
# Platform                                            PC
# Year                                               NaN
# Genre                                           Action
# Publisher       Warner Bros. Interactive Entertainment
# NA_Sales                                          0.05
# EU_Sales                                          0.14
# JP_Sales                                           0.0
# Other_Sales                                       0.03
# Global_Sales                                      0.22
# Critic_Score                                      76.0
# Critic_Count                                       8.0
# Developer                            Traveller's Tales
# User_Score                                         7.8
# User_Count                                        13.0
# Rating                                            E10+
# Name: 2377, dtype: object
#
# Index: 4349, Ligne complète:
# Name            Test Drive Unlimited 2
# Index                             2948
# Platform                            PC
# Year                               NaN
# Genre                           Racing
# Publisher                        Atari
# NA_Sales                          0.05
# EU_Sales                          0.11
# JP_Sales                           0.0
# Other_Sales                       0.03
# Global_Sales                       0.2
# Critic_Score                      68.0
# Critic_Count                      61.0
# Developer                         Eden
# User_Score                         6.4
# User_Count                        87.0
# Rating                               T
# Name: 4349, dtype: object
#
# Index: 4462, Ligne complète:
# Name            The Chronicles of Narnia: The Lion, The Witch ...
# Index                                                        3050
# Platform                                                       GC
# Year                                                          NaN
# Genre                                                      Action
# Publisher                              Disney Interactive Studios
# NA_Sales                                                     0.22
# EU_Sales                                                     0.06
# JP_Sales                                                      0.0
# Other_Sales                                                  0.01
# Global_Sales                                                 0.28
# Critic_Score                                                 66.0
# Critic_Count                                                  7.0
# Developer                                     Amaze Entertainment
# User_Score                                                    6.8
# User_Count                                                    5.0
# Rating                                                          E
# Name: 4462, dtype: object
#
# Index: 6793, Ligne complète:
# Name              NBA Live 2003
# Index                      5163
# Platform                     GC
# Year                        NaN
# Genre                    Sports
# Publisher       Electronic Arts
# NA_Sales                   0.23
# EU_Sales                   0.06
# JP_Sales                    0.0
# Other_Sales                0.01
# Global_Sales                0.3
# Critic_Score               83.0
# Critic_Count               22.0
# Developer             EA Canada
# User_Score                  8.3
# User_Count                 28.0
# Rating                        E
# Name: 6793, dtype: object
#
# Index: 6801, Ligne complète:
# Name            Bejeweled 3
# Index                  5172
# Platform                PS3
# Year                    NaN
# Genre                Puzzle
# Publisher           Unknown
# NA_Sales               0.13
# EU_Sales                0.0
# JP_Sales                0.0
# Other_Sales            0.01
# Global_Sales           0.14
# Critic_Score           75.0
# Critic_Count            9.0
# Developer            PopCap
# User_Score              tbd
# User_Count            119.0
# Rating                    E
# Name: 6801, dtype: object
#
# Index: 6803, Ligne complète:
# Name            Bejeweled 3
# Index                  5172
# Platform               X360
# Year                    NaN
# Genre                Puzzle
# Publisher           Unknown
# NA_Sales               0.13
# EU_Sales                0.0
# JP_Sales                0.0
# Other_Sales            0.01
# Global_Sales           0.14
# Critic_Score           75.0
# Critic_Count            9.0
# Developer            PopCap
# User_Score              tbd
# User_Count            119.0
# Rating                    E
# Name: 6803, dtype: object
#
# Index: 7293, Ligne complète:
# Name               Singularity
# Index                     5626
# Platform                   PS3
# Year                       NaN
# Genre                  Shooter
# Publisher              Unknown
# NA_Sales                  0.17
# EU_Sales                  0.04
# JP_Sales                  0.01
# Other_Sales               0.03
# Global_Sales              0.24
# Critic_Score              76.0
# Critic_Count              70.0
# Developer       Raven Software
# User_Score                 7.7
# User_Count               169.0
# Rating                       M
# Name: 7293, dtype: object
#
# Index: 7339, Ligne complète:
# Name            All-Star Baseball 2005
# Index                             5670
# Platform                           PS2
# Year                               NaN
# Genre                           Sports
# Publisher                      Unknown
# NA_Sales                          0.16
# EU_Sales                          0.12
# JP_Sales                           0.0
# Other_Sales                       0.04
# Global_Sales                      0.32
# Critic_Score                      72.0
# Critic_Count                      13.0
# Developer                      Acclaim
# User_Score                         8.6
# User_Count                        21.0
# Rating                               E
# Name: 7339, dtype: object
#
# Index: 7340, Ligne complète:
# Name            All-Star Baseball 2005
# Index                             5670
# Platform                            XB
# Year                               NaN
# Genre                           Sports
# Publisher                      Unknown
# NA_Sales                          0.11
# EU_Sales                          0.03
# JP_Sales                           0.0
# Other_Sales                       0.01
# Global_Sales                      0.15
# Critic_Score                      72.0
# Critic_Count                      13.0
# Developer                      Acclaim
# User_Score                         8.6
# User_Count                        21.0
# Rating                               E
# Name: 7340, dtype: object
#
# Index: 7430, Ligne complète:
# Name            Star Wars Jedi Knight II: Jedi Outcast
# Index                                             5770
# Platform                                            XB
# Year                                               NaN
# Genre                                          Shooter
# Publisher                                   Activision
# NA_Sales                                          0.23
# EU_Sales                                          0.07
# JP_Sales                                           0.0
# Other_Sales                                       0.01
# Global_Sales                                      0.31
# Critic_Score                                      81.0
# Critic_Count                                      24.0
# Developer                            Vicarious Visions
# User_Score                                         6.8
# User_Count                                        15.0
# Rating                                               T
# Name: 7430, dtype: object
#
# Index: 7453, Ligne complète:
# Name            Slot Machine
# Index                   5799
# Platform                2600
# Year                     NaN
# Genre                 Action
# Publisher              Atari
# NA_Sales                0.29
# EU_Sales                0.02
# JP_Sales                 0.0
# Other_Sales              0.0
# Global_Sales            0.31
# Critic_Score             NaN
# Critic_Count             NaN
# Developer                NaN
# User_Score               NaN
# User_Count               NaN
# Rating                   NaN
# Name: 7453, dtype: object
#
# Index: 7492, Ligne complète:
# Name            Shrek the Third
# Index                      5839
# Platform                     DS
# Year                        NaN
# Genre                    Action
# Publisher            Activision
# NA_Sales                   0.26
# EU_Sales                   0.02
# JP_Sales                    0.0
# Other_Sales                0.02
# Global_Sales                0.3
# Critic_Score                NaN
# Critic_Count                NaN
# Developer                   NaN
# User_Score                  NaN
# User_Count                  NaN
# Rating                      NaN
# Name: 7492, dtype: object
#
# Index: 7518, Ligne complète:
# Name            The Dukes of Hazzard II: Daisy Dukes It Out
# Index                                                  5862
# Platform                                                 PS
# Year                                                    NaN
# Genre                                                Racing
# Publisher                                           Unknown
# NA_Sales                                               0.17
# EU_Sales                                               0.11
# JP_Sales                                                0.0
# Other_Sales                                            0.02
# Global_Sales                                            0.3
# Critic_Score                                           53.0
# Critic_Count                                            5.0
# Developer                                    Sinister Games
# User_Score                                              tbd
# User_Count                                              NaN
# Rating                                                    E
# Name: 7518, dtype: object
#
# Index: 7526, Ligne complète:
# Name            Disgaea 3: Absence of Detention
# Index                                      5871
# Platform                                    PSV
# Year                                        NaN
# Genre                              Role-Playing
# Publisher                  Nippon Ichi Software
# NA_Sales                                   0.13
# EU_Sales                                   0.06
# JP_Sales                                   0.07
# Other_Sales                                0.04
# Global_Sales                                0.3
# Critic_Score                               78.0
# Critic_Count                               28.0
# Developer                  Nippon Ichi Software
# User_Score                                  7.6
# User_Count                                116.0
# Rating                                        T
# Name: 7526, dtype: object
#
# Index: 7566, Ligne complète:
# Name            Harvest Moon: The Tale of Two Towns
# Index                                          5914
# Platform                                        3DS
# Year                                            NaN
# Genre                                    Simulation
# Publisher                                   Unknown
# NA_Sales                                       0.28
# EU_Sales                                        0.0
# JP_Sales                                        0.0
# Other_Sales                                    0.02
# Global_Sales                                    0.3
# Critic_Score                                   68.0
# Critic_Count                                    6.0
# Developer                   Marvelous Entertainment
# User_Score                                      7.5
# User_Count                                     13.0
# Rating                                            E
# Name: 7566, dtype: object
#
# Index: 7698, Ligne complète:
# Name            Nicktoons: Battle for Volcano Island
# Index                                           6043
# Platform                                          GC
# Year                                             NaN
# Genre                                         Action
# Publisher                                    Unknown
# NA_Sales                                        0.22
# EU_Sales                                        0.06
# JP_Sales                                         0.0
# Other_Sales                                     0.01
# Global_Sales                                    0.29
# Critic_Score                                    59.0
# Critic_Count                                     6.0
# Developer                                    Natsume
# User_Score                                       tbd
# User_Count                                      16.0
# Rating                                             E
# Name: 7698, dtype: object
#
# Index: 7780, Ligne complète:
# Name            Haven: Call of the King
# Index                              6126
# Platform                            PS2
# Year                                NaN
# Genre                          Platform
# Publisher                  Midway Games
# NA_Sales                           0.14
# EU_Sales                           0.11
# JP_Sales                            0.0
# Other_Sales                        0.04
# Global_Sales                       0.28
# Critic_Score                       69.0
# Critic_Count                       26.0
# Developer             Traveller's Tales
# User_Score                          6.9
# User_Count                         15.0
# Rating                                T
# Name: 7780, dtype: object
#
# Index: 7805, Ligne complète:
# Name            Unreal Championship 2: The Liandri Conflict
# Index                                                  6154
# Platform                                                 XB
# Year                                                    NaN
# Genre                                               Shooter
# Publisher                                      Midway Games
# NA_Sales                                               0.22
# EU_Sales                                               0.05
# JP_Sales                                                0.0
# Other_Sales                                            0.01
# Global_Sales                                           0.28
# Critic_Score                                           85.0
# Critic_Count                                           54.0
# Developer                                        Epic Games
# User_Score                                              8.2
# User_Count                                             21.0
# Rating                                                    M
# Name: 7805, dtype: object
#
# Index: 7864, Ligne complète:
# Name            Pac-Man Fever
# Index                    6212
# Platform                   GC
# Year                      NaN
# Genre                    Misc
# Publisher             Unknown
# NA_Sales                 0.21
# EU_Sales                 0.06
# JP_Sales                  0.0
# Other_Sales              0.01
# Global_Sales             0.28
# Critic_Score             47.0
# Critic_Count             14.0
# Developer          Mass Media
# User_Score                6.3
# User_Count                7.0
# Rating                      E
# Name: 7864, dtype: object
#
# Index: 7924, Ligne complète:
# Name            The Legend of Zelda: The Minish Cap(weekly JP ...
# Index                                                        6273
# Platform                                                      GBA
# Year                                                          NaN
# Genre                                                      Action
# Publisher                                                     NaN
# NA_Sales                                                      0.0
# EU_Sales                                                      0.0
# JP_Sales                                                     0.27
# Other_Sales                                                  0.01
# Global_Sales                                                 0.27
# Critic_Score                                                  NaN
# Critic_Count                                                  NaN
# Developer                                                     NaN
# User_Score                                                    NaN
# User_Count                                                    NaN
# Rating                                                        NaN
# Name: 7924, dtype: object
#
# Index: 7932, Ligne complète:
# Name            Indy 500
# Index               6284
# Platform            2600
# Year                 NaN
# Genre             Racing
# Publisher          Atari
# NA_Sales            0.26
# EU_Sales            0.01
# JP_Sales             0.0
# Other_Sales          0.0
# Global_Sales        0.27
# Critic_Score         NaN
# Critic_Count         NaN
# Developer            NaN
# User_Score           NaN
# User_Count           NaN
# Rating               NaN
# Name: 7932, dtype: object
#
# Index: 7966, Ligne complète:
# Name                                Gun
# Index                              6315
# Platform                           X360
# Year                                NaN
# Genre                           Shooter
# Publisher                    Activision
# NA_Sales                           0.24
# EU_Sales                           0.01
# JP_Sales                            0.0
# Other_Sales                        0.02
# Global_Sales                       0.27
# Critic_Score                       77.0
# Critic_Count                       43.0
# Developer       Neversoft Entertainment
# User_Score                          8.7
# User_Count                         70.0
# Rating                                M
# Name: 7966, dtype: object
#
# Index: 7967, Ligne complète:
# Name            Flag Capture
# Index                   6317
# Platform                2600
# Year                     NaN
# Genre                 Action
# Publisher              Atari
# NA_Sales                0.25
# EU_Sales                0.02
# JP_Sales                 0.0
# Other_Sales              0.0
# Global_Sales            0.27
# Critic_Score             NaN
# Critic_Count             NaN
# Developer                NaN
# User_Score               NaN
# User_Count               NaN
# Rating                   NaN
# Name: 7967, dtype: object
#
# Index: 8043, Ligne complète:
# Name                            Rock Revolution
# Index                                      6403
# Platform                                    Wii
# Year                                        NaN
# Genre                                      Misc
# Publisher                               Unknown
# NA_Sales                                   0.07
# EU_Sales                                    0.0
# JP_Sales                                    0.0
# Other_Sales                                0.01
# Global_Sales                               0.08
# Critic_Score                               38.0
# Critic_Count                               28.0
# Developer       Zoe Mode, HB Studios Multimedia
# User_Score                                  5.1
# User_Count                                 17.0
# Rating                                        T
# Name: 8043, dtype: object
#
# Index: 8044, Ligne complète:
# Name                            Rock Revolution
# Index                                      6403
# Platform                                    PS3
# Year                                        NaN
# Genre                                      Misc
# Publisher                               Unknown
# NA_Sales                                   0.25
# EU_Sales                                    0.0
# JP_Sales                                    0.0
# Other_Sales                                0.02
# Global_Sales                               0.27
# Critic_Score                               38.0
# Critic_Count                               28.0
# Developer       Zoe Mode, HB Studios Multimedia
# User_Score                                  5.1
# User_Count                                 17.0
# Rating                                        T
# Name: 8044, dtype: object
#
# Index: 8149, Ligne complète:
# Name              Jonah Lomu Rugby Challenge
# Index                                   6497
# Platform                                 PS3
# Year                                     NaN
# Genre                                 Sports
# Publisher       Home Entertainment Suppliers
# NA_Sales                                 0.0
# EU_Sales                                 0.2
# JP_Sales                                 0.0
# Other_Sales                             0.06
# Global_Sales                            0.26
# Critic_Score                            73.0
# Critic_Count                            14.0
# Developer                  Sidhe Interactive
# User_Score                                 6
# User_Count                               8.0
# Rating                                     E
# Name: 8149, dtype: object
#
# Index: 8280, Ligne complète:
# Name            College Hoops 2K6
# Index                        6648
# Platform                      PS2
# Year                          NaN
# Genre                      Sports
# Publisher                 Unknown
# NA_Sales                     0.12
# EU_Sales                      0.1
# JP_Sales                      0.0
# Other_Sales                  0.03
# Global_Sales                 0.25
# Critic_Score                 77.0
# Critic_Count                 14.0
# Developer               2K Sports
# User_Score                    7.3
# User_Count                    6.0
# Rating                          E
# Name: 8280, dtype: object
#
# Index: 8409, Ligne complète:
# Name            Mega Man X Collection
# Index                            6778
# Platform                          PS2
# Year                              NaN
# Genre                            Misc
# Publisher                     Unknown
# NA_Sales                         0.12
# EU_Sales                         0.09
# JP_Sales                          0.0
# Other_Sales                      0.03
# Global_Sales                     0.24
# Critic_Score                     73.0
# Critic_Count                     23.0
# Developer                      Capcom
# User_Score                        8.8
# User_Count                       14.0
# Rating                              E
# Name: 8409, dtype: object
#
# Index: 8434, Ligne complète:
# Name                      BioShock 2
# Index                           6807
# Platform                          PC
# Year                             NaN
# Genre                        Shooter
# Publisher       Take-Two Interactive
# NA_Sales                        0.02
# EU_Sales                        0.19
# JP_Sales                         0.0
# Other_Sales                     0.04
# Global_Sales                    0.24
# Critic_Score                    88.0
# Critic_Count                    93.0
# Developer                   2K Marin
# User_Score                       8.2
# User_Count                     573.0
# Rating                             M
# Name: 8434, dtype: object
#
# Index: 8552, Ligne complète:
# Name            Danganronpa: Trigger Happy Havoc
# Index                                       6920
# Platform                                     PSP
# Year                                         NaN
# Genre                                       Misc
# Publisher                                Unknown
# NA_Sales                                     0.0
# EU_Sales                                     0.0
# JP_Sales                                    0.24
# Other_Sales                                  0.0
# Global_Sales                                0.24
# Critic_Score                                80.0
# Critic_Count                                55.0
# Developer                         Spike Chunsoft
# User_Score                                   8.1
# User_Count                                 235.0
# Rating                                         M
# Name: 8552, dtype: object
#
# Index: 8558, Ligne complète:
# Name                 DanceDanceRevolution II
# Index                                   6927
# Platform                                 Wii
# Year                                     NaN
# Genre                                   Misc
# Publisher       Konami Digital Entertainment
# NA_Sales                                0.22
# EU_Sales                                 0.0
# JP_Sales                                 0.0
# Other_Sales                             0.02
# Global_Sales                            0.24
# Critic_Score                             NaN
# Critic_Count                             NaN
# Developer                             Konami
# User_Score                               tbd
# User_Count                               NaN
# Rating                                  E10+
# Name: 8558, dtype: object
#
# Index: 8571, Ligne complète:
# Name            Tony Hawk's Downhill Jam
# Index                               6938
# Platform                             Wii
# Year                                 NaN
# Genre                             Sports
# Publisher                     Activision
# NA_Sales                            0.21
# EU_Sales                             0.0
# JP_Sales                             0.0
# Other_Sales                         0.02
# Global_Sales                        0.24
# Critic_Score                        69.0
# Critic_Count                        42.0
# Developer                   Toys for Bob
# User_Score                           6.2
# User_Count                          13.0
# Rating                              E10+
# Name: 8571, dtype: object
#
# Index: 8604, Ligne complète:
# Name            Big Beach Sports 2
# Index                         6967
# Platform                       Wii
# Year                           NaN
# Genre                       Sports
# Publisher                      THQ
# NA_Sales                      0.09
# EU_Sales                      0.12
# JP_Sales                       0.0
# Other_Sales                   0.03
# Global_Sales                  0.23
# Critic_Score                   NaN
# Critic_Count                   NaN
# Developer          Jet Black Games
# User_Score                     tbd
# User_Count                     NaN
# Rating                           E
# Name: 8604, dtype: object
#
# Index: 8605, Ligne complète:
# Name            Jet X20
# Index              6969
# Platform            PS2
# Year                NaN
# Genre            Racing
# Publisher       Unknown
# NA_Sales           0.11
# EU_Sales           0.09
# JP_Sales            0.0
# Other_Sales        0.03
# Global_Sales       0.23
# Critic_Score        NaN
# Critic_Count        NaN
# Developer           NaN
# User_Score          NaN
# User_Count          NaN
# Rating              NaN
# Name: 8605, dtype: object
#
# Index: 8655, Ligne complète:
# Name             Tribes: Aerial Assault
# Index                              7036
# Platform                            PS2
# Year                                NaN
# Genre                           Shooter
# Publisher                       Unknown
# NA_Sales                           0.11
# EU_Sales                           0.09
# JP_Sales                            0.0
# Other_Sales                        0.03
# Global_Sales                       0.23
# Critic_Score                       73.0
# Critic_Count                       23.0
# Developer       Midway Studios - Austin
# User_Score                          8.8
# User_Count                         47.0
# Rating                                T
# Name: 8655, dtype: object
#
# Index: 8807, Ligne complète:
# Name                           Move Fitness
# Index                                  7182
# Platform                                PS3
# Year                                    NaN
# Genre                                Sports
# Publisher       Sony Computer Entertainment
# NA_Sales                                0.0
# EU_Sales                               0.17
# JP_Sales                                0.0
# Other_Sales                            0.05
# Global_Sales                           0.22
# Critic_Score                            NaN
# Critic_Count                            NaN
# Developer                               NaN
# User_Score                              NaN
# User_Count                              NaN
# Rating                                  NaN
# Name: 8807, dtype: object
#
# Index: 8972, Ligne complète:
# Name            Yu Yu Hakusho: Dark Tournament
# Index                                     7352
# Platform                                   PS2
# Year                                       NaN
# Genre                                 Fighting
# Publisher                                  NaN
# NA_Sales                                   0.1
# EU_Sales                                  0.08
# JP_Sales                                   0.0
# Other_Sales                               0.03
# Global_Sales                              0.21
# Critic_Score                              56.0
# Critic_Count                              15.0
# Developer                      Digital Fiction
# User_Score                                 8.5
# User_Count                                18.0
# Rating                                       T
# Name: 8972, dtype: object
#
# Index: 8991, Ligne complète:
# Name            Ghostbusters II
# Index                      7370
# Platform                   2600
# Year                        NaN
# Genre                    Action
# Publisher            Activision
# NA_Sales                    0.2
# EU_Sales                   0.01
# JP_Sales                    0.0
# Other_Sales                 0.0
# Global_Sales               0.21
# Critic_Score                NaN
# Critic_Count                NaN
# Developer                   NaN
# User_Score                  NaN
# User_Count                  NaN
# Rating                      NaN
# Name: 8991, dtype: object
#
# Index: 8992, Ligne complète:
# Name            Breakaway IV
# Index                   7371
# Platform                2600
# Year                     NaN
# Genre                 Puzzle
# Publisher              Sears
# NA_Sales                 0.2
# EU_Sales                0.01
# JP_Sales                 0.0
# Other_Sales              0.0
# Global_Sales            0.21
# Critic_Score             NaN
# Critic_Count             NaN
# Developer                NaN
# User_Score               NaN
# User_Count               NaN
# Rating                   NaN
# Name: 8992, dtype: object
#
# Index: 9003, Ligne complète:
# Name            Robotech: Battlecry
# Index                          7383
# Platform                         XB
# Year                            NaN
# Genre                       Shooter
# Publisher                   Unknown
# NA_Sales                       0.16
# EU_Sales                       0.05
# JP_Sales                        0.0
# Other_Sales                    0.01
# Global_Sales                   0.21
# Critic_Score                   72.0
# Critic_Count                   20.0
# Developer             Vicious Cycle
# User_Score                      8.5
# User_Count                      8.0
# Rating                            T
# Name: 9003, dtype: object
#
# Index: 9031, Ligne complète:
# Name            Valkyria Chronicles III: Unrecorded Chronicles
# Index                                                     7407
# Platform                                                   PSP
# Year                                                       NaN
# Genre                                                 Strategy
# Publisher                                                 Sega
# NA_Sales                                                   0.0
# EU_Sales                                                   0.0
# JP_Sales                                                  0.21
# Other_Sales                                                0.0
# Global_Sales                                              0.21
# Critic_Score                                               NaN
# Critic_Count                                               NaN
# Developer                                                 Sega
# User_Score                                                 NaN
# User_Count                                                 NaN
# Rating                                                     NaN
# Name: 9031, dtype: object
#
# Index: 9040, Ligne complète:
# Name            WRC: FIA World Rally Championship
# Index                                        7424
# Platform                                      PS3
# Year                                          NaN
# Genre                                      Racing
# Publisher                        Black Bean Games
# NA_Sales                                      0.0
# EU_Sales                                     0.15
# JP_Sales                                     0.01
# Other_Sales                                  0.05
# Global_Sales                                 0.21
# Critic_Score                                 68.0
# Critic_Count                                 24.0
# Developer                         Milestone S.r.l
# User_Score                                    4.5
# User_Count                                    4.0
# Rating                                        NaN
# Name: 9040, dtype: object
#
# Index: 9041, Ligne complète:
# Name            WRC: FIA World Rally Championship
# Index                                        7424
# Platform                                       PC
# Year                                          NaN
# Genre                                      Racing
# Publisher                        Black Bean Games
# NA_Sales                                      0.0
# EU_Sales                                     0.01
# JP_Sales                                      0.0
# Other_Sales                                   0.0
# Global_Sales                                 0.01
# Critic_Score                                 68.0
# Critic_Count                                 24.0
# Developer                         Milestone S.r.l
# User_Score                                    4.5
# User_Count                                    4.0
# Rating                                        NaN
# Name: 9041, dtype: object
#
# Index: 9045, Ligne complète:
# Name            WRC: FIA World Rally Championship
# Index                                        7424
# Platform                                     X360
# Year                                          NaN
# Genre                                      Racing
# Publisher                        Black Bean Games
# NA_Sales                                      0.0
# EU_Sales                                      0.1
# JP_Sales                                      0.0
# Other_Sales                                  0.02
# Global_Sales                                 0.12
# Critic_Score                                 68.0
# Critic_Count                                 24.0
# Developer                         Milestone S.r.l
# User_Score                                    4.5
# User_Count                                    4.0
# Rating                                        NaN
# Name: 9045, dtype: object
#
# Index: 9228, Ligne complète:
# Name                    Famista 64
# Index                         7616
# Platform                       N64
# Year                           NaN
# Genre                       Sports
# Publisher       Namco Bandai Games
# NA_Sales                       0.0
# EU_Sales                       0.0
# JP_Sales                      0.17
# Other_Sales                   0.03
# Global_Sales                   0.2
# Critic_Score                   NaN
# Critic_Count                   NaN
# Developer                      NaN
# User_Score                     NaN
# User_Count                     NaN
# Rating                         NaN
# Name: 9228, dtype: object
#
# Index: 9256, Ligne complète:
# Name               Dead Space 3
# Index                      7649
# Platform                     PC
# Year                        NaN
# Genre                    Action
# Publisher       Electronic Arts
# NA_Sales                   0.02
# EU_Sales                   0.15
# JP_Sales                    0.0
# Other_Sales                0.02
# Global_Sales                0.2
# Critic_Score               78.0
# Critic_Count               68.0
# Developer        Visceral Games
# User_Score                  6.4
# User_Count                694.0
# Rating                        M
# Name: 9256, dtype: object
#
# Index: 9505, Ligne complète:
# Name                         Pet Zombies
# Index                               7909
# Platform                             3DS
# Year                                 NaN
# Genre                         Simulation
# Publisher          Majesco Entertainment
# NA_Sales                            0.18
# EU_Sales                             0.0
# JP_Sales                             0.0
# Other_Sales                         0.01
# Global_Sales                        0.19
# Critic_Score                         NaN
# Critic_Count                         NaN
# Developer       1st Playable Productions
# User_Score                           tbd
# User_Count                           NaN
# Rating                                 T
# Name: 9505, dtype: object
#
# Index: 9539, Ligne complète:
# Name            Star Trek: Legacy
# Index                        7947
# Platform                     X360
# Year                          NaN
# Genre                  Simulation
# Publisher                 Ubisoft
# NA_Sales                     0.14
# EU_Sales                     0.03
# JP_Sales                      0.0
# Other_Sales                  0.02
# Global_Sales                 0.19
# Critic_Score                 64.0
# Critic_Count                 41.0
# Developer        Mad Doc Software
# User_Score                    5.5
# User_Count                   42.0
# Rating                       E10+
# Name: 9539, dtype: object
#
# Index: 9637, Ligne complète:
# Name            Trauma Team
# Index                  8045
# Platform                Wii
# Year                    NaN
# Genre            Simulation
# Publisher           Unknown
# NA_Sales               0.15
# EU_Sales                0.0
# JP_Sales               0.02
# Other_Sales            0.01
# Global_Sales           0.18
# Critic_Score           82.0
# Critic_Count           29.0
# Developer             Atlus
# User_Score              8.8
# User_Count             25.0
# Rating                    T
# Name: 9637, dtype: object
#
# Index: 9672, Ligne complète:
# Name              Backbreaker
# Index                    8087
# Platform                  PS3
# Year                      NaN
# Genre                  Sports
# Publisher             Unknown
# NA_Sales                 0.16
# EU_Sales                  0.0
# JP_Sales                  0.0
# Other_Sales              0.01
# Global_Sales             0.17
# Critic_Score             54.0
# Critic_Count             29.0
# Developer       NaturalMotion
# User_Score                7.6
# User_Count               68.0
# Rating                      E
# Name: 9672, dtype: object
#
# Index: 9673, Ligne complète:
# Name              Backbreaker
# Index                    8087
# Platform                 X360
# Year                      NaN
# Genre                  Sports
# Publisher             Unknown
# NA_Sales                 0.17
# EU_Sales                  0.0
# JP_Sales                  0.0
# Other_Sales              0.01
# Global_Sales             0.18
# Critic_Score             54.0
# Critic_Count             29.0
# Developer       NaturalMotion
# User_Score                7.6
# User_Count               68.0
# Rating                      E
# Name: 9673, dtype: object
#
# Index: 9730, Ligne complète:
# Name            Twisted Metal: Small Brawl
# Index                                 8158
# Platform                                PS
# Year                                   NaN
# Genre                               Action
# Publisher                          Unknown
# NA_Sales                               0.1
# EU_Sales                              0.07
# JP_Sales                               0.0
# Other_Sales                           0.01
# Global_Sales                          0.18
# Critic_Score                          51.0
# Critic_Count                          14.0
# Developer                   Incognito Inc.
# User_Score                             7.6
# User_Count                            49.0
# Rating                                   T
# Name: 9730, dtype: object
#
# Index: 9735, Ligne complète:
# Name            Otomedius Excellent
# Index                          8168
# Platform                       X360
# Year                            NaN
# Genre                       Shooter
# Publisher                   Unknown
# NA_Sales                       0.13
# EU_Sales                        0.0
# JP_Sales                       0.04
# Other_Sales                    0.01
# Global_Sales                   0.18
# Critic_Score                   48.0
# Critic_Count                    8.0
# Developer                    Konami
# User_Score                      8.1
# User_Count                     16.0
# Rating                            T
# Name: 9735, dtype: object
#
# Index: 9759, Ligne complète:
# Name            NBA Starting Five
# Index                        8205
# Platform                      PS2
# Year                          NaN
# Genre                      Sports
# Publisher                 Unknown
# NA_Sales                     0.09
# EU_Sales                     0.07
# JP_Sales                      0.0
# Other_Sales                  0.02
# Global_Sales                 0.18
# Critic_Score                 53.0
# Critic_Count                 10.0
# Developer                  Konami
# User_Score                    7.3
# User_Count                    7.0
# Rating                          E
# Name: 9759, dtype: object
#
# Index: 9787, Ligne complète:
# Name                             Teen Titans
# Index                                   8225
# Platform                                 GBA
# Year                                     NaN
# Genre                                 Action
# Publisher                            Unknown
# NA_Sales                                0.13
# EU_Sales                                0.05
# JP_Sales                                 0.0
# Other_Sales                              0.0
# Global_Sales                            0.17
# Critic_Score                            63.0
# Critic_Count                            11.0
# Developer       Artificial Mind and Movement
# User_Score                               6.9
# User_Count                              11.0
# Rating                                  E10+
# Name: 9787, dtype: object
#
# Index: 9904, Ligne complète:
# Name            James Cameron's Dark Angel
# Index                                 8336
# Platform                               PS2
# Year                                   NaN
# Genre                               Action
# Publisher            Universal Interactive
# NA_Sales                              0.08
# EU_Sales                              0.07
# JP_Sales                               0.0
# Other_Sales                           0.02
# Global_Sales                          0.17
# Critic_Score                          48.0
# Critic_Count                          17.0
# Developer            Radical Entertainment
# User_Score                             6.5
# User_Count                            19.0
# Rating                                   T
# Name: 9904, dtype: object
#
# Index: 9948, Ligne complète:
# Name            Sword of the Samurai
# Index                           8378
# Platform                         PS2
# Year                             NaN
# Genre                       Fighting
# Publisher                    Ubisoft
# NA_Sales                         0.0
# EU_Sales                         0.0
# JP_Sales                        0.17
# Other_Sales                      0.0
# Global_Sales                    0.17
# Critic_Score                     NaN
# Critic_Count                     NaN
# Developer                        NaN
# User_Score                       NaN
# User_Count                       NaN
# Rating                           NaN
# Name: 9948, dtype: object
#
# Index: 10002, Ligne complète:
# Name                                             Splatterhouse
# Index                                                     8440
# Platform                                                   PS3
# Year                                                       NaN
# Genre                                                   Action
# Publisher                                   Namco Bandai Games
# NA_Sales                                                  0.13
# EU_Sales                                                  0.02
# JP_Sales                                                   0.0
# Other_Sales                                               0.02
# Global_Sales                                              0.17
# Critic_Score                                              62.0
# Critic_Count                                              51.0
# Developer       Namco Bandai Games America, Namco Bandai Games
# User_Score                                                 7.6
# User_Count                                                60.0
# Rating                                                       M
# Name: 10002, dtype: object
#
# Index: 10111, Ligne complète:
# Name            Alone in the Dark: The New Nightmare
# Index                                           8554
# Platform                                          PS
# Year                                             NaN
# Genre                                      Adventure
# Publisher                                 Infogrames
# NA_Sales                                        0.09
# EU_Sales                                        0.06
# JP_Sales                                         0.0
# Other_Sales                                     0.01
# Global_Sales                                    0.16
# Critic_Score                                    77.0
# Critic_Count                                    15.0
# Developer                                  Darkworks
# User_Score                                       8.1
# User_Count                                      40.0
# Rating                                             M
# Name: 10111, dtype: object
#
# Index: 10174, Ligne complète:
# Name                 Vegas Party
# Index                       8622
# Platform                     Wii
# Year                         NaN
# Genre                       Misc
# Publisher                Unknown
# NA_Sales                    0.15
# EU_Sales                     0.0
# JP_Sales                     0.0
# Other_Sales                 0.01
# Global_Sales                0.16
# Critic_Score                33.0
# Critic_Count                 6.0
# Developer       Storm City Games
# User_Score                   tbd
# User_Count                   NaN
# Rating                         T
# Name: 10174, dtype: object
#
# Index: 10251, Ligne complète:
# Name            Jurassic Park: The Game
# Index                              8708
# Platform                           X360
# Year                                NaN
# Genre                            Action
# Publisher                       Unknown
# NA_Sales                           0.15
# EU_Sales                            0.0
# JP_Sales                            0.0
# Other_Sales                        0.01
# Global_Sales                       0.16
# Critic_Score                       60.0
# Critic_Count                        9.0
# Developer                Telltale Games
# User_Score                          3.6
# User_Count                        138.0
# Rating                                T
# Name: 10251, dtype: object
#
# Index: 10293, Ligne complète:
# Name            Home Run
# Index               8761
# Platform            2600
# Year                 NaN
# Genre             Sports
# Publisher          Atari
# NA_Sales            0.14
# EU_Sales            0.01
# JP_Sales             0.0
# Other_Sales          0.0
# Global_Sales        0.15
# Critic_Score         NaN
# Critic_Count         NaN
# Developer            NaN
# User_Score           NaN
# User_Count           NaN
# Rating               NaN
# Name: 10293, dtype: object
#
# Index: 10418, Ligne complète:
# Name                eJay Clubworld
# Index                         8900
# Platform                       PS2
# Year                           NaN
# Genre                         Misc
# ...
# Index                                             15706
# Platform                                             DS
# Year                                                NaN
# Genre                                              Misc
# Publisher                  Konami Digital Entertainment
# NA_Sales                                            0.0
# EU_Sales                                            0.0
# JP_Sales                                           0.02
# Other_Sales                                         0.0
# Global_Sales                                       0.02
# Critic_Score                                        NaN
# Critic_Count                                        NaN
# Developer                                           NaN
# User_Score                                          NaN
# User_Count                                          NaN
# Rating                                              NaN
# Name: 15999, dtype: object
#
# Index: 16016, Ligne complète:
# Name            Without Warning
# Index                     15726
# Platform                     XB
# Year                        NaN
# Genre                   Shooter
# Publisher                Capcom
# NA_Sales                   0.01
# EU_Sales                    0.0
# JP_Sales                    0.0
# Other_Sales                 0.0
# Global_Sales               0.02
# Critic_Score               45.0
# Critic_Count               25.0
# Developer                CiRCLE
# User_Score                  6.5
# User_Count                  8.0
# Rating                        M
# Name: 16016, dtype: object
#
# Index: 16034, Ligne complète:
# Name            Football Manager 2007
# Index                           15748
# Platform                         X360
# Year                              NaN
# Genre                          Sports
# Publisher                        Sega
# NA_Sales                          0.0
# EU_Sales                         0.01
# JP_Sales                          0.0
# Other_Sales                       0.0
# Global_Sales                     0.02
# Critic_Score                      NaN
# Critic_Count                      NaN
# Developer                         NaN
# User_Score                        NaN
# User_Count                        NaN
# Rating                            NaN
# Name: 16034, dtype: object
#
# Index: 16082, Ligne complète:
# Name            Ferrari: The Race Experience
# Index                                  15818
# Platform                                 Wii
# Year                                     NaN
# Genre                                 Racing
# Publisher           System 3 Arcade Software
# NA_Sales                                 0.0
# EU_Sales                                0.01
# JP_Sales                                 0.0
# Other_Sales                              0.0
# Global_Sales                            0.02
# Critic_Score                            54.0
# Critic_Count                             4.0
# Developer                           System 3
# User_Score                               NaN
# User_Count                               NaN
# Rating                                     E
# Name: 16082, dtype: object
#
# Index: 16125, Ligne complète:
# Name            PDC World Championship Darts 2008
# Index                                       15871
# Platform                                       DS
# Year                                          NaN
# Genre                                      Sports
# Publisher                                 Unknown
# NA_Sales                                     0.01
# EU_Sales                                      0.0
# JP_Sales                                      0.0
# Other_Sales                                   0.0
# Global_Sales                                 0.02
# Critic_Score                                 51.0
# Critic_Count                                 18.0
# Developer                      Oxygen Interactive
# User_Score                                    5.4
# User_Count                                    7.0
# Rating                                       E10+
# Name: 16125, dtype: object
#
# Index: 16126, Ligne complète:
# Name            PDC World Championship Darts 2008
# Index                                       15871
# Platform                                      PSP
# Year                                          NaN
# Genre                                      Sports
# Publisher                      Oxygen Interactive
# NA_Sales                                     0.01
# EU_Sales                                      0.0
# JP_Sales                                      0.0
# Other_Sales                                   0.0
# Global_Sales                                 0.01
# Critic_Score                                 51.0
# Critic_Count                                 18.0
# Developer                      Oxygen Interactive
# User_Score                                    5.4
# User_Count                                    7.0
# Rating                                       E10+
# Name: 16126, dtype: object
#
# Index: 16134, Ligne complète:
# Name            Dinotopia: The Sunstone Odyssey
# Index                                     15882
# Platform                                     GC
# Year                                        NaN
# Genre                                    Action
# Publisher                               Unknown
# NA_Sales                                   0.01
# EU_Sales                                    0.0
# JP_Sales                                    0.0
# Other_Sales                                 0.0
# Global_Sales                               0.02
# Critic_Score                               50.0
# Critic_Count                                4.0
# Developer                         Vicious Cycle
# User_Score                                  tbd
# User_Count                                  NaN
# Rating                                        T
# Name: 16134, dtype: object
#
# Index: 16137, Ligne complète:
# Name            Dance! It's Your Stage
# Index                            15884
# Platform                           Wii
# Year                               NaN
# Genre                             Misc
# Publisher            DTP Entertainment
# NA_Sales                           0.0
# EU_Sales                          0.01
# JP_Sales                           0.0
# Other_Sales                        0.0
# Global_Sales                      0.02
# Critic_Score                       NaN
# Critic_Count                       NaN
# Developer                          NaN
# User_Score                         NaN
# User_Count                         NaN
# Rating                             NaN
# Name: 16137, dtype: object
#
# Index: 16155, Ligne complète:
# Name            Jet Impulse
# Index                 15906
# Platform                 DS
# Year                    NaN
# Genre            Simulation
# Publisher          Nintendo
# NA_Sales                0.0
# EU_Sales                0.0
# JP_Sales               0.02
# Other_Sales             0.0
# Global_Sales           0.02
# Critic_Score            NaN
# Critic_Count            NaN
# Developer               NaN
# User_Score              NaN
# User_Count              NaN
# Rating                  NaN
# Name: 16155, dtype: object
#
# Index: 16170, Ligne complète:
# Name                                        Dream Dancer
# Index                                              15921
# Platform                                              DS
# Year                                                 NaN
# Genre                                               Misc
# Publisher                                            NaN
# NA_Sales                                            0.01
# EU_Sales                                             0.0
# JP_Sales                                             0.0
# Other_Sales                                          0.0
# Global_Sales                                        0.02
# Critic_Score                                         NaN
# Critic_Count                                         NaN
# Developer       CyberPlanet Interactive Public Co., Ltd.
# User_Score                                           tbd
# User_Count                                           NaN
# Rating                                                 E
# Name: 16170, dtype: object
#
# Index: 16290, Ligne complète:
# Name            Aquaman: Battle for Atlantis
# Index                                  16072
# Platform                                  XB
# Year                                     NaN
# Genre                                 Action
# Publisher                            Unknown
# NA_Sales                                0.01
# EU_Sales                                 0.0
# JP_Sales                                 0.0
# Other_Sales                              0.0
# Global_Sales                            0.01
# Critic_Score                            26.0
# Critic_Count                            13.0
# Developer                      Lucky Chicken
# User_Score                               2.7
# User_Count                              15.0
# Rating                                     T
# Name: 16290, dtype: object
#
# Index: 16386, Ligne complète:
# Name            Homeworld Remastered Collection
# Index                                     16201
# Platform                                     PC
# Year                                        NaN
# Genre                                  Strategy
# Publisher                                   NaN
# NA_Sales                                    0.0
# EU_Sales                                   0.01
# JP_Sales                                    0.0
# Other_Sales                                 0.0
# Global_Sales                               0.01
# Critic_Score                               86.0
# Critic_Count                               49.0
# Developer                      Gearbox Software
# User_Score                                  8.2
# User_Count                                324.0
# Rating                                     E10+
# Name: 16386, dtype: object
#
# Index: 16388, Ligne complète:
# Name                                  Shorts
# Index                                  16204
# Platform                                  DS
# Year                                     NaN
# Genre                               Platform
# Publisher                            Unknown
# NA_Sales                                0.01
# EU_Sales                                 0.0
# JP_Sales                                 0.0
# Other_Sales                              0.0
# Global_Sales                            0.01
# Critic_Score                             NaN
# Critic_Count                             NaN
# Developer       Artificial Mind and Movement
# User_Score                               tbd
# User_Count                               NaN
# Rating                                  E10+
# Name: 16388, dtype: object
#
# Index: 16392, Ligne complète:
# Name            AKB1/48: Idol to Guam de Koishitara...
# Index                                            16208
# Platform                                          X360
# Year                                               NaN
# Genre                                             Misc
# Publisher                                          NaN
# NA_Sales                                           0.0
# EU_Sales                                           0.0
# JP_Sales                                          0.01
# Other_Sales                                        0.0
# Global_Sales                                      0.01
# Critic_Score                                       NaN
# Critic_Count                                       NaN
# Developer                                          NaN
# User_Score                                         NaN
# User_Count                                         NaN
# Rating                                             NaN
# Name: 16392, dtype: object
#
# Index: 16415, Ligne complète:
# Name            Brothers in Arms: Furious 4
# Index                                 16239
# Platform                               X360
# Year                                    NaN
# Genre                               Shooter
# Publisher                               NaN
# NA_Sales                               0.01
# EU_Sales                                0.0
# JP_Sales                                0.0
# Other_Sales                             0.0
# Global_Sales                           0.01
# Critic_Score                            NaN
# Critic_Count                            NaN
# Developer                  Gearbox Software
# User_Score                              NaN
# User_Count                              NaN
# Rating                                    M
# Name: 16415, dtype: object
#
# Index: 16426, Ligne complète:
# Name            Agarest Senki: Re-appearance
# Index                                  16256
# Platform                                 PS3
# Year                                     NaN
# Genre                           Role-Playing
# Publisher                       Idea Factory
# NA_Sales                                 0.0
# EU_Sales                                 0.0
# JP_Sales                                0.01
# Other_Sales                              0.0
# Global_Sales                            0.01
# Critic_Score                             NaN
# Critic_Count                             NaN
# Developer                                NaN
# User_Score                               NaN
# User_Count                               NaN
# Rating                                   NaN
# Name: 16426, dtype: object
#
# Index: 16473, Ligne complète:
# Name                         Freaky Flyers
# Index                                16317
# Platform                                GC
# Year                                   NaN
# Genre                               Racing
# Publisher                          Unknown
# NA_Sales                              0.01
# EU_Sales                               0.0
# JP_Sales                               0.0
# Other_Sales                            0.0
# Global_Sales                          0.01
# Critic_Score                          66.0
# Critic_Count                          20.0
# Developer       Midway Studios - San Diego
# User_Score                             tbd
# User_Count                             NaN
# Rating                                   T
# Name: 16473, dtype: object
#
# Index: 16490, Ligne complète:
# Name                     Inversion
# Index                        16337
# Platform                        PC
# Year                           NaN
# Genre                      Shooter
# Publisher       Namco Bandai Games
# NA_Sales                      0.01
# EU_Sales                       0.0
# JP_Sales                       0.0
# Other_Sales                    0.0
# Global_Sales                  0.01
# Critic_Score                  56.0
# Critic_Count                  23.0
# Developer        Saber Interactive
# User_Score                     5.4
# User_Count                    43.0
# Rating                           M
# Name: 16490, dtype: object
#
# Index: 16518, Ligne complète:
# Name            Hakuouki: Shinsengumi Kitan
# Index                                 16376
# Platform                                PS3
# Year                                    NaN
# Genre                             Adventure
# Publisher                           Unknown
# NA_Sales                               0.01
# EU_Sales                                0.0
# JP_Sales                                0.0
# Other_Sales                             0.0
# Global_Sales                           0.01
# Critic_Score                            NaN
# Critic_Count                            NaN
# Developer                               NaN
# User_Score                              NaN
# User_Count                              NaN
# Rating                                  NaN
# Name: 16518, dtype: object
#
# Index: 16606, Ligne complète:
# Name            The Smurfs
# Index                16500
# Platform               3DS
# Year                   NaN
# Genre               Action
# Publisher          Unknown
# NA_Sales               0.0
# EU_Sales              0.01
# JP_Sales               0.0
# Other_Sales            0.0
# Global_Sales          0.01
# Critic_Score           NaN
# Critic_Count           NaN
# Developer         Land Ho!
# User_Score             tbd
# User_Count             NaN
# Rating                   E
# Name: 16606, dtype: object

# %% [markdown]
# ## Heatmap des valeurs manquantes dans notre jeu de données

# %%
import seaborn as sns

# Graphique Seaborn pour créer une heatmap des valeurs manquantes

plt.figure(figsize=(10, 6))
sns.heatmap(df.isna(), cbar=False, cmap='viridis', yticklabels=False)
plt.title('Heatmap des valeurs manquantes')
plt.show()

# %% [markdown]
# Nombre de valeur manquante (NAN) dans les variables du dataset

# %% [markdown]
# ## Remplacement des valeurs manquantes dans "Year"

# %%
# Dictionnaire des années manquantes de chaque jeu

years_dict = {
    'LEGO Harry Potter: Years 5-7': 2011,
    'Test Drive Unlimited 2': 2011,
    'The Chronicles of Narnia: The Lion, The Witch and The Wardrobe': 2005,
    'NBA Live 2003': 2002,
    'Bejeweled 3': 2010,
    'Singularity': 2010,
    'All-Star Baseball 2005': 2004,
    'Star Wars Jedi Knight II: Jedi Outcast' : 2002,
    'Slot Machine': 1979,
    'Shrek the Third': 2007,
    'The Dukes of Hazzard II: Daisy Dukes It Out': 2005,
    'Disgaea 3: Absence of Detention': 2012,
    'Harvest Moon: The Tale of Two Towns': 2010,
    'Nicktoons: Battle for Volcano Island': 2006,
    'Haven: Call of the King': 2002,
    'Unreal Championship 2: The Liandri Conflict': 2005,
    'Pac-Man Fever': 2002,
    'The Legend of Zelda: The Minish Cap': 2004,
    'Indy 500': 1977,
    'Gun': 2005,
    'Flag Capture': 1978,
    'Rock Revolution': 2008,
    'Jonah Lomu Rugby Challenge': 2011,
    'College Hoops 2K6': 2005,
    'Mega Man X Collection': 2006,
    'BioShock 2': 2010,
    'Danganronpa: Trigger Happy Havoc': 2014,
    'DanceDanceRevolution II': 2011,
    "Tony Hawk's Downhill Jam": 2006,
    'Big Beach Sports 2': 2008,
    'Jet X20': 2002,
    'Tribes: Aerial Assault': 2002,
    'Move Fitness': 2013,
    'Yu Yu Hakusho: Dark Tournament': 2004,
    'Ghostbusters II': 1992,
    'Breakaway IV': 1978,
    'Robotech: Battlecry': 2002,
    'Valkyria Chronicles III: Unrecorded Chronicles': 2011,
    'WRC: FIA World Rally Championship': 2011,
    'Famista 64': 1997,
    'Dead Space 3': 2013,
    'Pet Zombies': 2011,
    'Star Trek: Legacy': 2006,
    'Trauma Team': 2010,
    'Backbreaker': 2010,
    'Twisted Metal: Small Brawl': 2001,
    'Otomedius Excellent': 2011,
    'NBA Starting Five': 2002,
    'Teen Titans': 2005,
    "James Cameron's Dark Angel": 2002,
    'Sword of the Samurai': 1989,
    'Splatterhouse': 2010,
    'Alone in the Dark: The New Nightmare': 2001,
    'Vegas Party': 2009,
    'Jurassic Park: The Game': 2011,
    'Home Run': 1978,
    'eJay Clubworld': 2003,
    'Our House Party!': 2009,
    'WCW Backstage Assault': 2000,
    "Disney's Cinderella: Magical Dreams": 2005,
    'Transworld Surf': 2001,
    'Street Fighter IV': 2009,
    'Nintendo Puzzle Collection': 2003,
    'Charm Girls Club: My Fashion Mall': 2009,
    'Record of Agarest War Zero': 2011,
    'Super Robot Wars OG Saga: Masou Kishin II - Revelation of Evil God': 2012,
    'Saru! Get You! Million Monkeys': 2006,
    'Street Hoops': 2002,
    'Godzilla: Destroy All Monsters Melee': 2002,
    'The Daring Game for Girls': 2010,
    'Rocksmith': 2011,
    'Major League Baseball 2K6': 2006,
    'Happy Feet Two': 2011,
    'Star Trek: Conquest': 2007,
    'GiFTPiA': 2003,
    "Disney's Chicken Little: Ace In Action": 2006,
    'Atsumare! Power Pro Kun no DS Koushien': 2006,
    'My Healthy Cooking Coach': 2009,
    'Luminous Arc 2 (JP sales)': 2008,
    'Egg Monster Hero': 2005,
    'Samurai Shodown Anthology': 2009,
    'Demon Chaos': 2005,
    'Action Man-Operation Extreme': 2000,
    'Super Puzzle Fighter II': 1996,
    'Charm Girls Club: My Fashion Show': 2009,
    'Get Fit with Mel B': 2010,
    'Face Racers: Photo Finish': 2011,
    'Zero: Tsukihami no Kamen': 2008,
    'The Hidden': 2007,
    'Dead Island: Riptide': 2013,
    'Mega Man Battle Network: Operation Shooting Star': 2009,
    'Smashing Drive': 2002,
    'Dream Trigger 3D': 2011,
    'Tornado': 2008,
    "McFarlane's Evil Prophecy": 2004,
    'Drake of the 99 Dragons': 2003,
    'Port Royale 3': 2012,
    'Build-A-Bear Workshop: Friendship Valley': 2010,
    'Alex Rider: Stormbreaker': 2006,
    'Yoostar on MTV': 2011,
    'Rayman Arena': 2002,
    'National Geographic Challenge!': 2011,
    'Jewel Link Chronicles: Mountains of Madness': 2012,
    'Chou Soujuu Mecha MG': 2006,
    'Prinny: Can I Really Be The Hero? (US sales)': 2008,
    'Combat Elite: WWII Paratroopers': 2005,
    'Captain America: Super Soldier': 2011,
    "Flip's Twisted World": 2010,
    'Mobile Ops: The One Year War': 2008,
    "Tom Clancy's Rainbow Six: Critical Hour": 2006,
    'GRID': 2008,
    'Reader Rabbit 2nd Grade': 2010,
    'Mountain Bike Adrenaline': 2007,
    'Tour de France 2011': 2011,
    'Drill Dozer': 2006,
    'Battle vs. Chess': 2012,
    'The History Channel: Great Battles - Medieval': 2010,
    'Monster Hunter Frontier Online': 2007,
    'RollerCoaster Tycoon': 1999,
    'B.L.U.E.: Legend of Water': 1998,
    "Luxor: Pharaoh's Challenge": 2007,
    'NHL Hitz Pro': 2003,
    'Sega Rally 2006': 2006,
    'World of Tanks': 2014,
    'Swords': 2010,
    'Half-Minute Hero 2': 2011,
    'Clockwork Empires': 2016,
    'Housekeeping': 2006,
    'Major League Baseball 2K8': 2008,
    'Sabre Wulf': 2004,
    'Beyond the Labyrinth': 2012,
    'Bikkuriman Daijiten': 2007,
    'Majesty 2: The Fantasy Kingdom Sim': 2009,
    'Fullmetal Alchemist: Brotherhood': 2009,
    'Samurai Spirits: Tenkaichi Kenkakuden': 2005,
    'Tom and Jerry in War of the Whiskers': 2002,
    'Super Duper Sumos': 2003,
    'Legacy of Ys: Books I & II': 2009,
    'The King of Fighters: Maximum Impact - Maniax': 2005,
    'Combat Wings: The Great Battles of WWII': 2012,
    'Tube Slider': 2003,
    'Umineko no Naku Koro ni San: Shinjitsu to Gensou no Yasoukyoku': 2011,
    'Wii de Asobu: Metroid Prime': 2009,
    'Payout Poker & Casino': 2006,
    'Saint': 2009,
    'Steal Princess': 2009,
    'Mario Tennis': 2000,
    'Runaway: A Twist of Fate': 2011,
    "Yu-Gi-Oh! 5D's Wheelie Breakers (JP sales)": 2009,
    "Cabela's Alaskan Adventure": 2006,
    'Writing and Speaking Beautiful Japanese DS': 2008,
    'Virtua Quest': 2005,
    "Shonen Jump's Yu-Gi-Oh! GX Card Almanac": 2007,
    'Without Warning': 2005,
    'Football Manager 2007': 2006,
    'Ferrari: The Race Experience': 2011,
    'PDC World Championship Darts 2008': 2009,
    'Dinotopia: The Sunstone Odyssey': 2003,
    "Dance! It's Your Stage": 2010,
    'Jet Impulse': 2007,
    'Dream Dancer': 2009,
    'Aquaman: Battle for Atlantis': 2003,
    'Homeworld Remastered Collection': 2015,
    'Shorts': 2009,
    'AKB1/48: Idol to Guam de Koishitara...': 2011,
    'Agarest Senki: Re-appearance': 2010,
    'Freaky Flyers': 2003,
    'Inversion': 2012,
    'Hakuouki: Shinsengumi Kitan': 2008,
    'The Smurfs': 2015,
    'The Legend of Zelda: The Minish Cap(weekly JP sales)': 2005,
    'Brothers in Arms: Furious 4': 2014,

    # Ajoutez d'autres jeux ici...
}

# Fonction pour remplir les années manquantes automatiquement

def fill_year(row):
    if pd.isna(row['Year']):
        return years_dict.get(row['Name'], row['Year'])
    return row['Year']

# Application du remplissage

df['Year'] = df.apply(fill_year, axis=1)

# Vérification les premières lignes du DataFrame après remplissage

# print(df.head(10))

# %%
# Identifier les valeurs manquantes dans la colonne Year

valeurs_manquantes = df[df["Year"].isna()]
colonne = "Year"

# Boucle pour afficher les lignes contenant des valeurs manquantes

for index, row in valeurs_manquantes.iterrows():
    print(f"Index: {index}, Ligne complète: \n{row}\n")

# %%
df.isna().sum()
# Out:
# Name               0
# Index              0
# Platform          48
# Year               0
# Genre              0
# Publisher         54
# NA_Sales           0
# EU_Sales           0
# JP_Sales           0
# Other_Sales        0
# Global_Sales       0
# Critic_Score    8282
# Critic_Count    8282
# Developer       5905
# User_Score      6032
# User_Count      8001
# Rating          6042
# dtype: int64

# %%
df.head(20)
# Out:
#                            Name  Index Platform    Year         Genre  \
# 0                    Wii Sports      1      Wii  2006.0        Sports
# 1             Super Mario Bros.      2      NES  1985.0      Platform
# 2             Super Mario Bros.      2       GB  1999.0      Platform
# 3                Mario Kart Wii      3      Wii  2008.0        Racing
# 4             Wii Sports Resort      4      Wii  2009.0        Sports
# 5      Pokemon Red/Pokemon Blue      5       GB  1996.0  Role-Playing
# 6                        Tetris      6      NES  1988.0        Puzzle
# 7                        Tetris      6       GB  1989.0        Puzzle
# 8         New Super Mario Bros.      7       DS  2006.0      Platform
# 9                      Wii Play      8      Wii  2006.0          Misc
# 10    New Super Mario Bros. Wii      9      Wii  2009.0      Platform
# 11                    Duck Hunt     10      NES  1984.0       Shooter
# 12                   Nintendogs     11       DS  2005.0    Simulation
# 13                Mario Kart DS     12       DS  2005.0        Racing
# 14  Pokemon Gold/Pokemon Silver     13       GB  1999.0  Role-Playing
# 15                      Wii Fit     14      Wii  2007.0        Sports
# 16                 Wii Fit Plus     15      Wii  2009.0        Sports
# 17           Kinect Adventures!     16     X360  2010.0          Misc
# 18           Grand Theft Auto V     17     X360  2013.0        Action
# 19           Grand Theft Auto V     17      PS4  2014.0        Action
#
#                  Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0                 Nintendo     41.49     29.02      3.77         8.46
# 1                 Nintendo     29.08      3.58      6.81         0.77
# 2                 Nintendo      3.40      1.30      0.15         0.22
# 3                 Nintendo     15.85     12.88      3.79         3.31
# 4                 Nintendo     15.75     11.01      3.28         2.96
# 5                 Nintendo     11.27      8.89     10.22         1.00
# 6                 Nintendo      2.97      0.69      1.81         0.11
# 7                 Nintendo     23.20      2.26      4.22         0.58
# 8                 Nintendo     11.38      9.23      6.50         2.90
# 9                 Nintendo     14.03      9.20      2.93         2.85
# 10                Nintendo     14.59      7.06      4.70         2.26
# 11                Nintendo     26.93      0.63      0.28         0.47
# 12                Nintendo      9.07     11.00      1.93         2.75
# 13                Nintendo      9.81      7.57      4.13         1.92
# 14                Nintendo      9.00      6.18      7.20         0.71
# 15                Nintendo      8.94      8.03      3.60         2.15
# 16                Nintendo      9.09      8.59      2.53         1.79
# 17  Microsoft Game Studios     14.97      4.94      0.24         1.67
# 18    Take-Two Interactive      9.63      5.31      0.06         1.38
# 19    Take-Two Interactive      3.80      5.81      0.36         2.02
#
#     Global_Sales  Critic_Score  Critic_Count            Developer User_Score  \
# 0          82.74          76.0          51.0             Nintendo          8
# 1          40.24           NaN           NaN             Nintendo        8.3
# 2           5.07           NaN           NaN             Nintendo        8.3
# 3          35.82          82.0          73.0             Nintendo        8.3
# 4          33.00          80.0          73.0             Nintendo          8
# 5          31.37           NaN           NaN                  NaN        NaN
# 6           5.58           NaN           NaN                  NaN        NaN
# 7          30.26           NaN           NaN                  NaN        NaN
# 8          30.01          89.0          65.0             Nintendo        8.5
# 9          29.02          58.0          41.0             Nintendo        6.6
# 10         28.62          87.0          80.0             Nintendo        8.4
# 11         28.31           NaN           NaN                  NaN        NaN
# 12         24.76           NaN           NaN                  NaN        NaN
# 13         23.42          91.0          64.0             Nintendo        8.6
# 14         23.10           NaN           NaN                  NaN        NaN
# 15         22.72          80.0          63.0             Nintendo        7.7
# 16         22.00          80.0          33.0             Nintendo        7.4
# 17         21.82          61.0          45.0  Good Science Studio        6.3
# 18         16.38          97.0          50.0       Rockstar North        8.2
# 19         11.98          97.0          50.0       Rockstar North        8.2
#
#     User_Count Rating
# 0        322.0      E
# 1        138.0      E
# 2        138.0      E
# 3        709.0      E
# 4        192.0      E
# 5          NaN    NaN
# 6          NaN    NaN
# 7          NaN    NaN
# 8        431.0      E
# 9        129.0      E
# 10       594.0      E
# 11         NaN    NaN
# 12         NaN    NaN
# 13       464.0      E
# 14         NaN    NaN
# 15       146.0      E
# 16        52.0      E
# 17       106.0      E
# 18      3994.0      M
# 19      3994.0      M

# %% [markdown]
# ## Remplacement des valeurs manquantes dans "User" et "Critic"

# %%
# Remplacement les valeurs "tbd" par NaN dans la colonne User_Score

df['User_Score'].replace('tbd', np.nan, inplace=True)
df['User_Score'].replace('NaN', np.nan, inplace=True)

# Conversion des colonnes nécessaires en numérique

df['User_Score'] = pd.to_numeric(df['User_Score'], errors='coerce')  # 'coerce' pour transformer les non-convertibles en NaN
df['Critic_Score'] = pd.to_numeric(df['Critic_Score'], errors='coerce')
df['User_Count'] = pd.to_numeric(df['User_Count'], errors='coerce')
df['Critic_Count'] = pd.to_numeric(df['Critic_Count'], errors='coerce')

# Calcul de la moyenne en ignorant les NaN

#mean_user_score = df['User_Score'].mean(skipna=True)
#mean_critic_score = df['Critic_Score'].mean(skipna=True)
#mean_user_count = df['User_Count'].mean(skipna=True)
#mean_critic_count = df['Critic_Count'].mean(skipna=True)

#print("La moyenne du Score Utilisateur est de ", mean_user_score)
#print("La moyenne du Score Critique est de ",mean_critic_score)
#print("La moyenne du Nombre d'avis Utilisateurs est de ",mean_user_count)
#print("La moyenne du Nombre d'avis des Critiques est de ",mean_critic_count)
# Out:
# <ipython-input-37-00a5a1ca6de8>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['User_Score'].replace('tbd', np.nan, inplace=True)
# <ipython-input-37-00a5a1ca6de8>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['User_Score'].replace('NaN', np.nan, inplace=True)

# %%
df["User_Score"].value_counts()
# Out:
# User_Score
# 8.2    351
# 7.8    332
# 8.0    323
# 8.5    322
# 8.3    315
#       ...
# 9.7      1
# 0.7      1
# 0.2      1
# 1.2      1
# 0.6      1
# Name: count, Length: 95, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16730 entries, 0 to 16729
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          16730 non-null  object
#  1   Index         16730 non-null  int64
#  2   Platform      16682 non-null  object
#  3   Year          16730 non-null  float64
#  4   Genre         16730 non-null  object
#  5   Publisher     16676 non-null  object
#  6   NA_Sales      16730 non-null  float64
#  7   EU_Sales      16730 non-null  float64
#  8   JP_Sales      16730 non-null  float64
#  9   Other_Sales   16730 non-null  float64
#  10  Global_Sales  16730 non-null  float64
#  11  Critic_Score  8448 non-null   float64
#  12  Critic_Count  8448 non-null   float64
#  13  Developer     10825 non-null  object
#  14  User_Score    8553 non-null   float64
#  15  User_Count    8729 non-null   float64
#  16  Rating        10688 non-null  object
# dtypes: float64(10), int64(1), object(6)
# memory usage: 2.2+ MB

# %%
# Remplacement des valeurs manquantes par la moyenne respective

#df['User_Score'].fillna(mean_user_score, inplace=True)
#df['Critic_Score'].fillna(mean_critic_score, inplace=True)
#df['User_Count'].fillna(mean_user_count, inplace=True)
#df['Critic_Count'].fillna(mean_critic_count, inplace=True)

# Vérification

print(df.isna().sum())
# Out:
# Name               0
# Index              0
# Platform          48
# Year               0
# Genre              0
# Publisher         54
# NA_Sales           0
# EU_Sales           0
# JP_Sales           0
# Other_Sales        0
# Global_Sales       0
# Critic_Score    8282
# Critic_Count    8282
# Developer       5905
# User_Score      8177
# User_Count      8001
# Rating          6042
# dtype: int64

# %% [markdown]
# ## Test moyenne par "Genre" pour "User" et "Critic"

# %%
# Calculer la moyenne des notes et du nombre d'avis pour chaque genre

genre_mean_userscore = df.groupby('Genre')['User_Score'].mean()

print(genre_mean_userscore.head(15))

genre_mean_usercount = df.groupby('Genre')['User_Count'].mean()

print(genre_mean_usercount.head(15))

genre_mean_criticscore = df.groupby('Genre')['Critic_Score'].mean()

print(genre_mean_criticscore.head(15))

genre_mean_criticcount = df.groupby('Genre')['Critic_Count'].mean()

print(genre_mean_criticcount.head(15))

# Remplacer les valeurs manquantes par la moyenne des notes du genre correspondant

df['User_Score'] = df.apply(lambda row: genre_mean_userscore[row['Genre']] if pd.isnull(row['User_Score']) else row['User_Score'], axis=1)
df['User_Count'] = df.apply(lambda row: genre_mean_usercount[row['Genre']] if pd.isnull(row['User_Count']) else row['User_Count'], axis=1)
df['Critic_Score'] = df.apply(lambda row: genre_mean_criticscore[row['Genre']] if pd.isnull(row['Critic_Score']) else row['Critic_Score'], axis=1)
df['Critic_Count'] = df.apply(lambda row: genre_mean_criticcount[row['Genre']] if pd.isnull(row['Critic_Count']) else row['Critic_Count'], axis=1)

# Afficher les premières lignes du DataFrame pour vérifier le remplissage

print("\nAperçu du DataFrame après remplissage des valeurs manquantes:")
print(df.head())
# Out:
# Genre
# Action          7.178607
# Adventure       7.262722
# Fighting        7.309091
# Misc            6.986804
# Platform        7.444359
# Puzzle          7.201987
# Racing          7.189515
# Role-Playing    7.653837
# Shooter         7.166465
# Simulation      7.206522
# Sports          7.132806
# Strategy        7.219658
# Name: User_Score, dtype: float64
# Genre
# Action          234.625913
# Adventure       117.734104
# Fighting         82.225806
# Misc             48.438735
# Platform        120.752688
# Puzzle           39.791411
# Racing           70.807692
# Role-Playing    385.848414
# Shooter         386.557884
# Simulation      106.970509
# Sports           71.453333
# Strategy        200.540616
# Name: User_Count, dtype: float64
# Genre
# Action          67.737456
# Adventure       65.978528
# Fighting        70.027273
# Misc            66.656126
# Platform        68.190574
# Puzzle          67.317391
# Racing          68.853282
# Role-Playing    72.992157
# Shooter         70.758799
# Simulation      68.991453
# Sports          73.283019
# Strategy        71.963455
# Name: Critic_Score, dtype: float64
# Genre
# Action          33.739990
# Adventure       23.239264
# Fighting        30.897727
# Misc            23.638340
# Platform        25.538934
# Puzzle          19.860870
# Racing          26.507079
# Role-Playing    35.711111
# Shooter         40.787785
# Simulation      21.985755
# Sports          25.043019
# Strategy        30.255814
# Name: Critic_Count, dtype: float64
#
# Aperçu du DataFrame après remplissage des valeurs manquantes:
#                 Name  Index Platform    Year     Genre Publisher  NA_Sales  \
# 0         Wii Sports      1      Wii  2006.0    Sports  Nintendo     41.49
# 1  Super Mario Bros.      2      NES  1985.0  Platform  Nintendo     29.08
# 2  Super Mario Bros.      2       GB  1999.0  Platform  Nintendo      3.40
# 3     Mario Kart Wii      3      Wii  2008.0    Racing  Nintendo     15.85
# 4  Wii Sports Resort      4      Wii  2009.0    Sports  Nintendo     15.75
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  Critic_Count  \
# 0     29.02      3.77         8.46         82.74     76.000000     51.000000
# 1      3.58      6.81         0.77         40.24     68.190574     25.538934
# 2      1.30      0.15         0.22          5.07     68.190574     25.538934
# 3     12.88      3.79         3.31         35.82     82.000000     73.000000
# 4     11.01      3.28         2.96         33.00     80.000000     73.000000
#
#   Developer  User_Score  User_Count Rating
# 0  Nintendo         8.0       322.0      E
# 1  Nintendo         8.3       138.0      E
# 2  Nintendo         8.3       138.0      E
# 3  Nintendo         8.3       709.0      E
# 4  Nintendo         8.0       192.0      E

# %%
print(df["User_Score"].value_counts())
print("------------------------")
print(df.info())
print("------------------------")
print(df.isna().sum())
# Out:
# User_Score
# 7.178607    1342
# 6.986804    1268
# 7.132806    1099
# 7.262722     954
# 7.653837     647
#             ...
# 9.700000       1
# 0.700000       1
# 0.200000       1
# 1.200000       1
# 0.600000       1
# Name: count, Length: 107, dtype: int64
# ------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16730 entries, 0 to 16729
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          16730 non-null  object
#  1   Index         16730 non-null  int64
#  2   Platform      16682 non-null  object
#  3   Year          16730 non-null  float64
#  4   Genre         16730 non-null  object
#  5   Publisher     16676 non-null  object
#  6   NA_Sales      16730 non-null  float64
#  7   EU_Sales      16730 non-null  float64
#  8   JP_Sales      16730 non-null  float64
#  9   Other_Sales   16730 non-null  float64
#  10  Global_Sales  16730 non-null  float64
#  11  Critic_Score  16730 non-null  float64
#  12  Critic_Count  16730 non-null  float64
#  13  Developer     10825 non-null  object
#  14  User_Score    16730 non-null  float64
#  15  User_Count    16730 non-null  float64
#  16  Rating        10688 non-null  object
# dtypes: float64(10), int64(1), object(6)
# memory usage: 2.2+ MB
# None
# ------------------------
# Name               0
# Index              0
# Platform          48
# Year               0
# Genre              0
# Publisher         54
# NA_Sales           0
# EU_Sales           0
# JP_Sales           0
# Other_Sales        0
# Global_Sales       0
# Critic_Score       0
# Critic_Count       0
# Developer       5905
# User_Score         0
# User_Count         0
# Rating          6042
# dtype: int64

# %% [markdown]
# ## Remplacement des valeurs manquantes dans "Platform"

# %%
print(df["Name"] == "Watch Dogs 2")
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 16725    False
# 16726    False
# 16727     True
# 16728    False
# 16729    False
# Name: Name, Length: 16730, dtype: bool

# %%
# Identifier les valeurs manquantes dans la colonne Year

platform_manquantes = df[df["Platform"].isna()]
colonne_platform = "Platform"

# Boucle pour afficher les lignes contenant des valeurs manquantes

for index, row in platform_manquantes.iterrows():
    print(f"Index: {index}, Ligne complète: \n{row}\n")

# Problème : ces jeux sont sortis sur différentes plateformes en même temps
# Out:
# Index: 16682, Ligne complète:
# Name            Assassin's Creed The Ezio Collection
# Index                                          16734
# Platform                                         NaN
# Year                                          2016.0
# Genre                                         Action
# Publisher                                    Ubisoft
# NA_Sales                                        0.04
# EU_Sales                                        0.13
# JP_Sales                                         0.0
# Other_Sales                                     0.03
# Global_Sales                                     0.2
# Critic_Score                                    72.0
# Critic_Count                                    32.0
# Developer                           Ubisoft Montreal
# User_Score                                       7.4
# User_Count                                      49.0
# Rating                                             M
# Name: 16682, dtype: object
#
# Index: 16683, Ligne complète:
# Name            Azure Striker Gunvolt
# Index                           16746
# Platform                          NaN
# Year                           2016.0
# Genre                          Action
# Publisher            Yacht Club Games
# NA_Sales                         0.01
# EU_Sales                          0.0
# JP_Sales                          0.0
# Other_Sales                       0.0
# Global_Sales                     0.01
# Critic_Score                     77.0
# Critic_Count                     20.0
# Developer                Inti Creates
# User_Score                        8.4
# User_Count                       62.0
# Rating                           E10+
# Name: 16683, dtype: object
#
# Index: 16684, Ligne complète:
# Name                                 Batman: Arkham VR
# Index                                            16770
# Platform                                           NaN
# Year                                            2016.0
# Genre                                           Action
# Publisher       Warner Bros. Interactive Entertainment
# NA_Sales                                          0.25
# EU_Sales                                           0.0
# JP_Sales                                           0.0
# Other_Sales                                       0.06
# Global_Sales                                       0.3
# Critic_Score                                      75.0
# Critic_Count                                      59.0
# Developer                           Rocksteady Studios
# User_Score                                         7.3
# User_Count                                        89.0
# Rating                                               M
# Name: 16684, dtype: object
#
# Index: 16685, Ligne complète:
# Name                          Batman: Return to Arkham
# Index                                            16771
# Platform                                           NaN
# Year                                            2016.0
# Genre                                           Action
# Publisher       Warner Bros. Interactive Entertainment
# NA_Sales                                          0.07
# EU_Sales                                          0.16
# JP_Sales                                           0.0
# Other_Sales                                       0.04
# Global_Sales                                      0.26
# Critic_Score                                      73.0
# Critic_Count                                      28.0
# Developer                  Rocksteady Studios, Virtuos
# User_Score                                         8.5
# User_Count                                        79.0
# Rating                                               T
# Name: 16685, dtype: object
#
# Index: 16686, Ligne complète:
# Name              Battlefield 1
# Index                     16784
# Platform                    NaN
# Year                     2016.0
# Genre                   Shooter
# Publisher       Electronic Arts
# NA_Sales                    1.1
# EU_Sales                   2.15
# JP_Sales                   0.21
# Other_Sales                0.61
# Global_Sales               4.08
# Critic_Score               88.0
# Critic_Count               31.0
# Developer               EA DICE
# User_Score                  8.4
# User_Count                809.0
# Rating                        M
# Name: 16686, dtype: object
#
# Index: 16687, Ligne complète:
# Name            BlazBlue Central Fiction
# Index                              16838
# Platform                             NaN
# Year                              2016.0
# Genre                           Fighting
# Publisher                          PQube
# NA_Sales                            0.04
# EU_Sales                             0.0
# JP_Sales                            0.03
# Other_Sales                         0.01
# Global_Sales                        0.08
# Critic_Score                        85.0
# Critic_Count                        21.0
# Developer               Arc System Works
# User_Score                           7.6
# User_Count                          39.0
# Rating                                 T
# Name: 16687, dtype: object
#
# Index: 16688, Ligne complète:
# Name            Call of Duty: Infinite Warfare
# Index                                    16918
# Platform                                   NaN
# Year                                    2016.0
# Genre                                  Shooter
# Publisher                           Activision
# NA_Sales                                  1.61
# EU_Sales                                   2.0
# JP_Sales                                  0.15
# Other_Sales                               0.71
# Global_Sales                              4.46
# Critic_Score                              77.0
# Critic_Count                              82.0
# Developer                        Infinity Ward
# User_Score                                 3.4
# User_Count                              1129.0
# Rating                                       M
# Name: 16688, dtype: object
#
# Index: 16689, Ligne complète:
# Name            Darksiders: Warmastered Edition
# Index                                     17045
# Platform                                    NaN
# Year                                     2016.0
# Genre                                    Action
# Publisher                          Nordic Games
# NA_Sales                                   0.02
# EU_Sales                                    0.0
# JP_Sales                                    0.0
# Other_Sales                                 0.0
# Global_Sales                               0.02
# Critic_Score                               79.0
# Critic_Count                                9.0
# Developer               Nordic Games Publishing
# User_Score                                  8.5
# User_Count                                 15.0
# Rating                                        M
# Name: 16689, dtype: object
#
# Index: 16690, Ligne complète:
# Name                  Dishonored 2
# Index                        17161
# Platform                       NaN
# Year                        2016.0
# Genre                       Action
# Publisher       Bethesda Softworks
# NA_Sales                      0.22
# EU_Sales                      0.32
# JP_Sales                       0.0
# Other_Sales                    0.1
# Global_Sales                  0.64
# Critic_Score                  88.0
# Critic_Count                  56.0
# Developer           Arkane Studios
# User_Score                     7.7
# User_Count                   569.0
# Rating                           M
# Name: 16690, dtype: object
#
# Index: 16691, Ligne complète:
# Name            Dragon Ball: Xenoverse 2
# Index                              17215
# Platform                             NaN
# Year                              2016.0
# Genre                             Action
# Publisher             Namco Bandai Games
# NA_Sales                            0.24
# EU_Sales                            0.27
# JP_Sales                            0.09
# Other_Sales                          0.1
# Global_Sales                        0.71
# Critic_Score                        73.0
# Critic_Count                        54.0
# Developer              Dimps Corporation
# User_Score                           7.8
# User_Count                         117.0
# Rating                                 T
# Name: 16691, dtype: object
#
# Index: 16692, Ligne complète:
# Name                           DriveClub VR
# Index                                 17246
# Platform                                NaN
# Year                                 2016.0
# Genre                                Racing
# Publisher       Sony Computer Entertainment
# NA_Sales                               0.03
# EU_Sales                               0.05
# JP_Sales                                0.0
# Other_Sales                            0.01
# Global_Sales                           0.09
# Critic_Score                           67.0
# Critic_Count                           34.0
# Developer                 Evolution Studios
# User_Score                              7.4
# User_Count                            110.0
# Rating                                    E
# Name: 16692, dtype: object
#
# Index: 16693, Ligne complète:
# Name            Duke Nukem 3D: 20th Anniversary World Tour
# Index                                                17253
# Platform                                               NaN
# Year                                                2016.0
# Genre                                              Shooter
# Publisher                                 Gearbox Software
# NA_Sales                                              0.03
# EU_Sales                                               0.0
# JP_Sales                                               0.0
# Other_Sales                                           0.01
# Global_Sales                                          0.03
# Critic_Score                                          77.0
# Critic_Count                                          15.0
# Developer                                 Gearbox Software
# User_Score                                             6.9
# User_Count                                            15.0
# Rating                                                   M
# Name: 16693, dtype: object
#
# Index: 16694, Ligne complète:
# Name               Dungeons 2
# Index                   17257
# Platform                  NaN
# Year                   2016.0
# Genre            Role-Playing
# Publisher       Kalypso Media
# NA_Sales                 0.01
# EU_Sales                  0.0
# JP_Sales                  0.0
# Other_Sales               0.0
# Global_Sales             0.01
# Critic_Score             61.0
# Critic_Count              9.0
# Developer             Kalypso
# User_Score                7.9
# User_Count               14.0
# Rating                      T
# Name: 16694, dtype: object
#
# Index: 16695, Ligne complète:
# Name                 Eagle Flight
# Index                       17279
# Platform                      NaN
# Year                       2016.0
# Genre                   Adventure
# Publisher                 Ubisoft
# NA_Sales                     0.01
# EU_Sales                     0.05
# JP_Sales                      0.0
# Other_Sales                  0.01
# Global_Sales                 0.07
# Critic_Score                 72.0
# Critic_Count                 31.0
# Developer       Ubisoft, FunHouse
# User_Score                    7.8
# User_Count                   22.0
# Rating                       E10+
# Name: 16695, dtype: object
#
# Index: 16696, Ligne complète:
# Name            EVE: Valkyrie
# Index                   17325
# Platform                  NaN
# Year                   2016.0
# Genre                 Shooter
# Publisher                 CCP
# NA_Sales                 0.03
# EU_Sales                 0.05
# JP_Sales                  0.0
# Other_Sales              0.02
# Global_Sales              0.1
# Critic_Score             73.0
# Critic_Count             26.0
# Developer                 CCP
# User_Score                6.3
# User_Count               37.0
# Rating                      T
# Name: 16696, dtype: object
#
# Index: 16697, Ligne complète:
# Name              Farming Simulator 17
# Index                            17397
# Platform                           NaN
# Year                            2016.0
# Genre                       Simulation
# Publisher       Focus Home Interactive
# NA_Sales                          0.03
# EU_Sales                          0.58
# JP_Sales                           0.0
# Other_Sales                       0.04
# Global_Sales                      0.65
# Critic_Score                      64.0
# Critic_Count                       5.0
# Developer              Giants Software
# User_Score                         8.0
# User_Count                        20.0
# Rating                               E
# Name: 16697, dtype: object
#
# Index: 16698, Ligne complète:
# Name            Fast Racing Neo
# Index                     17402
# Platform                    NaN
# Year                     2016.0
# Genre                    Action
# Publisher              Nintendo
# NA_Sales                    0.0
# EU_Sales                   0.01
# JP_Sales                    0.0
# Other_Sales                 0.0
# Global_Sales               0.01
# Critic_Score               81.0
# Critic_Count               46.0
# Developer               Shin'en
# User_Score                  8.5
# User_Count                151.0
# Rating                        E
# Name: 16698, dtype: object
#
# Index: 16699, Ligne complète:
# Name            Football Manager 2017
# Index                           17488
# Platform                          NaN
# Year                           2016.0
# Genre                      Simulation
# Publisher                        Sega
# NA_Sales                          0.0
# EU_Sales                         0.09
# JP_Sales                          0.0
# Other_Sales                      0.01
# Global_Sales                     0.09
# Critic_Score                     81.0
# Critic_Count                     41.0
# Developer          Sports Interactive
# User_Score                        4.3
# User_Count                       57.0
# Rating                              E
# Name: 16699, dtype: object
#
# Index: 16700, Ligne complète:
# Name                    Gears of War 4
# Index                            17525
# Platform                           NaN
# Year                            2016.0
# Genre                          Shooter
# Publisher       Microsoft Game Studios
# NA_Sales                          0.78
# EU_Sales                          0.44
# JP_Sales                           0.0
# Other_Sales                       0.12
# Global_Sales                      1.35
# Critic_Score                      84.0
# Critic_Count                      96.0
# Developer                The Coalition
# User_Score                         6.2
# User_Count                       815.0
# Rating                               M
# Name: 16700, dtype: object
#
# Index: 16701, Ligne complète:
# Name                          Here They Lie
# Index                                 17681
# Platform                                NaN
# Year                                 2016.0
# Genre                             Adventure
# Publisher       Sony Computer Entertainment
# NA_Sales                                0.0
# EU_Sales                               0.02
# JP_Sales                                0.0
# Other_Sales                             0.0
# Global_Sales                           0.02
# Critic_Score                           62.0
# Critic_Count                           31.0
# Developer                  The Tangentlemen
# User_Score                              6.5
# User_Count                             36.0
# Rating                                    M
# Name: 16701, dtype: object
#
# Index: 16702, Ligne complète:
# Name            Just Dance 2017
# Index                     17767
# Platform                    NaN
# Year                     2016.0
# Genre                      Misc
# Publisher               Ubisoft
# NA_Sales                   0.03
# EU_Sales                    0.0
# JP_Sales                    0.0
# Other_Sales                 0.0
# Global_Sales               0.04
# Critic_Score               75.0
# Critic_Count                5.0
# Developer         Ubisoft Paris
# User_Score                  8.0
# User_Count                  6.0
# Rating                     E10+
# Name: 16702, dtype: object
#
# Index: 16703, Ligne complète:
# Name                 Killing Floor 2
# Index                          17779
# Platform                         NaN
# Year                          2016.0
# Genre                        Shooter
# Publisher       Tripwire Interactive
# NA_Sales                        0.03
# EU_Sales                        0.01
# JP_Sales                         0.0
# Other_Sales                     0.01
# Global_Sales                    0.05
# Critic_Score                    76.0
# Critic_Count                    39.0
# Developer       Tripwire Interactive
# User_Score                       8.0
# User_Count                      57.0
# Rating                             M
# Name: 16703, dtype: object
#
# Index: 16704, Ligne complète:
# Name                      LEGO Harry Potter Collection
# Index                                            17856
# Platform                                           NaN
# Year                                            2016.0
# Genre                                           Action
# Publisher       Warner Bros. Interactive Entertainment
# NA_Sales                                          0.01
# EU_Sales                                          0.11
# JP_Sales                                           0.0
# Other_Sales                                       0.02
# Global_Sales                                      0.15
# Critic_Score                                      73.0
# Critic_Count                                      16.0
# Developer       Warner Bros. Interactive Entertainment
# User_Score                                         8.1
# User_Count                                         7.0
# Rating                                            E10+
# Name: 16704, dtype: object
#
# Index: 16705, Ligne complète:
# Name                       Mafia III
# Index                          17985
# Platform                         NaN
# Year                          2016.0
# Genre                         Action
# Publisher       Take-Two Interactive
# NA_Sales                        0.42
# EU_Sales                        1.08
# JP_Sales                        0.03
# Other_Sales                     0.28
# Global_Sales                    1.81
# Critic_Score                    68.0
# Critic_Count                    66.0
# Developer                  Hangar 13
# User_Score                       5.1
# User_Count                    1147.0
# Rating                             M
# Name: 16705, dtype: object
#
# Index: 16706, Ligne complète:
# Name            Mario Party: Star Rush
# Index                            18007
# Platform                           NaN
# Year                            2016.0
# Genre                             Misc
# Publisher                     Nintendo
# NA_Sales                          0.08
# EU_Sales                          0.13
# JP_Sales                          0.08
# Other_Sales                       0.02
# Global_Sales                       0.3
# Critic_Score                      68.0
# Critic_Count                      37.0
# Developer            Nintendo, Nd Cube
# User_Score                         6.8
# User_Count                        16.0
# Rating                               E
# Name: 16706, dtype: object
#
# Index: 16707, Ligne complète:
# Name            Mark McMorris Infinite Air
# Index                                18019
# Platform                               NaN
# Year                                2016.0
# Genre                               Sports
# Publisher                FuRyu Corporation
# NA_Sales                              0.01
# EU_Sales                               0.0
# JP_Sales                               0.0
# Other_Sales                            0.0
# Global_Sales                          0.02
# Critic_Score                          49.0
# Critic_Count                          15.0
# Developer            HB Studios Multimedia
# User_Score                             6.0
# User_Count                            29.0
# Rating                                   T
# Name: 16707, dtype: object
#
# Index: 16708, Ligne complète:
# Name                  MotoGP 14
# Index                      18160
# Platform                     NaN
# Year                      2014.0
# Genre                     Racing
# Publisher       Milestone S.r.l.
# NA_Sales                    0.04
# EU_Sales                    0.11
# JP_Sales                     0.0
# Other_Sales                 0.03
# Global_Sales                0.18
# Critic_Score                73.0
# Critic_Count                28.0
# Developer        Milestone S.r.l
# User_Score                   6.4
# User_Count                  26.0
# Rating                         E
# Name: 16708, dtype: object
#
# Index: 16709, Ligne complète:
# Name                Paper Mario: Color Splash
# Index                                   18388
# Platform                                  NaN
# Year                                   2016.0
# Genre                            Role-Playing
# Publisher                            Nintendo
# NA_Sales                                  0.2
# EU_Sales                                 0.14
# JP_Sales                                 0.05
# Other_Sales                              0.03
# Global_Sales                             0.42
# Critic_Score                             75.0
# Critic_Count                             72.0
# Developer       Nintendo, Intelligent Systems
# User_Score                                6.8
# User_Count                              208.0
# Rating                                      E
# Name: 16709, dtype: object
#
# Index: 16710, Ligne complète:
# Name                     PlayStation VR Worlds
# Index                                    18434
# Platform                                   NaN
# Year                                    2016.0
# Genre                                     Misc
# Publisher          Sony Computer Entertainment
# NA_Sales                                  0.06
# EU_Sales                                  0.14
# JP_Sales                                  0.02
# Other_Sales                               0.04
# Global_Sales                              0.25
# Critic_Score                              59.0
# Critic_Count                              48.0
# Developer       Sony Interactive Entertainment
# User_Score                                 7.1
# User_Count                                73.0
# Rating                                       M
# Name: 16710, dtype: object
#
# Index: 16711, Ligne complète:
# Name            Prototype: Biohazard Bundle
# Index                                 18492
# Platform                                NaN
# Year                                 2016.0
# Genre                                Action
# Publisher                        Activision
# NA_Sales                               0.01
# EU_Sales                                0.0
# JP_Sales                                0.0
# Other_Sales                             0.0
# Global_Sales                           0.02
# Critic_Score                           48.0
# Critic_Count                            4.0
# Developer             Radical Entertainment
# User_Score                              2.0
# User_Count                             53.0
# Rating                                    M
# Name: 16711, dtype: object
#
# Index: 16712, Ligne complète:
# Name                     Ride 2
# Index                     18594
# Platform                    NaN
# Year                     2016.0
# Genre                    Racing
# Publisher       Milestone S.r.l
# NA_Sales                    0.0
# EU_Sales                   0.04
# JP_Sales                    0.0
# Other_Sales                0.01
# Global_Sales               0.05
# Critic_Score               71.0
# Critic_Count               19.0
# Developer       Milestone S.r.l
# User_Score                  8.0
# User_Count                 12.0
# Rating                        E
# Name: 16712, dtype: object
#
# Index: 16713, Ligne complète:
# Name            RIGS: Mechanized Combat League
# Index                                    18604
# Platform                                   NaN
# Year                                    2016.0
# Genre                                   Action
# Publisher          Sony Computer Entertainment
# NA_Sales                                  0.03
# EU_Sales                                  0.05
# JP_Sales                                  0.01
# Other_Sales                               0.02
# Global_Sales                              0.11
# Critic_Score                              79.0
# Critic_Count                              42.0
# Developer                   Guerilla Cambridge
# User_Score                                 7.9
# User_Count                                76.0
# Rating                                       T
# Name: 16713, dtype: object
#
# Index: 16714, Ligne complète:
# Name            Robinson: The Journey
# Index                           18615
# Platform                          NaN
# Year                           2016.0
# Genre                          Action
# Publisher                      Crytek
# NA_Sales                         0.06
# EU_Sales                         0.03
# JP_Sales                          0.0
# Other_Sales                      0.02
# Global_Sales                     0.12
# Critic_Score                     65.0
# Critic_Count                     40.0
# Developer                      Crytek
# User_Score                        6.9
# User_Count                       62.0
# Rating                            NaN
# Name: 16714, dtype: object
#
# Index: 16715, Ligne complète:
# Name            Root Letter
# Index                 18638
# Platform                NaN
# Year                 2016.0
# Genre             Adventure
# Publisher             PQube
# NA_Sales                0.0
# EU_Sales               0.03
# JP_Sales               0.01
# Other_Sales            0.01
# Global_Sales           0.05
# Critic_Score           78.0
# Critic_Count            6.0
# Developer          Kadokawa
# User_Score              7.8
# User_Count              6.0
# Rating                    M
# Name: 16715, dtype: object
#
# Index: 16716, Ligne complète:
# Name            Sherlock Holmes: The Devil's Daughter
# Index                                           18707
# Platform                                          NaN
# Year                                           2016.0
# Genre                                       Adventure
# Publisher                          Bigben Interactive
# NA_Sales                                          0.0
# EU_Sales                                         0.01
# JP_Sales                                          0.0
# Other_Sales                                       0.0
# Global_Sales                                     0.01
# Critic_Score                                     65.0
# Critic_Count                                     18.0
# Developer                                   Frogwares
# User_Score                                        7.3
# User_Count                                       72.0
# Rating                                              T
# Name: 16716, dtype: object
#
# Index: 16717, Ligne complète:
# Name            Sid Meier's Civilization VI
# Index                                 18728
# Platform                                NaN
# Year                                 2016.0
# Genre                              Strategy
# Publisher              Take-Two Interactive
# NA_Sales                               0.09
# EU_Sales                               0.13
# JP_Sales                                0.0
# Other_Sales                            0.02
# Global_Sales                           0.25
# Critic_Score                           88.0
# Critic_Count                           81.0
# Developer                     Firaxis Games
# User_Score                              7.3
# User_Count                            684.0
# Rating                                 E10+
# Name: 16717, dtype: object
#
# Index: 16718, Ligne complète:
# Name            Skylanders Imaginators
# Index                            18770
# Platform                           NaN
# Year                            2016.0
# Genre                         Platform
# Publisher                   Activision
# NA_Sales                          0.04
# EU_Sales                          0.08
# JP_Sales                           0.0
# Other_Sales                       0.02
# Global_Sales                      0.14
# Critic_Score                      80.0
# Critic_Count                      47.0
# Developer                 Toys for Bob
# User_Score                         5.5
# User_Count                        17.0
# Rating                            E10+
# Name: 16718, dtype: object
#
# Index: 16719, Ligne complète:
# Name            Superdimension Neptune vs Sega Hard Girls
# Index                                               18930
# Platform                                              NaN
# Year                                               2016.0
# Genre                                        Role-Playing
# Publisher                      Idea Factory International
# NA_Sales                                              0.0
# EU_Sales                                             0.02
# JP_Sales                                              0.0
# Other_Sales                                          0.01
# Global_Sales                                         0.03
# Critic_Score                                         73.0
# Critic_Count                                         16.0
# Developer                                   Compile Heart
# User_Score                                            8.4
# User_Count                                           12.0
# Rating                                                  T
# Name: 16719, dtype: object
#
# Index: 16720, Ligne complète:
# Name            Super Dungeon Bros
# Index                        18931
# Platform                       NaN
# Year                        2016.0
# Genre                       Action
# Publisher             Nordic Games
# NA_Sales                      0.01
# EU_Sales                       0.0
# JP_Sales                       0.0
# Other_Sales                    0.0
# Global_Sales                  0.01
# Critic_Score                  42.0
# Critic_Count                   9.0
# Developer              React Games
# User_Score                     2.3
# User_Count                     7.0
# Rating                        E10+
# Name: 16720, dtype: object
#
# Index: 16721, Ligne complète:
# Name                   Super Stardust Ultra VR
# Index                                    18945
# Platform                                   NaN
# Year                                    2016.0
# Genre                                  Shooter
# Publisher          Sony Computer Entertainment
# NA_Sales                                   0.0
# EU_Sales                                  0.01
# JP_Sales                                   0.0
# Other_Sales                                0.0
# Global_Sales                              0.01
# Critic_Score                              66.0
# Critic_Count                              13.0
# Developer       Sony Interactive Entertainment
# User_Score                                 6.2
# User_Count                                13.0
# Rating                                    E10+
# Name: 16721, dtype: object
#
# Index: 16722, Ligne complète:
# Name            Sword Art Online: Hollow Realization
# Index                                          18953
# Platform                                         NaN
# Year                                          2016.0
# Genre                                   Role-Playing
# Publisher                         Namco Bandai Games
# NA_Sales                                        0.06
# EU_Sales                                        0.02
# JP_Sales                                         0.1
# Other_Sales                                     0.02
# Global_Sales                                    0.19
# Critic_Score                                    69.0
# Critic_Count                                    32.0
# Developer                         Bandai Namco Games
# User_Score                                       7.7
# User_Count                                      52.0
# Rating                                             T
# Name: 16722, dtype: object
#
# Index: 16723, Ligne complète:
# Name            The Sims 4: City Living
# Index                             19122
# Platform                            NaN
# Year                             2016.0
# Genre                        Simulation
# Publisher               Electronic Arts
# NA_Sales                           0.02
# EU_Sales                           0.08
# JP_Sales                            0.0
# Other_Sales                        0.01
# Global_Sales                        0.1
# Critic_Score                       77.0
# Critic_Count                       10.0
# Developer                         Maxis
# User_Score                          5.7
# User_Count                         30.0
# Rating                                T
# Name: 16723, dtype: object
#
# Index: 16724, Ligne complète:
# Name                      Titanfall 2
# Index                           19174
# Platform                          NaN
# Year                           2016.0
# Genre                         Shooter
# Publisher             Electronic Arts
# NA_Sales                         0.34
# EU_Sales                         0.25
# JP_Sales                         0.05
# Other_Sales                      0.12
# Global_Sales                     0.75
# Critic_Score                     89.0
# Critic_Count                     56.0
# Developer       Respawn Entertainment
# User_Score                        8.4
# User_Count                      704.0
# Rating                              M
# Name: 16724, dtype: object
#
# Index: 16725, Ligne complète:
# Name            Transport Fever
# Index                     19265
# Platform                    NaN
# Year                     2016.0
# Genre                Simulation
# Publisher              Astragon
# NA_Sales                    0.0
# EU_Sales                   0.03
# JP_Sales                    0.0
# Other_Sales                 0.0
# Global_Sales               0.04
# Critic_Score               70.0
# Critic_Count               11.0
# Developer           Urban Games
# User_Score                  7.0
# User_Count                 28.0
# Rating                      NaN
# Name: 16725, dtype: object
#
# Index: 16726, Ligne complète:
# Name              Until Dawn: Rush of Blood
# Index                                 19313
# Platform                                NaN
# Year                                 2016.0
# Genre                             Adventure
# Publisher       Sony Computer Entertainment
# NA_Sales                               0.18
# EU_Sales                               0.15
# JP_Sales                                0.0
# Other_Sales                            0.07
# Global_Sales                           0.39
# Critic_Score                           72.0
# Critic_Count                           49.0
# Developer                SuperMassive Games
# User_Score                              8.0
# User_Count                             68.0
# Rating                                    M
# Name: 16726, dtype: object
#
# Index: 16727, Ligne complète:
# Name                Watch Dogs 2
# Index                      19362
# Platform                     NaN
# Year                      2016.0
# Genre                     Action
# Publisher                Ubisoft
# NA_Sales                    0.37
# EU_Sales                    0.58
# JP_Sales                     0.0
# Other_Sales                 0.18
# Global_Sales                1.13
# Critic_Score                83.0
# Critic_Count                88.0
# Developer       Ubisoft Montreal
# User_Score                   7.8
# User_Count                 621.0
# Rating                         M
# Name: 16727, dtype: object
#
# Index: 16728, Ligne complète:
# Name            World of Final Fantasy
# Index                            19395
# Platform                           NaN
# Year                            2016.0
# Genre                     Role-Playing
# Publisher                  Square Enix
# NA_Sales                          0.08
# EU_Sales                          0.14
# JP_Sales                          0.08
# Other_Sales                       0.04
# Global_Sales                      0.33
# Critic_Score                      77.0
# Critic_Count                      74.0
# Developer                  Square Enix
# User_Score                         8.3
# User_Count                       222.0
# Rating                            E10+
# Name: 16728, dtype: object
#
# Index: 16729, Ligne complète:
# Name                        WWE 2K17
# Index                          19423
# Platform                         NaN
# Year                          2016.0
# Genre                         Sports
# Publisher       Take-Two Interactive
# NA_Sales                        0.17
# EU_Sales                        0.34
# JP_Sales                         0.0
# Other_Sales                     0.09
# Global_Sales                     0.6
# Critic_Score                    69.0
# Critic_Count                    50.0
# Developer                     Yuke's
# User_Score                       6.9
# User_Count                      88.0
# Rating                             T
# Name: 16729, dtype: object

# %%
# Remplacement des valeurs manquantes par les valeurs réelles trouvées sur VGChartz

df.at[16682, 'Platform'] = 'XOne',
df.at[16683, 'Platform'] = '3DS',
df.at[16684, 'Platform'] = 'PS4',
df.at[16685, 'Platform'] = 'XOne',
df.at[16686, 'Platform'] = 'PS4',
df.at[16687, 'Platform'] = 'PS4',
df.at[16688, 'Platform'] = 'PS4',
df.at[16689, 'Platform'] = 'PS4',
df.at[16690, 'Platform'] = 'PS4',
df.at[16691, 'Platform'] = 'PS4',
df.at[16692, 'Platform'] = 'PS4',
df.at[16693, 'Platform'] = 'XOne',
df.at[16694, 'Platform'] = 'PS4',
df.at[16695, 'Platform'] = 'PS4',
df.at[16696, 'Platform'] = 'PS4',
df.at[16697, 'Platform'] = 'PS4',
df.at[16698, 'Platform'] = 'WiiU',
df.at[16699, 'Platform'] = 'PC',
df.at[16700, 'Platform'] = 'XOne',
df.at[16701, 'Platform'] = 'PS4',
df.at[16702, 'Platform'] = 'PS4',
df.at[16703, 'Platform'] = 'PS4',
df.at[16704, 'Platform'] = 'PS4',
df.at[16705, 'Platform'] = 'PS4',
df.at[16706, 'Platform'] = '3DS',
df.at[16707, 'Platform'] = 'PS4',
df.at[16708, 'Platform'] = 'PS4',
df.at[16709, 'Platform'] = 'WiiU',
df.at[16710, 'Platform'] = 'PS4',
df.at[16711, 'Platform'] = 'XOne',
df.at[16712, 'Platform'] = 'XOne',
df.at[16713, 'Platform'] = 'PS4',
df.at[16714, 'Platform'] = 'PS4',
df.at[16715, 'Platform'] = 'PSV',
df.at[16716, 'Platform'] = 'PC',
df.at[16717, 'Platform'] = 'PC',
df.at[16718, 'Platform'] = 'WiiU',
df.at[16719, 'Platform'] = 'PSV',
df.at[16720, 'Platform'] = 'PC',
df.at[16721, 'Platform'] = 'PS4',
df.at[16722, 'Platform'] = 'PS4',
df.at[16723, 'Platform'] = 'PC',
df.at[16724, 'Platform'] = 'PS4',
df.at[16725, 'Platform'] = 'PC',
df.at[16726, 'Platform'] = 'PS4',
df.at[16727, 'Platform'] = 'PS4',
df.at[16728, 'Platform'] = 'PS4',
df.at[16729, 'Platform'] = 'PS4',

# %%
df.isna().sum()
# Out:
# Name               0
# Index              0
# Platform           0
# Year               0
# Genre              0
# Publisher         54
# NA_Sales           0
# EU_Sales           0
# JP_Sales           0
# Other_Sales        0
# Global_Sales       0
# Critic_Score       0
# Critic_Count       0
# Developer       5905
# User_Score         0
# User_Count         0
# Rating          6042
# dtype: int64

# %% [markdown]
# ## Valeurs manquantes dans "Publisher"

# %%
# Dictionnaire des "Publisher" manquants de chaque jeu

publisher_dict = {
    'Triple Play 99': "Electronic Arts",
    'Shrek / Shrek 2 2-in-1 Gameboy Advance Video': "Majesco",
    "Bentley's Hackpack": "Sony Computer Entertainment",
    'Nicktoons Collection: Game Boy Advance Video Volume 1': "Majesco",
    'SpongeBob SquarePants: Game Boy Advance Video Volume 1': "Majesco",
    'SpongeBob SquarePants: Game Boy Advance Video Volume 2': "Majesco",
    'The Fairly Odd Parents: Game Boy Advance Video Volume 1': "Majesco",
    'The Fairly Odd Parents: Game Boy Advance Video Volume 2': "Majesco",
    'Cartoon Network Collection: Game Boy Advance Video Platinum Edition': "Majesco",
    'The Legend of Zelda: The Minish Cap(weekly JP sales)': "Nintendo",
    'Sonic X: Game Boy Advance Video Volume 1': "Majesco",
    'Dora the Explorer: Game Boy Advance Video Volume 1': "Majesco",
    'Cartoon Network Collection: Game Boy Advance Video Volume 1': "Majesco",
    'All Grown Up!: Game Boy Advance Video Volume 1': "Majesco",
    'Nicktoons Collection: Game Boy Advance Video Volume 2': "Majesco",
    'Yu Yu Hakusho: Dark Tournament': "Atari",
    'SpongeBob SquarePants: Game Boy Advance Video Volume 3': "Majesco",
    'Thomas the Tank Engine & Friends': "THQ",
    'Dragon Ball GT: Game Boy Advance Video Volume 1': "Majesco",
    'Codename: Kids Next Door: Game Boy Advance Video Volume 1': "Majesco",
    'Teenage Mutant Ninja Turtles: Game Boy Advance Video Volume 1': "Majesco",
    'Stronghold 3': "SouthPeak Interactive",
    'Cartoon Network Collection: Game Boy Advance Video Special Edition': "Majesco",
    'Pokémon: Johto Photo Finish: Game Boy Advance Video': "Majesco",
    'Strawberry Shortcake: Game Boy Advance Video Volume 1': "Majesco",
    'Farming Simulator 2011': "Focus Home Interactive",
    'Super Robot Wars OG Saga: Masou Kishin II - Revelation of Evil God': "Namco Bandai Games",
    'Disney Channel Collection Vol. 1': "Majesco",
    'Cartoon Network Collection: Game Boy Advance Video Volume 2': "Majesco",
    'Silverlicious': "GameMill",
    'UK Truck Simulator': "Excalibur Publishing",
    'Xia-Xia': "GameMill",
    'Nicktoons Collection: Game Boy Advance Video Volume 3': "Majesco",
    'Demolition Company: Gold Edition': "Giants Software",
    'Moshi, Kono Sekai ni Kami-sama ga Iru to suru Naraba.': "Rejet",
    'Super Robot Monkey Team: Game Boy Advance Video Volume 1': "Majesco",
    'Dance with Devils': "Rejet",
    "Legends of Oz: Dorothy's Return": "GameMill",
    'Driving Simulator 2011': "Excalibur Publishing",
    "Atsumare! Power Pro Kun no DS Koushien": "Konami",
    "Action Man-Operation Extreme": "Hasnro Interactive",
    "Chou Soujuu Mecha MG": "Nintendo",
    "Prinny: Can I Really Be The Hero? (US sales)": "NIS America",
    "Monster Hunter Frontier Online": "Capcom",
    "B.L.U.E.: Legend of Water": "Hudson Soft",
    "World of Tanks": "Wargaming.net",
    "Housekeeping": "IE Institute",
    "Bikkuriman Daijiten": "3 O'Clock",
    "Umineko no Naku Koro ni San: Shinjitsu to Gensou no Yasoukyoku": "Alchemist",
    "Mario Tennis": "Nintendo",
    "Dream Dancer": "Zoo Games",
    "Homeworld Remastered Collection": "Gearbox Software",
    "AKB1/48: Idol to Guam de Koishitara...": "Namco Bandai Games",
    "Brothers in Arms: Furious 4": "Ubisoft"



}
# Fonction pour remplir les "Publisher" manquantes automatiquement

def fill_publisher(row):
    if pd.isna(row['Publisher']):
        return publisher_dict.get(row['Name'], row['Publisher'])
    return row['Publisher']

# Application du remplissage

df['Publisher'] = df.apply(fill_publisher, axis=1)

# Vérification les premières lignes du DataFrame après remplissage

# %%
df.iloc[16392]["Name"]
# Out:
# 'AKB1/48: Idol to Guam de Koishitara...'

# %%
# Identifier les valeurs manquantes dans la colonne Publisher

publisher_manquantes = df[df["Publisher"].isna()]
colonne_publisher = "Publisher"

# Boucle pour afficher les lignes contenant des valeurs manquantes

for index, row in publisher_manquantes.iterrows():
    print(f"Index: {index}, Ligne complète: \n{row}\n")

# %%
df.isna().sum()
# Out:
# Name               0
# Index              0
# Platform           0
# Year               0
# Genre              0
# Publisher          0
# NA_Sales           0
# EU_Sales           0
# JP_Sales           0
# Other_Sales        0
# Global_Sales       0
# Critic_Score       0
# Critic_Count       0
# Developer       5905
# User_Score         0
# User_Count         0
# Rating          6042
# dtype: int64
