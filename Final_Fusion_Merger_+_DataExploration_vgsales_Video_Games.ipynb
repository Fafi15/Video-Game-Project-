# %%
import pandas as pd
import numpy as np

# Jeu de données videogames trouvé sur le site Data World
# URL : https://data.world/sumitrock/videogames

# Import du jeu de données

videogames = pd.read_csv("Video_Games.csv")
videogames.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 1           NaN        NaN         NaN       NaN    NaN
# 2          73.0        8.3       709.0  Nintendo      E
# 3          73.0          8       192.0  Nintendo      E
# 4           NaN        NaN         NaN       NaN    NaN

# %%
videogames.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       10015 non-null  object
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# dtypes: float64(9), object(7)
# memory usage: 2.0+ MB

# %%
videogames.describe()
# Out:
#        Year_of_Release      NA_Sales      EU_Sales      JP_Sales  \
# count     16450.000000  16719.000000  16719.000000  16719.000000
# mean       2006.487356      0.263330      0.145025      0.077602
# std           5.878995      0.813514      0.503283      0.308818
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2020.000000     41.360000     28.960000     10.220000
#
#         Other_Sales  Global_Sales  Critic_Score  Critic_Count    User_Count
# count  16719.000000  16719.000000   8137.000000   8137.000000   7590.000000
# mean       0.047332      0.533543     68.967679     26.360821    162.229908
# std        0.186710      1.547935     13.938165     18.980495    561.282326
# min        0.000000      0.010000     13.000000      3.000000      4.000000
# 25%        0.000000      0.060000     60.000000     12.000000     10.000000
# 50%        0.010000      0.170000     71.000000     21.000000     24.000000
# 75%        0.030000      0.470000     79.000000     36.000000     81.000000
# max       10.570000     82.530000     98.000000    113.000000  10665.000000

# %%
# Nombre de valeurs manquantes

videogames.isna().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         6704
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %%
# Renommer colonne Year_of_Release en Year

videogames = videogames.rename(columns={'Year_of_Release': 'Year'})

print(videogames["Year"])
# Out:
# 0        2006.0
# 1        1985.0
# 2        2008.0
# 3        2009.0
# 4        1996.0
#           ...
# 16714    2016.0
# 16715    2006.0
# 16716    2016.0
# 16717    2003.0
# 16718    2016.0
# Name: Year, Length: 16719, dtype: float64

# %% [markdown]
# # Fusion de videogames avec vgsales

# %%
# Jeu de données d'origine, issu de Kaggle

# Import du jeu de données vgsales

vgsales = pd.read_csv("vgsales.csv")

vgsales.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
vgsales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
# Sélection des colonnes de videogames à fusionner

columnsfusion = ["Critic_Score", "Critic_Count", "User_Score", "User_Count", "Developer", "Rating", "Name"]
dfusion = videogames[columnsfusion]

# Fusion des colonnes videogames avec vgsales avec comme clé commune Name
# Merge nommé df1

df1 = pd.merge(vgsales, dfusion, on='Name', how='left')

df1.head()
# Out:
#    Rank               Name Platform    Year     Genre Publisher  NA_Sales  \
# 0     1         Wii Sports      Wii  2006.0    Sports  Nintendo     41.49
# 1     2  Super Mario Bros.      NES  1985.0  Platform  Nintendo     29.08
# 2     2  Super Mario Bros.      NES  1985.0  Platform  Nintendo     29.08
# 3     3     Mario Kart Wii      Wii  2008.0    Racing  Nintendo     15.85
# 4     4  Wii Sports Resort      Wii  2009.0    Sports  Nintendo     15.75
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  Critic_Count  \
# 0     29.02      3.77         8.46         82.74          76.0          51.0
# 1      3.58      6.81         0.77         40.24           NaN           NaN
# 2      3.58      6.81         0.77         40.24           NaN           NaN
# 3     12.88      3.79         3.31         35.82          82.0          73.0
# 4     11.01      3.28         2.96         33.00          80.0          73.0
#
#   User_Score  User_Count Developer Rating
# 0          8       322.0  Nintendo      E
# 1        NaN         NaN       NaN    NaN
# 2        NaN         NaN       NaN    NaN
# 3        8.3       709.0  Nintendo      E
# 4          8       192.0  Nintendo      E

# %%
print(df1.isna().sum())
print("--------------------------------")
print("Nombre de doublons est de", df1.duplicated().sum())
print("--------------------------------")
print(df1.info())
# Out:
# Rank                0
# Name                0
# Platform            0
# Year              635
# Genre               0
# Publisher          68
# NA_Sales            0
# EU_Sales            0
# JP_Sales            0
# Other_Sales         0
# Global_Sales        0
# Critic_Score    14762
# Critic_Count    14762
# User_Score      10147
# User_Count      15286
# Developer       10004
# Rating          10261
# dtype: int64
# --------------------------------
# Nombre de doublons est de 3391
# --------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35186 entries, 0 to 35185
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          35186 non-null  int64
#  1   Name          35186 non-null  object
#  2   Platform      35186 non-null  object
#  3   Year          34551 non-null  float64
#  4   Genre         35186 non-null  object
#  5   Publisher     35118 non-null  object
#  6   NA_Sales      35186 non-null  float64
#  7   EU_Sales      35186 non-null  float64
#  8   JP_Sales      35186 non-null  float64
#  9   Other_Sales   35186 non-null  float64
#  10  Global_Sales  35186 non-null  float64
#  11  Critic_Score  20424 non-null  float64
#  12  Critic_Count  20424 non-null  float64
#  13  User_Score    25039 non-null  object
#  14  User_Count    19900 non-null  float64
#  15  Developer     25182 non-null  object
#  16  Rating        24925 non-null  object
# dtypes: float64(9), int64(1), object(7)
# memory usage: 4.6+ MB
# None

# %%
doublons = df1[df1.duplicated(keep=False)]

# Identifier les doublons sur toutes les colonnes du merge "df1"

doublons = df1.duplicated(subset=["Name",	"Platform", "Year",	"Genre", "Publisher",	"NA_Sales",	"EU_Sales",	"JP_Sales",	"Other_Sales", "Global_Sales"])

# Éliminer les doublons en gardant la première occurrence

###################### Merge sans doublons nommé "dfvg" !

dfvg = df1[~doublons]

# Vérification

print(dfvg.isna().sum())
print("--------------------------------")
print("Nombre de doublons est de", dfvg.duplicated().sum())
# Out:
# Rank               0
# Name               0
# Platform           0
# Year             270
# Genre              0
# Publisher         58
# NA_Sales           0
# EU_Sales           0
# JP_Sales           0
# Other_Sales        0
# Global_Sales       0
# Critic_Score    8267
# Critic_Count    8267
# User_Score      6630
# User_Count      8766
# Developer       6562
# Rating          6693
# dtype: int64
# --------------------------------
# Nombre de doublons est de 0

# %%
dfvg.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 3     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 4     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 5     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.49     29.02      3.77         8.46         82.74          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 3     15.85     12.88      3.79         3.31         35.82          82.0
# 4     15.75     11.01      3.28         2.96         33.00          80.0
# 5     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 1           NaN        NaN         NaN       NaN    NaN
# 3          73.0        8.3       709.0  Nintendo      E
# 4          73.0          8       192.0  Nintendo      E
# 5           NaN        NaN         NaN       NaN    NaN

# %%
dfvg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16597 entries, 0 to 35184
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16597 non-null  int64
#  1   Name          16597 non-null  object
#  2   Platform      16597 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16597 non-null  object
#  5   Publisher     16539 non-null  object
#  6   NA_Sales      16597 non-null  float64
#  7   EU_Sales      16597 non-null  float64
#  8   JP_Sales      16597 non-null  float64
#  9   Other_Sales   16597 non-null  float64
#  10  Global_Sales  16597 non-null  float64
#  11  Critic_Score  8330 non-null   float64
#  12  Critic_Count  8330 non-null   float64
#  13  User_Score    9967 non-null   object
#  14  User_Count    7831 non-null   float64
#  15  Developer     10035 non-null  object
#  16  Rating        9904 non-null   object
# dtypes: float64(9), int64(1), object(7)
# memory usage: 2.3+ MB

# %%
# Identifier les valeurs manquantes dans la colonne Year

valeurs_manquantes = dfvg[dfvg["Year"].isna()]
colonne = "Year"

# Boucle pour afficher les lignes contenant des valeurs manquantes

for index, row in valeurs_manquantes.iterrows():
    print(f"Index: {index}, Ligne complète: \n{row}\n")
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# Index: 5031, Ligne complète:
# Rank                                   1992
# Name            Legacy of Kain: Soul Reaver
# Platform                                 PS
# Year                                    NaN
# Genre                                Action
# Publisher                 Eidos Interactive
# NA_Sales                               0.58
# EU_Sales                                0.4
# JP_Sales                                0.0
# Other_Sales                            0.07
# Global_Sales                           1.04
# Critic_Score                           91.0
# Critic_Count                           17.0
# User_Score                                9
# User_Count                            132.0
# Developer                  Crystal Dynamics
# Rating                                    T
# Name: 5031, dtype: object
#
# Index: 5115, Ligne complète:
# Rank                            2021
# Name            Donkey Kong Land III
# Platform                          GB
# Year                             NaN
# Genre                       Platform
# Publisher                   Nintendo
# NA_Sales                        0.68
# EU_Sales                        0.31
# JP_Sales                         0.0
# Other_Sales                     0.04
# Global_Sales                    1.03
# Critic_Score                     NaN
# Critic_Count                     NaN
# User_Score                       NaN
# User_Count                       NaN
# Developer                        NaN
# Rating                           NaN
# Name: 5115, dtype: object
#
# Index: 5292, Ligne complète:
# Rank                                              2088
# Name                      LEGO Harry Potter: Years 5-7
# Platform                                          X360
# Year                                               NaN
# Genre                                           Action
# Publisher       Warner Bros. Interactive Entertainment
# NA_Sales                                          0.51
# EU_Sales                                          0.39
# JP_Sales                                           0.0
# Other_Sales                                       0.09
# Global_Sales                                      0.99
# Critic_Score                                      76.0
# Critic_Count                                       8.0
# User_Score                                         7.8
# User_Count                                        13.0
# Developer                            Traveller's Tales
# Rating                                            E10+
# Name: 5292, dtype: object
#
# Index: 5390, Ligne complète:
# Rank                      2115
# Name            Air-Sea Battle
# Platform                  2600
# Year                       NaN
# Genre                  Shooter
# Publisher                Atari
# NA_Sales                  0.91
# EU_Sales                  0.06
# JP_Sales                   0.0
# Other_Sales               0.01
# Global_Sales              0.98
# Critic_Score               NaN
# Critic_Count               NaN
# User_Score                 NaN
# User_Count                 NaN
# Developer                  NaN
# Rating                     NaN
# Name: 5390, dtype: object
#
# Index: 5391, Ligne complète:
# Rank                    2116
# Name            Suikoden III
# Platform                 PS2
# Year                     NaN
# Genre           Role-Playing
# Publisher            Unknown
# NA_Sales                0.29
# EU_Sales                0.23
# JP_Sales                0.38
# Other_Sales             0.08
# Global_Sales            0.98
# Critic_Score            86.0
# Critic_Count            23.0
# User_Score               7.7
# User_Count             113.0
# Developer               KCET
# Rating                     T
# Name: 5391, dtype: object
#
# Index: 5457, Ligne complète:
# Rank                             2136
# Name                         Yakuza 4
# Platform                          PS3
# Year                              NaN
# Genre                          Action
# Publisher                        Sega
# NA_Sales                         0.15
# EU_Sales                         0.14
# JP_Sales                         0.63
# Other_Sales                      0.05
# Global_Sales                     0.97
# Critic_Score                     78.0
# Critic_Count                     59.0
# User_Score                          8
# User_Count                      177.0
# Developer       Ryu ga Gotoku Studios
# Rating                              M
# Name: 5457, dtype: object
#
# Index: 5496, Ligne complète:
# Rank                                              2147
# Name                      LEGO Harry Potter: Years 5-7
# Platform                                           PS3
# Year                                               NaN
# Genre                                           Action
# Publisher       Warner Bros. Interactive Entertainment
# NA_Sales                                          0.36
# EU_Sales                                          0.45
# JP_Sales                                           0.0
# Other_Sales                                       0.16
# Global_Sales                                      0.97
# Critic_Score                                      76.0
# Critic_Count                                       8.0
# User_Score                                         7.8
# User_Count                                        13.0
# Developer                            Traveller's Tales
# Rating                                            E10+
# Name: 5496, dtype: object
#
# Index: 5572, Ligne complète:
# Rank                        2175
# Name            Wheel of Fortune
# Platform                     PS2
# Year                         NaN
# Genre                       Misc
# Publisher                Unknown
# NA_Sales                    0.47
# EU_Sales                    0.36
# JP_Sales                     0.0
# Other_Sales                 0.12
# Global_Sales                0.95
# Critic_Score                 NaN
# Critic_Count                 NaN
# User_Score                   NaN
# User_Count                   NaN
# Developer                    NaN
# Rating                       NaN
# Name: 5572, dtype: object
#
# Index: 5894, Ligne complète:
# Rank                    2288
# Name            Namco Museum
# Platform                  XB
# Year                     NaN
# Genre                   Misc
# Publisher            Unknown
# NA_Sales                0.77
# EU_Sales                0.11
# JP_Sales                 0.0
# Other_Sales             0.04
# Global_Sales            0.91
# Critic_Score            79.0
# Critic_Count            10.0
# User_Score               7.3
# User_Count               6.0
# Developer         Mass Media
# Rating                     E
# Name: 5894, dtype: object
#
# Index: 5928, Ligne complète:
# Rank                     2297
# Name            Rhythm Heaven
# Platform                  Wii
# Year                      NaN
# Genre                    Misc
# Publisher             Unknown
# NA_Sales                 0.13
# EU_Sales                  0.0
# JP_Sales                 0.77
# Other_Sales              0.01
# Global_Sales              0.9
# Critic_Score             83.0
# Critic_Count             48.0
# User_Score                  9
# User_Count               63.0
# Developer            Nintendo
# Rating                      E
# Name: 5928, dtype: object
#
# Index: 6222, Ligne complète:
# Rank                                               2417
# Name            The Lord of the Rings: War in the North
# Platform                                            PS3
# Year                                                NaN
# Genre                                            Action
# Publisher        Warner Bros. Interactive Entertainment
# NA_Sales                                           0.25
# EU_Sales                                           0.45
# JP_Sales                                           0.01
# Other_Sales                                        0.15
# Global_Sales                                       0.86
# Critic_Score                                       61.0
# Critic_Count                                       48.0
# User_Score                                          7.4
# User_Count                                        113.0
# Developer                             Snowblind Studios
# Rating                                                M
# Name: 6222, dtype: object
#
# Index: 6235, Ligne complète:
# Rank                                               2424
# Name            The Lord of the Rings: War in the North
# Platform                                           X360
# Year                                                NaN
# Genre                                            Action
# Publisher        Warner Bros. Interactive Entertainment
# NA_Sales                                           0.52
# EU_Sales                                           0.26
# JP_Sales                                            0.0
# Other_Sales                                        0.08
# Global_Sales                                       0.86
# Critic_Score                                       61.0
# Critic_Count                                       48.0
# User_Score                                          7.4
# User_Count                                        113.0
# Developer                             Snowblind Studios
# Rating                                                M
# Name: 6235, dtype: object
#
# Index: 6408, Ligne complète:
# Rank                     2486
# Name            Madden NFL 07
# Platform                  PSP
# Year                      NaN
# Genre                  Sports
# Publisher             Unknown
# NA_Sales                 0.77
# EU_Sales                 0.03
# JP_Sales                  0.0
# Other_Sales              0.04
# Global_Sales             0.83
# Critic_Score             84.0
# Critic_Count             29.0
# User_Score                8.2
# User_Count               39.0
# Developer           EA Sports
# Rating                      E
# Name: 6408, dtype: object
#
# Index: 6436, Ligne complète:
# Rank                          2499
# Name            MLB SlugFest 20-03
# Platform                       PS2
# Year                           NaN
# Genre                       Sports
# Publisher                  Unknown
# NA_Sales                      0.41
# EU_Sales                      0.32
# JP_Sales                       0.0
# Other_Sales                   0.11
# Global_Sales                  0.83
# Critic_Score                  77.0
# Critic_Count                  25.0
# User_Score                     8.2
# User_Count                     6.0
# Developer                   Midway
# Rating                           E
# Name: 6436, dtype: object
#
# Index: 6517, Ligne complète:
# Rank                                2530
# Name            Shaun White Snowboarding
# Platform                            X360
# Year                                 NaN
# Genre                             Sports
# Publisher                        Ubisoft
# NA_Sales                            0.48
# EU_Sales                            0.26
# JP_Sales                             0.0
# Other_Sales                         0.08
# Global_Sales                        0.82
# Critic_Score                        60.0
# Critic_Count                        48.0
# User_Score                           7.6
# User_Count                          25.0
# Developer               Ubisoft Montreal
# Rating                                 T
# Name: 6517, dtype: object
#
# Index: 6671, Ligne complète:
# Rank                                      2588
# Name            PES 2009: Pro Evolution Soccer
# Platform                                   PSP
# Year                                       NaN
# Genre                                   Sports
# Publisher         Konami Digital Entertainment
# NA_Sales                                  0.04
# EU_Sales                                  0.33
# JP_Sales                                  0.26
# Other_Sales                               0.17
# Global_Sales                               0.8
# Critic_Score                               NaN
# Critic_Count                               NaN
# User_Score                                 NaN
# User_Count                                 NaN
# Developer                                  NaN
# Rating                                     NaN
# Name: 6671, dtype: object
#
# Index: 7180, Ligne complète:
# Rank                     2778
# Name            Madden NFL 11
# Platform                  Wii
# Year                      NaN
# Genre                  Sports
# Publisher             Unknown
# NA_Sales                  0.7
# EU_Sales                  0.0
# JP_Sales                  0.0
# Other_Sales              0.05
# Global_Sales             0.74
# Critic_Score             84.0
# Critic_Count             47.0
# User_Score                5.7
# User_Count              120.0
# Developer          EA Tiburon
# Rating                      E
# Name: 7180, dtype: object
#
# Index: 7204, Ligne complète:
# Rank                           2788
# Name            WarioWare: Twisted!
# Platform                        GBA
# Year                            NaN
# Genre                        Puzzle
# Publisher                   Unknown
# NA_Sales                       0.16
# EU_Sales                       0.06
# JP_Sales                        0.5
# Other_Sales                    0.02
# Global_Sales                   0.74
# Critic_Score                    NaN
# Critic_Count                    NaN
# User_Score                      NaN
# User_Count                      NaN
# Developer                       NaN
# Rating                          NaN
# Name: 7204, dtype: object
#
# Index: 7345, Ligne complète:
# Rank                                              2840
# Name                      LEGO Harry Potter: Years 5-7
# Platform                                            DS
# Year                                               NaN
# Genre                                           Action
# Publisher       Warner Bros. Interactive Entertainment
# NA_Sales                                          0.35
# EU_Sales                                           0.3
# JP_Sales                                           0.0
# Other_Sales                                       0.07
# Global_Sales                                      0.72
# Critic_Score                                      76.0
# Critic_Count                                       8.0
# User_Score                                         7.8
# User_Count                                        13.0
# Developer                            Traveller's Tales
# Rating                                            E10+
# Name: 7345, dtype: object
#
# Index: 7638, Ligne complète:
# Rank                              2949
# Name            Test Drive Unlimited 2
# Platform                          X360
# Year                               NaN
# Genre                           Racing
# Publisher                        Atari
# NA_Sales                           0.3
# EU_Sales                          0.32
# JP_Sales                           0.0
# Other_Sales                       0.07
# Global_Sales                      0.69
# Critic_Score                      68.0
# Critic_Count                      61.0
# User_Score                         6.4
# User_Count                        87.0
# Developer                         Eden
# Rating                               T
# Name: 7638, dtype: object
#
# Index: 7903, Ligne complète:
# Rank                                                         3051
# Name            The Chronicles of Narnia: The Lion, The Witch ...
# Platform                                                      GBA
# Year                                                          NaN
# Genre                                                      Action
# Publisher                              Disney Interactive Studios
# NA_Sales                                                     0.48
# EU_Sales                                                     0.18
# JP_Sales                                                      0.0
# Other_Sales                                                  0.01
# Global_Sales                                                 0.67
# Critic_Score                                                 66.0
# Critic_Count                                                  7.0
# User_Score                                                    6.8
# User_Count                                                    5.0
# Developer                                     Amaze Entertainment
# Rating                                                          E
# Name: 7903, dtype: object
#
# Index: 8154, Ligne complète:
# Rank                              3143
# Name            Test Drive Unlimited 2
# Platform                           PS3
# Year                               NaN
# Genre                           Racing
# Publisher                        Atari
# NA_Sales                          0.16
# EU_Sales                          0.35
# JP_Sales                          0.01
# Other_Sales                       0.12
# Global_Sales                      0.64
# Critic_Score                      68.0
# Critic_Count                      61.0
# User_Score                         6.4
# User_Count                        87.0
# Developer                         Eden
# Rating                               T
# Name: 8154, dtype: object
#
# Index: 8310, Ligne complète:
# Rank                        3196
# Name            Monster Hunter 2
# Platform                     PS2
# Year                         NaN
# Genre               Role-Playing
# Publisher                 Capcom
# NA_Sales                     0.0
# EU_Sales                     0.0
# JP_Sales                    0.63
# Other_Sales                  0.0
# Global_Sales                0.63
# Critic_Score                 NaN
# Critic_Count                 NaN
# User_Score                   NaN
# User_Count                   NaN
# Developer                    NaN
# Rating                       NaN
# Name: 8310, dtype: object
#
# Index: 8374, Ligne complète:
# Rank                                  3219
# Name            Advance Wars: Days of Ruin
# Platform                                DS
# Year                                   NaN
# Genre                             Strategy
# Publisher                         Nintendo
# NA_Sales                              0.44
# EU_Sales                              0.13
# JP_Sales                               0.0
# Other_Sales                           0.06
# Global_Sales                          0.63
# Critic_Score                          86.0
# Critic_Count                          55.0
# User_Score                             8.7
# User_Count                            96.0
# Developer              Intelligent Systems
# Rating                                E10+
# Name: 8374, dtype: object
#
# Index: 8424, Ligne complète:
# Rank                                     3240
# Name            Metal Gear Solid 2: Substance
# Platform                                   XB
# Year                                      NaN
# Genre                                  Action
# Publisher        Konami Digital Entertainment
# NA_Sales                                 0.38
# EU_Sales                                 0.22
# JP_Sales                                  0.0
# Other_Sales                              0.03
# Global_Sales                             0.62
# Critic_Score                             87.0
# Critic_Count                             28.0
# User_Score                                8.5
# User_Count                               39.0
# Developer                                KCEJ
# Rating                                      M
# Name: 8424, dtype: object
#
# Index: 8705, Ligne complète:
# Rank                                    3348
# Name                      The Golden Compass
# Platform                                 Wii
# Year                                     NaN
# Genre                                 Action
# Publisher                               Sega
# NA_Sales                                0.26
# EU_Sales                                0.28
# JP_Sales                                 0.0
# Other_Sales                             0.07
# Global_Sales                             0.6
# Critic_Score                            43.0
# Critic_Count                             7.0
# User_Score                               4.9
# User_Count                               8.0
# Developer       Artificial Mind and Movement
# Rating                                  E10+
# Name: 8705, dtype: object
#
# Index: 8909, Ligne complète:
# Rank                       3423
# Name              Madden NFL 06
# Platform                   X360
# Year                        NaN
# Genre                    Sports
# Publisher       Electronic Arts
# NA_Sales                   0.54
# EU_Sales                    0.0
# JP_Sales                   0.01
# Other_Sales                0.03
# Global_Sales               0.59
# Critic_Score               88.0
# Critic_Count               29.0
# User_Score                    8
# User_Count                121.0
# Developer             EA Sports
# Rating                        E
# Name: 8909, dtype: object
#
# Index: 9039, Ligne complète:
# Rank                               3470
# Name            NASCAR: Dirt to Daytona
# Platform                            PS2
# Year                                NaN
# Genre                            Racing
# Publisher                       Unknown
# NA_Sales                           0.28
# EU_Sales                           0.22
# JP_Sales                            0.0
# Other_Sales                        0.07
# Global_Sales                       0.58
# Critic_Score                       84.0
# Critic_Count                       10.0
# User_Score                          8.8
# User_Count                         19.0
# Developer            Monster Games Inc.
# Rating                                E
# Name: 9039, dtype: object
#
# Index: 9101, Ligne complète:
# Rank                       3503
# Name            Madden NFL 2002
# Platform                     XB
# Year                        NaN
# Genre                    Sports
# Publisher               Unknown
# NA_Sales                   0.53
# EU_Sales                   0.02
# JP_Sales                    0.0
# Other_Sales                0.03
# Global_Sales               0.58
# Critic_Score               94.0
# Critic_Count               23.0
# User_Score                  7.9
# User_Count                 46.0
# Developer             EA Sports
# Rating                        E
# Name: 9101, dtype: object
#
# Index: 9639, Ligne complète:
# Rank                             3717
# Name            Def Jam: Fight for NY
# Platform                           XB
# Year                              NaN
# Genre                        Fighting
# Publisher             Electronic Arts
# NA_Sales                         0.43
# EU_Sales                          0.1
# JP_Sales                          0.0
# Other_Sales                      0.02
# Global_Sales                     0.54
# Critic_Score                     83.0
# Critic_Count                     46.0
# User_Score                        8.9
# User_Count                       73.0
# Developer                   Aki Corp.
# Rating                              M
# Name: 9639, dtype: object
#
# Index: 9730, Ligne complète:
# Rank                         3755
# Name            NBA Street Vol. 2
# Platform                       GC
# Year                          NaN
# Genre                      Sports
# Publisher         Electronic Arts
# NA_Sales                     0.41
# EU_Sales                     0.11
# JP_Sales                      0.0
# Other_Sales                  0.01
# Global_Sales                 0.54
# Critic_Score                 90.0
# Critic_Count                 31.0
# User_Score                    8.8
# User_Count                   70.0
# Developer         Electronic Arts
# Rating                          E
# Name: 9730, dtype: object
#
# Index: 10048, Ligne complète:
# Rank                     3882
# Name            Fishing Derby
# Platform                 2600
# Year                      NaN
# Genre                  Sports
# Publisher          Activision
# NA_Sales                 0.48
# EU_Sales                 0.03
# JP_Sales                  0.0
# Other_Sales              0.01
# Global_Sales             0.51
# Critic_Score              NaN
# Critic_Count              NaN
# User_Score                NaN
# User_Count                NaN
# Developer                 NaN
# Rating                    NaN
# Name: 10048, dtype: object
#
# Index: 10234, Ligne complète:
# Rank                                    3954
# Name                                     Wet
# Platform                                X360
# Year                                     NaN
# Genre                                Shooter
# Publisher                 Bethesda Softworks
# NA_Sales                                0.23
# EU_Sales                                0.21
# JP_Sales                                0.01
# Other_Sales                             0.05
# Global_Sales                             0.5
# Critic_Score                            70.0
# Critic_Count                            61.0
# User_Score                               6.4
# User_Count                              55.0
# Developer       Artificial Mind and Movement
# Rating                                     M
# Name: 10234, dtype: object
#
# Index: 10770, Ligne complète:
# Rank                          4147
# Name            Sonic the Hedgehog
# Platform                       PS3
# Year                           NaN
# Genre                     Platform
# Publisher                      NaN
# NA_Sales                       0.0
# EU_Sales                      0.48
# JP_Sales                       0.0
# Other_Sales                    0.0
# Global_Sales                  0.48
# Critic_Score                   NaN
# Critic_Count                   NaN
# User_Score                     NaN
# User_Count                     NaN
# Developer                      NaN
# Rating                         NaN
# Name: 10770, dtype: object
#
# Index: 10780, Ligne complète:
# Rank                   4153
# Name                 Karate
# Platform               2600
# Year                    NaN
# Genre              Fighting
# Publisher       Ultravision
# NA_Sales               0.44
# EU_Sales               0.03
# JP_Sales                0.0
# Other_Sales             0.0
# Global_Sales           0.47
# Critic_Score            NaN
# Critic_Count            NaN
# User_Score              NaN
# User_Count              NaN
# Developer               NaN
# Rating                  NaN
# Name: 10780, dtype: object
#
# Index: 10889, Ligne complète:
# Rank                               4201
# Name            Tiger Woods PGA Tour 07
# Platform                            Wii
# Year                                NaN
# Genre                            Sports
# Publisher               Electronic Arts
# NA_Sales                           0.43
# EU_Sales                            0.0
# JP_Sales                            0.0
# Other_Sales                        0.04
# Global_Sales                       0.47
# Critic_Score                       79.0
# Critic_Count                       33.0
# User_Score                            6
# User_Count                          8.0
# Developer             EA Redwood Shores
# Rating                                E
# Name: 10889, dtype: object
#
# Index: 10969, Ligne complète:
# Rank                    4234
# Name            Circus Atari
# Platform                2600
# Year                     NaN
# Genre                 Action
# Publisher              Atari
# NA_Sales                0.43
# EU_Sales                0.03
# JP_Sales                 0.0
# Other_Sales              0.0
# Global_Sales            0.46
# Critic_Score             NaN
# Critic_Count             NaN
# User_Score               NaN
# User_Count               NaN
# Developer                NaN
# Rating                   NaN
# Name: 10969, dtype: object
#
# Index: 11218, Ligne complète:
# Rank                                                         4332
# Name            The Chronicles of Riddick: Escape from Butcher...
# Platform                                                       XB
# Year                                                          NaN
# Genre                                                     Shooter
# Publisher                                           Vivendi Games
# NA_Sales                                                     0.32
# EU_Sales                                                     0.11
# JP_Sales                                                      0.0
# Other_Sales                                                  0.02
# Global_Sales                                                 0.45
# Critic_Score                                                 89.0
# Critic_Count                                                 84.0
# User_Score                                                    8.9
# User_Count                                                   85.0
# Developer                                              Starbreeze
# Rating                                                          M
# Name: 11218, dtype: object
#
# Index: 11344, Ligne complète:
# Rank                                             4380
# Name            Maze Craze: A Game of Cops 'n Robbers
# Platform                                         2600
# Year                                              NaN
# Genre                                          Action
# Publisher                                       Atari
# NA_Sales                                         0.42
# EU_Sales                                         0.02
# JP_Sales                                          0.0
# Other_Sales                                       0.0
# Global_Sales                                     0.45
# Critic_Score                                      NaN
# Critic_Count                                      NaN
# User_Score                                        NaN
# User_Count                                        NaN
# Developer                                         NaN
# Rating                                            NaN
# Name: 11344, dtype: object
#
# Index: 11347, Ligne complète:
# Rank                                    4382
# Name                 Silent Hill: Homecoming
# Platform                                X360
# Year                                     NaN
# Genre                                 Action
# Publisher       Konami Digital Entertainment
# NA_Sales                                0.25
# EU_Sales                                0.16
# JP_Sales                                 0.0
# Other_Sales                             0.04
# Global_Sales                            0.45
# Critic_Score                            70.0
# Critic_Count                            54.0
# User_Score                               6.9
# User_Count                             180.0
# Developer                 Double Helix Games
# Rating                                     M
# Name: 11347, dtype: object
#
# Index: 11559, Ligne complète:
# Rank                      4471
# Name            Super Breakout
# Platform                  2600
# Year                       NaN
# Genre                   Puzzle
# Publisher                Atari
# NA_Sales                  0.41
# EU_Sales                  0.03
# JP_Sales                   0.0
# Other_Sales                0.0
# Global_Sales              0.44
# Critic_Score               NaN
# Critic_Count               NaN
# User_Score                 NaN
# User_Count                 NaN
# Developer                  NaN
# Rating                     NaN
# Name: 11559, dtype: object
#
# Index: 11563, Ligne complète:
# Rank                                             4474
# Name            Robert Ludlum's The Bourne Conspiracy
# Platform                                         X360
# Year                                              NaN
# Genre                                          Action
# Publisher                               Vivendi Games
# NA_Sales                                         0.26
# EU_Sales                                         0.14
# JP_Sales                                          0.0
# Other_Sales                                      0.04
# Global_Sales                                     0.44
# Critic_Score                                     71.0
# Critic_Count                                     72.0
# User_Score                                        7.2
# User_Count                                       63.0
# Developer                           High Moon Studios
# Rating                                              T
# Name: 11563, dtype: object
#
# Index: 11722, Ligne complète:
# Rank                    4538
# Name            NHL Slapshot
# Platform                 Wii
# Year                     NaN
# Genre                 Sports
# Publisher            Unknown
# NA_Sales                 0.4
# EU_Sales                 0.0
# JP_Sales                 0.0
# Other_Sales             0.02
# Global_Sales            0.43
# Critic_Score            76.0
# Critic_Count            25.0
# User_Score               8.1
# User_Count               7.0
# Developer          EA Sports
# Rating                     E
# Name: 11722, dtype: object
#
# Index: 12086, Ligne complète:
# Rank                       4685
# Name                       TERA
# Platform                     PC
# Year                        NaN
# Genre              Role-Playing
# Publisher               Unknown
# NA_Sales                   0.24
# EU_Sales                   0.12
# JP_Sales                    0.0
# Other_Sales                0.05
# Global_Sales               0.41
# Critic_Score               77.0
# Critic_Count               41.0
# User_Score                  6.8
# User_Count                742.0
# Developer       Bluehole Studio
# Rating                        M
# Name: 12086, dtype: object
#
# Index: 12382, Ligne complète:
# Rank                                              4793
# Name                      LEGO Harry Potter: Years 5-7
# Platform                                           3DS
# Year                                               NaN
# Genre                                           Action
# Publisher       Warner Bros. Interactive Entertainment
# NA_Sales                                          0.18
# EU_Sales                                          0.19
# JP_Sales                                           0.0
# Other_Sales                                       0.04
# Global_Sales                                       0.4
# Critic_Score                                      76.0
# Critic_Count                                       8.0
# User_Score                                         7.8
# User_Count                                        13.0
# Developer                            Traveller's Tales
# Rating                                            E10+
# Name: 12382, dtype: object
#
# Index: 12410, Ligne complète:
# Rank                        4799
# Name            NFL GameDay 2003
# Platform                     PS2
# Year                         NaN
# Genre                     Sports
# Publisher                Unknown
# NA_Sales                     0.2
# EU_Sales                    0.15
# JP_Sales                     0.0
# Other_Sales                 0.05
# Global_Sales                 0.4
# Critic_Score                60.0
# Critic_Count                23.0
# User_Score                   tbd
# User_Count                   NaN
# Developer             989 Sports
# Rating                         E
# Name: 12410, dtype: object
#
# Index: 12575, Ligne complète:
# Rank                                    4860
# Name                 Silent Hill: Homecoming
# Platform                                 PS3
# Year                                     NaN
# Genre                                 Action
# Publisher       Konami Digital Entertainment
# NA_Sales                                0.18
# EU_Sales                                0.15
# JP_Sales                                 0.0
# Other_Sales                             0.06
# Global_Sales                             0.4
# Critic_Score                            70.0
# Critic_Count                            54.0
# User_Score                               6.9
# User_Count                             180.0
# Developer                 Double Helix Games
# Rating                                     M
# Name: 12575, dtype: object
#
# Index: 12591, Ligne complète:
# Rank                                       4867
# Name            Harvest Moon: Save the Homeland
# Platform                                    PS2
# Year                                        NaN
# Genre                                Simulation
# Publisher                               Unknown
# NA_Sales                                   0.19
# EU_Sales                                   0.15
# JP_Sales                                    0.0
# Other_Sales                                0.05
# Global_Sales                                0.4
# Critic_Score                               76.0
# Critic_Count                               14.0
# User_Score                                  8.8
# User_Count                                 72.0
# Developer           Victor Interactive Software
# Rating                                        E
# Name: 12591, dtype: object
#
# Index: 12774, Ligne complète:
# Rank                                             4936
# Name            Robert Ludlum's The Bourne Conspiracy
# Platform                                          PS3
# Year                                              NaN
# Genre                                          Action
# Publisher                               Vivendi Games
# NA_Sales                                         0.18
# EU_Sales                                         0.14
# JP_Sales                                          0.0
# Other_Sales                                      0.06
# Global_Sales                                     0.39
# Critic_Score                                     71.0
# Critic_Count                                     72.0
# User_Score                                        7.2
# User_Count                                       63.0
# Developer                           High Moon Studios
# Rating                                              T
# Name: 12774, dtype: object
#
# Index: 13082, Ligne complète:
# Rank               5063
# Name            Hangman
# Platform           2600
# Year                NaN
# Genre            Puzzle
# Publisher         Atari
# NA_Sales           0.35
# EU_Sales           0.02
# JP_Sales            0.0
# Other_Sales         0.0
# Global_Sales       0.38
# Critic_Score        NaN
# Critic_Count        NaN
# User_Score          NaN
# User_Count          NaN
# Developer           NaN
# Rating              NaN
# Name: 13082, dtype: object
#
# Index: 13118, Ligne complète:
# Rank                                    5080
# Name                      The Golden Compass
# Platform                                 PSP
# Year                                     NaN
# Genre                                 Action
# Publisher                               Sega
# NA_Sales                                0.11
# EU_Sales                                0.16
# JP_Sales                                 0.0
# Other_Sales                              0.1
# Global_Sales                            0.38
# Critic_Score                            43.0
# Critic_Count                             7.0
# User_Score                               4.9
# User_Count                               8.0
# Developer       Artificial Mind and Movement
# Rating                                  E10+
# Name: 13118, dtype: object
#
# Index: 13346, Ligne complète:
# Rank                       5164
# Name              NBA Live 2003
# Platform                     XB
# Year                        NaN
# Genre                    Sports
# Publisher       Electronic Arts
# NA_Sales                   0.31
# EU_Sales                   0.04
# JP_Sales                    0.0
# Other_Sales                0.01
# Global_Sales               0.36
# Critic_Score               83.0
# Critic_Count               22.0
# User_Score                  8.3
# User_Count                 28.0
# Developer             EA Canada
# Rating                        E
# Name: 13346, dtype: object
#
# Index: 13368, Ligne complète:
# Rank                   5173
# Name            Bejeweled 3
# Platform                 DS
# Year                    NaN
# Genre                Puzzle
# Publisher           Unknown
# NA_Sales               0.32
# EU_Sales               0.02
# JP_Sales                0.0
# Other_Sales            0.03
# Global_Sales           0.36
# Critic_Score           75.0
# Critic_Count            9.0
# User_Score              tbd
# User_Count              NaN
# Developer            PopCap
# Rating                    E
# Name: 13368, dtype: object
#
# Index: 13423, Ligne complète:
# Rank                                                 5197
# Name            Cubix Robots for Everyone: Clash 'n' Bash
# Platform                                              GBA
# Year                                                  NaN
# Genre                                              Action
# Publisher                                         Unknown
# NA_Sales                                             0.26
# EU_Sales                                              0.1
# JP_Sales                                              0.0
# Other_Sales                                          0.01
# Global_Sales                                         0.36
# Critic_Score                                          NaN
# Critic_Count                                          NaN
# User_Score                                            NaN
# User_Count                                            NaN
# Developer                                             NaN
# Rating                                                NaN
# Name: 13423, dtype: object
#
# Index: 13424, Ligne complète:
# Rank                     5198
# Name                Tropico 4
# Platform                 X360
# Year                      NaN
# Genre                Strategy
# Publisher       Kalypso Media
# NA_Sales                  0.2
# EU_Sales                 0.13
# JP_Sales                  0.0
# Other_Sales              0.03
# Global_Sales             0.36
# Critic_Score             77.0
# Critic_Count             18.0
# User_Score                7.5
# User_Count               37.0
# Developer           Haemimont
# Rating                      T
# Name: 13424, dtype: object
#
# Index: 13518, Ligne complète:
# Rank                          5242
# Name            Tomb Raider (2013)
# Platform                        PC
# Year                           NaN
# Genre                       Action
# Publisher              Square Enix
# NA_Sales                      0.06
# EU_Sales                      0.25
# JP_Sales                       0.0
# Other_Sales                   0.05
# Global_Sales                  0.36
# Critic_Score                   NaN
# Critic_Count                   NaN
# User_Score                     NaN
# User_Count                     NaN
# Developer                      NaN
# Rating                         NaN
# Name: 13518, dtype: object
#
# Index: 13652, Ligne complète:
# Rank                                                     5304
# Name            Dragon Ball Z: Budokai Tenkaichi 2 (JP sales)
# Platform                                                  Wii
# Year                                                      NaN
# Genre                                                  Action
# Publisher                                                 NaN
# NA_Sales                                                 0.15
# EU_Sales                                                 0.05
# JP_Sales                                                 0.14
# Other_Sales                                              0.01
# Global_Sales                                             0.35
# Critic_Score                                              NaN
# Critic_Count                                              NaN
# User_Score                                                NaN
# User_Count                                                NaN
# Developer                                                 NaN
# Rating                                                    NaN
# Name: 13652, dtype: object
#
# Index: 14148, Ligne complète:
# Rank                    5510
# Name             Custom Robo
# Platform                 N64
# Year                     NaN
# Genre           Role-Playing
# Publisher           Nintendo
# NA_Sales                 0.0
# EU_Sales                 0.0
# JP_Sales                0.29
# Other_Sales             0.04
# Global_Sales            0.33
# Critic_Score            65.0
# Critic_Count            31.0
# User_Score               8.1
# User_Count              27.0
# Developer         Noise Inc.
# Rating                     T
# Name: 14148, dtype: object
#
# Index: 14415, Ligne complète:
# Rank                        5620
# Name            Final Fantasy XI
# Platform                     PS2
# Year                         NaN
# Genre               Role-Playing
# Publisher                Unknown
# NA_Sales                    0.08
# EU_Sales                    0.06
# JP_Sales                    0.15
# Other_Sales                 0.02
# Global_Sales                0.32
# Critic_Score                85.0
# Critic_Count                49.0
# User_Score                   6.9
# User_Count                  66.0
# Developer            Square Enix
# Rating                         T
# Name: 14415, dtype: object
#
# Index: 14429, Ligne complète:
# Rank                      5627
# Name               Singularity
# Platform                  X360
# Year                       NaN
# Genre                  Shooter
# Publisher              Unknown
# NA_Sales                  0.24
# EU_Sales                  0.05
# JP_Sales                   0.0
# Other_Sales               0.02
# Global_Sales              0.32
# Critic_Score              76.0
# Critic_Count              70.0
# User_Score                 7.7
# User_Count               169.0
# Developer       Raven Software
# Rating                       M
# Name: 14429, dtype: object
#
# Index: 14495, Ligne complète:
# Rank                  5659
# Name              Dragster
# Platform              2600
# Year                   NaN
# Genre               Racing
# Publisher       Activision
# NA_Sales               0.3
# EU_Sales              0.02
# JP_Sales               0.0
# Other_Sales            0.0
# Global_Sales          0.32
# Critic_Score           NaN
# Critic_Count           NaN
# User_Score             NaN
# User_Count             NaN
# Developer              NaN
# Rating                 NaN
# Name: 14495, dtype: object
#
# Index: 14517, Ligne complète:
# Rank                              5671
# Name            All-Star Baseball 2005
# Platform                           PS2
# Year                               NaN
# Genre                           Sports
# Publisher                      Unknown
# NA_Sales                          0.16
# EU_Sales                          0.12
# JP_Sales                           0.0
# Other_Sales                       0.04
# Global_Sales                      0.32
# Critic_Score                      72.0
# Critic_Count                      13.0
# User_Score                         8.6
# User_Count                        21.0
# Developer                      Acclaim
# Rating                               E
# Name: 14517, dtype: object
#
# Index: 14732, Ligne complète:
# Rank                                              5771
# Name            Star Wars Jedi Knight II: Jedi Outcast
# Platform                                            XB
# Year                                               NaN
# Genre                                          Shooter
# Publisher                                   Activision
# NA_Sales                                          0.23
# EU_Sales                                          0.07
# JP_Sales                                           0.0
# Other_Sales                                       0.01
# Global_Sales                                      0.31
# Critic_Score                                      81.0
# Critic_Count                                      24.0
# User_Score                                         6.8
# User_Count                                        15.0
# Developer                            Vicarious Visions
# Rating                                               T
# Name: 14732, dtype: object
#
# Index: 14798, Ligne complète:
# Rank                    5800
# Name            Slot Machine
# Platform                2600
# Year                     NaN
# Genre                 Action
# Publisher              Atari
# NA_Sales                0.29
# EU_Sales                0.02
# JP_Sales                 0.0
# Other_Sales              0.0
# Global_Sales            0.31
# Critic_Score             NaN
# Critic_Count             NaN
# User_Score               NaN
# User_Count               NaN
# Developer                NaN
# Rating                   NaN
# Name: 14798, dtype: object
#
# Index: 14869, Ligne complète:
# Rank                       5840
# Name            Shrek the Third
# Platform                     DS
# Year                        NaN
# Genre                    Action
# Publisher            Activision
# NA_Sales                   0.26
# EU_Sales                   0.02
# JP_Sales                    0.0
# Other_Sales                0.02
# Global_Sales                0.3
# Critic_Score                NaN
# Critic_Count                NaN
# User_Score                  NaN
# User_Count                  NaN
# Developer                   NaN
# Rating                      NaN
# Name: 14869, dtype: object
#
# ...
# Genre                          Sports
# Publisher                        Sega
# NA_Sales                          0.0
# EU_Sales                         0.01
# JP_Sales                          0.0
# Other_Sales                       0.0
# Global_Sales                     0.02
# Critic_Score                      NaN
# Critic_Count                      NaN
# User_Score                        NaN
# User_Count                        NaN
# Developer                         NaN
# Rating                            NaN
# Name: 33868, dtype: object
#
# Index: 33994, Ligne complète:
# Rank                                   15814
# Name            Ferrari: The Race Experience
# Platform                                 Wii
# Year                                     NaN
# Genre                                 Racing
# Publisher           System 3 Arcade Software
# NA_Sales                                 0.0
# EU_Sales                                0.01
# JP_Sales                                 0.0
# Other_Sales                              0.0
# Global_Sales                            0.02
# Critic_Score                            54.0
# Critic_Count                             4.0
# User_Score                               NaN
# User_Count                               NaN
# Developer                           System 3
# Rating                                     E
# Name: 33994, dtype: object
#
# Index: 34078, Ligne complète:
# Rank                                        15868
# Name            PDC World Championship Darts 2008
# Platform                                       DS
# Year                                          NaN
# Genre                                      Sports
# Publisher                                 Unknown
# NA_Sales                                     0.01
# EU_Sales                                      0.0
# JP_Sales                                      0.0
# Other_Sales                                   0.0
# Global_Sales                                 0.02
# Critic_Score                                 51.0
# Critic_Count                                 18.0
# User_Score                                    5.4
# User_Count                                    7.0
# Developer                      Oxygen Interactive
# Rating                                       E10+
# Name: 34078, dtype: object
#
# Index: 34102, Ligne complète:
# Rank                                      15879
# Name            Dinotopia: The Sunstone Odyssey
# Platform                                     GC
# Year                                        NaN
# Genre                                    Action
# Publisher                               Unknown
# NA_Sales                                   0.01
# EU_Sales                                    0.0
# JP_Sales                                    0.0
# Other_Sales                                 0.0
# Global_Sales                               0.02
# Critic_Score                               50.0
# Critic_Count                                4.0
# User_Score                                  tbd
# User_Count                                  NaN
# Developer                         Vicious Cycle
# Rating                                        T
# Name: 34102, dtype: object
#
# Index: 34105, Ligne complète:
# Rank                             15881
# Name            Dance! It's Your Stage
# Platform                           Wii
# Year                               NaN
# Genre                             Misc
# Publisher            DTP Entertainment
# NA_Sales                           0.0
# EU_Sales                          0.01
# JP_Sales                           0.0
# Other_Sales                        0.0
# Global_Sales                      0.02
# Critic_Score                       NaN
# Critic_Count                       NaN
# User_Score                         NaN
# User_Count                         NaN
# Developer                          NaN
# Rating                             NaN
# Name: 34105, dtype: object
#
# Index: 34138, Ligne complète:
# Rank                  15903
# Name            Jet Impulse
# Platform                 DS
# Year                    NaN
# Genre            Simulation
# Publisher          Nintendo
# NA_Sales                0.0
# EU_Sales                0.0
# JP_Sales               0.02
# Other_Sales             0.0
# Global_Sales           0.02
# Critic_Score            NaN
# Critic_Count            NaN
# User_Score              NaN
# User_Count              NaN
# Developer               NaN
# Rating                  NaN
# Name: 34138, dtype: object
#
# Index: 34154, Ligne complète:
# Rank                                               15918
# Name                                        Dream Dancer
# Platform                                              DS
# Year                                                 NaN
# Genre                                               Misc
# Publisher                                            NaN
# NA_Sales                                            0.01
# EU_Sales                                             0.0
# JP_Sales                                             0.0
# Other_Sales                                          0.0
# Global_Sales                                        0.02
# Critic_Score                                         NaN
# Critic_Count                                         NaN
# User_Score                                           tbd
# User_Count                                           NaN
# Developer       CyberPlanet Interactive Public Co., Ltd.
# Rating                                                 E
# Name: 34154, dtype: object
#
# Index: 34359, Ligne complète:
# Rank                                        16060
# Name            PDC World Championship Darts 2008
# Platform                                      PSP
# Year                                          NaN
# Genre                                      Sports
# Publisher                      Oxygen Interactive
# NA_Sales                                     0.01
# EU_Sales                                      0.0
# JP_Sales                                      0.0
# Other_Sales                                   0.0
# Global_Sales                                 0.01
# Critic_Score                                 51.0
# Critic_Count                                 18.0
# User_Score                                    5.4
# User_Count                                    7.0
# Developer                      Oxygen Interactive
# Rating                                       E10+
# Name: 34359, dtype: object
#
# Index: 34362, Ligne complète:
# Rank                                        16061
# Name            WRC: FIA World Rally Championship
# Platform                                       PC
# Year                                          NaN
# Genre                                      Racing
# Publisher                        Black Bean Games
# NA_Sales                                      0.0
# EU_Sales                                     0.01
# JP_Sales                                      0.0
# Other_Sales                                   0.0
# Global_Sales                                 0.01
# Critic_Score                                 68.0
# Critic_Count                                 24.0
# User_Score                                    4.5
# User_Count                                    4.0
# Developer                         Milestone S.r.l
# Rating                                        NaN
# Name: 34362, dtype: object
#
# Index: 34377, Ligne complète:
# Rank                                   16068
# Name            Aquaman: Battle for Atlantis
# Platform                                  XB
# Year                                     NaN
# Genre                                 Action
# Publisher                            Unknown
# NA_Sales                                0.01
# EU_Sales                                 0.0
# JP_Sales                                 0.0
# Other_Sales                              0.0
# Global_Sales                            0.01
# Critic_Score                            26.0
# Critic_Count                            13.0
# User_Score                               2.7
# User_Count                              15.0
# Developer                      Lucky Chicken
# Rating                                     T
# Name: 34377, dtype: object
#
# Index: 34569, Ligne complète:
# Rank                                      16194
# Name            Homeworld Remastered Collection
# Platform                                     PC
# Year                                        NaN
# Genre                                  Strategy
# Publisher                                   NaN
# NA_Sales                                    0.0
# EU_Sales                                   0.01
# JP_Sales                                    0.0
# Other_Sales                                 0.0
# Global_Sales                               0.01
# Critic_Score                               86.0
# Critic_Count                               49.0
# User_Score                                  8.2
# User_Count                                324.0
# Developer                      Gearbox Software
# Rating                                     E10+
# Name: 34569, dtype: object
#
# Index: 34574, Ligne complète:
# Rank                                   16197
# Name                                  Shorts
# Platform                                  DS
# Year                                     NaN
# Genre                               Platform
# Publisher                            Unknown
# NA_Sales                                0.01
# EU_Sales                                 0.0
# JP_Sales                                 0.0
# Other_Sales                              0.0
# Global_Sales                            0.01
# Critic_Score                             NaN
# Critic_Count                             NaN
# User_Score                               tbd
# User_Count                               NaN
# Developer       Artificial Mind and Movement
# Rating                                  E10+
# Name: 34574, dtype: object
#
# Index: 34578, Ligne complète:
# Rank                                             16201
# Name            AKB1/48: Idol to Guam de Koishitara...
# Platform                                          X360
# Year                                               NaN
# Genre                                             Misc
# Publisher                                          NaN
# NA_Sales                                           0.0
# EU_Sales                                           0.0
# JP_Sales                                          0.01
# Other_Sales                                        0.0
# Global_Sales                                      0.01
# Critic_Score                                       NaN
# Critic_Count                                       NaN
# User_Score                                         NaN
# User_Count                                         NaN
# Developer                                          NaN
# Rating                                             NaN
# Name: 34578, dtype: object
#
# Index: 34626, Ligne complète:
# Rank                                  16232
# Name            Brothers in Arms: Furious 4
# Platform                               X360
# Year                                    NaN
# Genre                               Shooter
# Publisher                               NaN
# NA_Sales                               0.01
# EU_Sales                                0.0
# JP_Sales                                0.0
# Other_Sales                             0.0
# Global_Sales                           0.01
# Critic_Score                            NaN
# Critic_Count                            NaN
# User_Score                              NaN
# User_Count                              NaN
# Developer                  Gearbox Software
# Rating                                    M
# Name: 34626, dtype: object
#
# Index: 34657, Ligne complète:
# Rank                                   16249
# Name            Agarest Senki: Re-appearance
# Platform                                 PS3
# Year                                     NaN
# Genre                           Role-Playing
# Publisher                       Idea Factory
# NA_Sales                                 0.0
# EU_Sales                                 0.0
# JP_Sales                                0.01
# Other_Sales                              0.0
# Global_Sales                            0.01
# Critic_Score                             NaN
# Critic_Count                             NaN
# User_Score                               NaN
# User_Count                               NaN
# Developer                                NaN
# Rating                                   NaN
# Name: 34657, dtype: object
#
# Index: 34740, Ligne complète:
# Rank                                 16310
# Name                         Freaky Flyers
# Platform                                GC
# Year                                   NaN
# Genre                               Racing
# Publisher                          Unknown
# NA_Sales                              0.01
# EU_Sales                               0.0
# JP_Sales                               0.0
# Other_Sales                            0.0
# Global_Sales                          0.01
# Critic_Score                          66.0
# Critic_Count                          20.0
# User_Score                             tbd
# User_Count                             NaN
# Developer       Midway Studios - San Diego
# Rating                                   T
# Name: 34740, dtype: object
#
# Index: 34765, Ligne complète:
# Rank                         16330
# Name                     Inversion
# Platform                        PC
# Year                           NaN
# Genre                      Shooter
# Publisher       Namco Bandai Games
# NA_Sales                      0.01
# EU_Sales                       0.0
# JP_Sales                       0.0
# Other_Sales                    0.0
# Global_Sales                  0.01
# Critic_Score                  56.0
# Critic_Count                  23.0
# User_Score                     5.4
# User_Count                    43.0
# Developer        Saber Interactive
# Rating                           M
# Name: 34765, dtype: object
#
# Index: 34828, Ligne complète:
# Rank                                  16369
# Name            Hakuouki: Shinsengumi Kitan
# Platform                                PS3
# Year                                    NaN
# Genre                             Adventure
# Publisher                           Unknown
# NA_Sales                               0.01
# EU_Sales                                0.0
# JP_Sales                                0.0
# Other_Sales                             0.0
# Global_Sales                           0.01
# Critic_Score                            NaN
# Critic_Count                            NaN
# User_Score                              NaN
# User_Count                              NaN
# Developer                               NaN
# Rating                                  NaN
# Name: 34828, dtype: object
#
# Index: 34932, Ligne complète:
# Rank                                   16430
# Name                            Virtua Quest
# Platform                                  GC
# Year                                     NaN
# Genre                           Role-Playing
# Publisher                            Unknown
# NA_Sales                                0.01
# EU_Sales                                 0.0
# JP_Sales                                 0.0
# Other_Sales                              0.0
# Global_Sales                            0.01
# Critic_Score                            53.0
# Critic_Count                            17.0
# User_Score                               7.6
# User_Count                               5.0
# Developer       Artificial Mind and Movement
# Rating                                     T
# Name: 34932, dtype: object
#
# Index: 35034, Ligne complète:
# Rank                 16496
# Name            The Smurfs
# Platform               3DS
# Year                   NaN
# Genre               Action
# Publisher          Unknown
# NA_Sales               0.0
# EU_Sales              0.01
# JP_Sales               0.0
# Other_Sales            0.0
# Global_Sales          0.01
# Critic_Score           NaN
# Critic_Count           NaN
# User_Score             tbd
# User_Count             NaN
# Developer         Land Ho!
# Rating                   E
# Name: 35034, dtype: object

# %%
# Remplacement à la main d'une valeur manquante

dfvg.at[395, "Year"] = 2003

# Vérification

print(dfvg["Year"][395])
# Out:
# 2003.0

# %%
# Remplacement des valeurs manquantes par les valeurs réelles trouvées sur les sites Metacritic et SensCritique

dfvg.at[937, "Year"] = 2003
dfvg.at[1067, "Year"] = 2008
dfvg.at[1173, "Year"] = 2005
dfvg.at[1173, "Publisher"] = "THQ"
dfvg.at[1173, "Critic_Score"] = 84
dfvg.at[1173, "Critic_Count"] = 45
dfvg.at[1173, "User_Score"] = 8.2
dfvg.at[1173, "User_Count"] = 93
dfvg.at[1173, "Developer"] = "Yuke's"
dfvg.at[1173, "Rating"] = "T"
dfvg.at[1528, "Year"] = 1978
dfvg.at[1580, "Year"] = 2007
dfvg.at[1642, "Year"] = 2001
dfvg.at[1642, "User_Score"] = 8.0
dfvg.at[1642, "User_Count"] = 7
dfvg.at[1649, "Year"] = 2008
dfvg.at[1833, "Year"] = 2006
dfvg.at[2001, "Year"] = 2007
dfvg.at[2849, "Year"] = 2010
dfvg.at[2874, "Year"] = 2007
dfvg.at[3274, "Year"] = 1998
dfvg.at[3613, "Year"] = 2011
dfvg.at[3799, "Year"] = 2008
dfvg.at[3837, "Year"] = 1980
dfvg.at[3837, "User_Score"] = 7.1
dfvg.at[3837, "User_Count"] = 64
dfvg.at[3837, "Developer"] = "Warren Robinett"
dfvg.at[4026, "Year"] = 1977
dfvg.at[4026, "User_Score"] = 5.8
dfvg.at[4026, "User_Count"] = 32
dfvg.at[4180, "Year"] = 2002
dfvg.at[4304, "Year"] = 2002
dfvg.at[4649, "Year"] = 2007
dfvg.at[5031, "Year"] = 1999
dfvg.at[5115, "Year"] = 1997
dfvg.at[5115, "User_Score"] = 6.8
dfvg.at[5115, "User_Count"] = 144
dfvg.at[5115, "Developer"] = "Rare"
dfvg.at[5115, "Rating"] = "E"
dfvg.at[5292, "Year"] = 2011
dfvg.at[5390, "Year"] = 1977
dfvg.at[5390, "User_Score"] = 4.9
dfvg.at[5390, "User_Count"] = 15
dfvg.at[5390, "Developer"] = "Larry Kaplan"
dfvg.at[5391, "Year"] = 2002
dfvg.at[5391, "Publisher"] = "Konami"
dfvg.at[5457, "Year"] = 2011
dfvg.at[5496, "Year"] = 2011
dfvg.at[5572, "Year"] = 2003
dfvg.at[5572, "Publisher"] = "Atari"
dfvg.at[5572, "Rating"] = "E"
dfvg.at[5894, "Year"] = 2002
dfvg.at[5894, "Publisher"] = "Namco"
dfvg.at[5928, "Year"] = 2009
dfvg.at[5928, "Publisher"] = "Nintendo"
dfvg.at[6222, "Year"] = 2011
dfvg.at[6235, "Year"] = 2011
dfvg.at[6408, "Year"] = 2006
dfvg.at[6408, "Publisher"] = "EA Tiburon"
dfvg.at[6436, "Year"] = 2002
dfvg.at[6436, "Publisher"] = "Midway"
dfvg.at[6517, "Year"] = 2008
dfvg.at[6671, "Year"] = 2009
dfvg.at[6671, "Critic_Score"] = 77
dfvg.at[6671, "Critic_Count"] = 34
dfvg.at[6671, "User_Score"] = 6.5
dfvg.at[6671, "User_Count"] = 35
dfvg.at[6671, "Developer"] = "KCET"
dfvg.at[6671, "Rating"] = "E"
dfvg.at[7180, "Year"] = 2010
dfvg.at[7180, "Publisher"] = "Electronic Arts"
dfvg.at[7204, "Year"] = 2005
dfvg.at[7204, "Publisher"] = "Nintendo"
dfvg.at[6671, "Critic_Score"] = 88
dfvg.at[6671, "Critic_Count"] = 39
dfvg.at[6671, "User_Score"] = 8.6
dfvg.at[6671, "User_Count"] = 39
dfvg.at[6671, "Developer"] = "Nintendo"
dfvg.at[6671, "Rating"] = "E"
dfvg.at[7345, "Year"] = 2011
dfvg.at[7638, "Year"] = 2011
dfvg.at[7903, "Year"] = 2005
dfvg.at[8154, "Year"] = 2011
dfvg.at[8310, "Year"] = 2006
dfvg.at[8310, "Developer"] = "Capcom"
dfvg.at[8374, "Year"] = 2008
dfvg.at[8424, "Year"] = 2002
dfvg.at[8705, "Year"] = 2007
dfvg.at[8909, "Year"] = 2005
dfvg.at[9039, "Year"] = 2002
dfvg.at[9039, "Publisher"] = "Infogrames"
dfvg.at[9101, "Year"] = 2001
dfvg.at[9101, "Publisher"] = "EA Sports"
dfvg.at[9639, "Year"] = 2004
dfvg.at[9730, "Year"] = 2003
dfvg.at[10048, "Year"] = 1980
dfvg.at[10048, "User_Score"] = 6.1
dfvg.at[10048, "User_Count"] = 6
dfvg.at[10048, "Developer"] = "Activision"
dfvg.at[10048, "Rating"] = "E"
dfvg.at[10234, "Year"] = 2009
dfvg.at[10770, "Year"] = 2007
dfvg.at[10770, "Publisher"] = "Sega"
dfvg.at[10770, "Critic_Score"] = 77
dfvg.at[10770, "Critic_Count"] = 11
dfvg.at[10770, "User_Score"] = 7.8
dfvg.at[10770, "User_Count"] = 104
dfvg.at[10770, "Developer"] = "Backbone Entertainment"
dfvg.at[10770, "Rating"] = "E"
dfvg.at[10780, "Year"] = 1982
dfvg.at[10780, "Developer"] = "Froggo Games"
dfvg.at[10889, "Year"] = 2006
dfvg.at[10969, "Year"] = 1980
dfvg.at[10969, "Developer"] = "Atari"
dfvg.at[11218, "Year"] = 2004
dfvg.at[11344, "Year"] = 1980
dfvg.at[11347, "Year"] = 2008
dfvg.at[11559, "Year"] = 1981
dfvg.at[11559, "User_Score"] = 6.7
dfvg.at[11559, "User_Count"] = 26
dfvg.at[11559, "Developer"] = "Ed Rotberg"
dfvg.at[11563, "Year"] = 2008
dfvg.at[11722, "Year"] = 2010
dfvg.at[12086, "Year"] = 2012
dfvg.at[12086, "Publisher"] = "En Masse Entertainment"
dfvg.at[12382, "Year"] = 2011
dfvg.at[12410, "Year"] = 2002
dfvg.at[12410, "Publisher"] = "SCEA"
dfvg.at[12575, "Year"] = 2008
dfvg.at[12591, "Year"] = 2001
dfvg.at[12591, "Publisher"] = "Natsume"
dfvg.at[12774, "Year"] = 2008
dfvg.at[13082, "Year"] = 1978
dfvg.at[13082, "Developer"] = "Alan Miller"
dfvg.at[13118, "Year"] = 2007
dfvg.at[13346, "Year"] = 2002
dfvg.at[13368, "Year"] = 2010
dfvg.at[13423, "Year"] = 2002
dfvg.at[13423, "Publisher"] = "3DO"
dfvg.at[13423, "Developer"] = "Blitz Games"
dfvg.at[13424, "Year"] = 2011
dfvg.at[13518, "Year"] = 2013
dfvg.at[13518, "Critic_Score"] = 86
dfvg.at[13518, "Critic_Count"] = 18
dfvg.at[13518, "User_Score"] = 8.4
dfvg.at[13518, "User_Count"] = 998
dfvg.at[13518, "Developer"] = "Crystal Dynamics"
dfvg.at[13518, "Rating"] = "AO"
dfvg.at[13652, "Year"] = 2006
dfvg.at[13652, "Publisher"] = "Atari SA"
dfvg.at[13652, "Critic_Score"] = 72
dfvg.at[13652, "Critic_Count"] = 37
dfvg.at[13652, "User_Score"] = 8.6
dfvg.at[13652, "User_Count"] = 43
dfvg.at[13652, "Developer"] = "Spike"
dfvg.at[13652, "Rating"] = "T"
dfvg.at[14148, "Year"] = 1999
dfvg.at[14415, "Year"] = 2004
dfvg.at[14415, "Publisher"] = "SCEA"
dfvg.at[14429, "Year"] = 2010
dfvg.at[14429, "Publisher"] = "Activision"
dfvg.at[14495, "Year"] = 1980
dfvg.at[14495, "Developer"] = "Activision"

# %%
# Affichage des lignes avec des valeurs manquantes

for index, row in valeurs_manquantes.iterrows():
    print(f"Index: {index}, Ligne complète: \n{row}\n")
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# Index: 5031, Ligne complète:
# Rank                                   1992
# Name            Legacy of Kain: Soul Reaver
# Platform                                 PS
# Year                                    NaN
# Genre                                Action
# Publisher                 Eidos Interactive
# NA_Sales                               0.58
# EU_Sales                                0.4
# JP_Sales                                0.0
# Other_Sales                            0.07
# Global_Sales                           1.04
# Critic_Score                           91.0
# Critic_Count                           17.0
# User_Score                                9
# User_Count                            132.0
# Developer                  Crystal Dynamics
# Rating                                    T
# Name: 5031, dtype: object
#
# Index: 5115, Ligne complète:
# Rank                            2021
# Name            Donkey Kong Land III
# Platform                          GB
# Year                             NaN
# Genre                       Platform
# Publisher                   Nintendo
# NA_Sales                        0.68
# EU_Sales                        0.31
# JP_Sales                         0.0
# Other_Sales                     0.04
# Global_Sales                    1.03
# Critic_Score                     NaN
# Critic_Count                     NaN
# User_Score                       NaN
# User_Count                       NaN
# Developer                        NaN
# Rating                           NaN
# Name: 5115, dtype: object
#
# Index: 5292, Ligne complète:
# Rank                                              2088
# Name                      LEGO Harry Potter: Years 5-7
# Platform                                          X360
# Year                                               NaN
# Genre                                           Action
# Publisher       Warner Bros. Interactive Entertainment
# NA_Sales                                          0.51
# EU_Sales                                          0.39
# JP_Sales                                           0.0
# Other_Sales                                       0.09
# Global_Sales                                      0.99
# Critic_Score                                      76.0
# Critic_Count                                       8.0
# User_Score                                         7.8
# User_Count                                        13.0
# Developer                            Traveller's Tales
# Rating                                            E10+
# Name: 5292, dtype: object
#
# Index: 5390, Ligne complète:
# Rank                      2115
# Name            Air-Sea Battle
# Platform                  2600
# Year                       NaN
# Genre                  Shooter
# Publisher                Atari
# NA_Sales                  0.91
# EU_Sales                  0.06
# JP_Sales                   0.0
# Other_Sales               0.01
# Global_Sales              0.98
# Critic_Score               NaN
# Critic_Count               NaN
# User_Score                 NaN
# User_Count                 NaN
# Developer                  NaN
# Rating                     NaN
# Name: 5390, dtype: object
#
# Index: 5391, Ligne complète:
# Rank                    2116
# Name            Suikoden III
# Platform                 PS2
# Year                     NaN
# Genre           Role-Playing
# Publisher            Unknown
# NA_Sales                0.29
# EU_Sales                0.23
# JP_Sales                0.38
# Other_Sales             0.08
# Global_Sales            0.98
# Critic_Score            86.0
# Critic_Count            23.0
# User_Score               7.7
# User_Count             113.0
# Developer               KCET
# Rating                     T
# Name: 5391, dtype: object
#
# Index: 5457, Ligne complète:
# Rank                             2136
# Name                         Yakuza 4
# Platform                          PS3
# Year                              NaN
# Genre                          Action
# Publisher                        Sega
# NA_Sales                         0.15
# EU_Sales                         0.14
# JP_Sales                         0.63
# Other_Sales                      0.05
# Global_Sales                     0.97
# Critic_Score                     78.0
# Critic_Count                     59.0
# User_Score                          8
# User_Count                      177.0
# Developer       Ryu ga Gotoku Studios
# Rating                              M
# Name: 5457, dtype: object
#
# Index: 5496, Ligne complète:
# Rank                                              2147
# Name                      LEGO Harry Potter: Years 5-7
# Platform                                           PS3
# Year                                               NaN
# Genre                                           Action
# Publisher       Warner Bros. Interactive Entertainment
# NA_Sales                                          0.36
# EU_Sales                                          0.45
# JP_Sales                                           0.0
# Other_Sales                                       0.16
# Global_Sales                                      0.97
# Critic_Score                                      76.0
# Critic_Count                                       8.0
# User_Score                                         7.8
# User_Count                                        13.0
# Developer                            Traveller's Tales
# Rating                                            E10+
# Name: 5496, dtype: object
#
# Index: 5572, Ligne complète:
# Rank                        2175
# Name            Wheel of Fortune
# Platform                     PS2
# Year                         NaN
# Genre                       Misc
# Publisher                Unknown
# NA_Sales                    0.47
# EU_Sales                    0.36
# JP_Sales                     0.0
# Other_Sales                 0.12
# Global_Sales                0.95
# Critic_Score                 NaN
# Critic_Count                 NaN
# User_Score                   NaN
# User_Count                   NaN
# Developer                    NaN
# Rating                       NaN
# Name: 5572, dtype: object
#
# Index: 5894, Ligne complète:
# Rank                    2288
# Name            Namco Museum
# Platform                  XB
# Year                     NaN
# Genre                   Misc
# Publisher            Unknown
# NA_Sales                0.77
# EU_Sales                0.11
# JP_Sales                 0.0
# Other_Sales             0.04
# Global_Sales            0.91
# Critic_Score            79.0
# Critic_Count            10.0
# User_Score               7.3
# User_Count               6.0
# Developer         Mass Media
# Rating                     E
# Name: 5894, dtype: object
#
# Index: 5928, Ligne complète:
# Rank                     2297
# Name            Rhythm Heaven
# Platform                  Wii
# Year                      NaN
# Genre                    Misc
# Publisher             Unknown
# NA_Sales                 0.13
# EU_Sales                  0.0
# JP_Sales                 0.77
# Other_Sales              0.01
# Global_Sales              0.9
# Critic_Score             83.0
# Critic_Count             48.0
# User_Score                  9
# User_Count               63.0
# Developer            Nintendo
# Rating                      E
# Name: 5928, dtype: object
#
# Index: 6222, Ligne complète:
# Rank                                               2417
# Name            The Lord of the Rings: War in the North
# Platform                                            PS3
# Year                                                NaN
# Genre                                            Action
# Publisher        Warner Bros. Interactive Entertainment
# NA_Sales                                           0.25
# EU_Sales                                           0.45
# JP_Sales                                           0.01
# Other_Sales                                        0.15
# Global_Sales                                       0.86
# Critic_Score                                       61.0
# Critic_Count                                       48.0
# User_Score                                          7.4
# User_Count                                        113.0
# Developer                             Snowblind Studios
# Rating                                                M
# Name: 6222, dtype: object
#
# Index: 6235, Ligne complète:
# Rank                                               2424
# Name            The Lord of the Rings: War in the North
# Platform                                           X360
# Year                                                NaN
# Genre                                            Action
# Publisher        Warner Bros. Interactive Entertainment
# NA_Sales                                           0.52
# EU_Sales                                           0.26
# JP_Sales                                            0.0
# Other_Sales                                        0.08
# Global_Sales                                       0.86
# Critic_Score                                       61.0
# Critic_Count                                       48.0
# User_Score                                          7.4
# User_Count                                        113.0
# Developer                             Snowblind Studios
# Rating                                                M
# Name: 6235, dtype: object
#
# Index: 6408, Ligne complète:
# Rank                     2486
# Name            Madden NFL 07
# Platform                  PSP
# Year                      NaN
# Genre                  Sports
# Publisher             Unknown
# NA_Sales                 0.77
# EU_Sales                 0.03
# JP_Sales                  0.0
# Other_Sales              0.04
# Global_Sales             0.83
# Critic_Score             84.0
# Critic_Count             29.0
# User_Score                8.2
# User_Count               39.0
# Developer           EA Sports
# Rating                      E
# Name: 6408, dtype: object
#
# Index: 6436, Ligne complète:
# Rank                          2499
# Name            MLB SlugFest 20-03
# Platform                       PS2
# Year                           NaN
# Genre                       Sports
# Publisher                  Unknown
# NA_Sales                      0.41
# EU_Sales                      0.32
# JP_Sales                       0.0
# Other_Sales                   0.11
# Global_Sales                  0.83
# Critic_Score                  77.0
# Critic_Count                  25.0
# User_Score                     8.2
# User_Count                     6.0
# Developer                   Midway
# Rating                           E
# Name: 6436, dtype: object
#
# Index: 6517, Ligne complète:
# Rank                                2530
# Name            Shaun White Snowboarding
# Platform                            X360
# Year                                 NaN
# Genre                             Sports
# Publisher                        Ubisoft
# NA_Sales                            0.48
# EU_Sales                            0.26
# JP_Sales                             0.0
# Other_Sales                         0.08
# Global_Sales                        0.82
# Critic_Score                        60.0
# Critic_Count                        48.0
# User_Score                           7.6
# User_Count                          25.0
# Developer               Ubisoft Montreal
# Rating                                 T
# Name: 6517, dtype: object
#
# Index: 6671, Ligne complète:
# Rank                                      2588
# Name            PES 2009: Pro Evolution Soccer
# Platform                                   PSP
# Year                                       NaN
# Genre                                   Sports
# Publisher         Konami Digital Entertainment
# NA_Sales                                  0.04
# EU_Sales                                  0.33
# JP_Sales                                  0.26
# Other_Sales                               0.17
# Global_Sales                               0.8
# Critic_Score                               NaN
# Critic_Count                               NaN
# User_Score                                 NaN
# User_Count                                 NaN
# Developer                                  NaN
# Rating                                     NaN
# Name: 6671, dtype: object
#
# Index: 7180, Ligne complète:
# Rank                     2778
# Name            Madden NFL 11
# Platform                  Wii
# Year                      NaN
# Genre                  Sports
# Publisher             Unknown
# NA_Sales                  0.7
# EU_Sales                  0.0
# JP_Sales                  0.0
# Other_Sales              0.05
# Global_Sales             0.74
# Critic_Score             84.0
# Critic_Count             47.0
# User_Score                5.7
# User_Count              120.0
# Developer          EA Tiburon
# Rating                      E
# Name: 7180, dtype: object
#
# Index: 7204, Ligne complète:
# Rank                           2788
# Name            WarioWare: Twisted!
# Platform                        GBA
# Year                            NaN
# Genre                        Puzzle
# Publisher                   Unknown
# NA_Sales                       0.16
# EU_Sales                       0.06
# JP_Sales                        0.5
# Other_Sales                    0.02
# Global_Sales                   0.74
# Critic_Score                    NaN
# Critic_Count                    NaN
# User_Score                      NaN
# User_Count                      NaN
# Developer                       NaN
# Rating                          NaN
# Name: 7204, dtype: object
#
# Index: 7345, Ligne complète:
# Rank                                              2840
# Name                      LEGO Harry Potter: Years 5-7
# Platform                                            DS
# Year                                               NaN
# Genre                                           Action
# Publisher       Warner Bros. Interactive Entertainment
# NA_Sales                                          0.35
# EU_Sales                                           0.3
# JP_Sales                                           0.0
# Other_Sales                                       0.07
# Global_Sales                                      0.72
# Critic_Score                                      76.0
# Critic_Count                                       8.0
# User_Score                                         7.8
# User_Count                                        13.0
# Developer                            Traveller's Tales
# Rating                                            E10+
# Name: 7345, dtype: object
#
# Index: 7638, Ligne complète:
# Rank                              2949
# Name            Test Drive Unlimited 2
# Platform                          X360
# Year                               NaN
# Genre                           Racing
# Publisher                        Atari
# NA_Sales                           0.3
# EU_Sales                          0.32
# JP_Sales                           0.0
# Other_Sales                       0.07
# Global_Sales                      0.69
# Critic_Score                      68.0
# Critic_Count                      61.0
# User_Score                         6.4
# User_Count                        87.0
# Developer                         Eden
# Rating                               T
# Name: 7638, dtype: object
#
# Index: 7903, Ligne complète:
# Rank                                                         3051
# Name            The Chronicles of Narnia: The Lion, The Witch ...
# Platform                                                      GBA
# Year                                                          NaN
# Genre                                                      Action
# Publisher                              Disney Interactive Studios
# NA_Sales                                                     0.48
# EU_Sales                                                     0.18
# JP_Sales                                                      0.0
# Other_Sales                                                  0.01
# Global_Sales                                                 0.67
# Critic_Score                                                 66.0
# Critic_Count                                                  7.0
# User_Score                                                    6.8
# User_Count                                                    5.0
# Developer                                     Amaze Entertainment
# Rating                                                          E
# Name: 7903, dtype: object
#
# Index: 8154, Ligne complète:
# Rank                              3143
# Name            Test Drive Unlimited 2
# Platform                           PS3
# Year                               NaN
# Genre                           Racing
# Publisher                        Atari
# NA_Sales                          0.16
# EU_Sales                          0.35
# JP_Sales                          0.01
# Other_Sales                       0.12
# Global_Sales                      0.64
# Critic_Score                      68.0
# Critic_Count                      61.0
# User_Score                         6.4
# User_Count                        87.0
# Developer                         Eden
# Rating                               T
# Name: 8154, dtype: object
#
# Index: 8310, Ligne complète:
# Rank                        3196
# Name            Monster Hunter 2
# Platform                     PS2
# Year                         NaN
# Genre               Role-Playing
# Publisher                 Capcom
# NA_Sales                     0.0
# EU_Sales                     0.0
# JP_Sales                    0.63
# Other_Sales                  0.0
# Global_Sales                0.63
# Critic_Score                 NaN
# Critic_Count                 NaN
# User_Score                   NaN
# User_Count                   NaN
# Developer                    NaN
# Rating                       NaN
# Name: 8310, dtype: object
#
# Index: 8374, Ligne complète:
# Rank                                  3219
# Name            Advance Wars: Days of Ruin
# Platform                                DS
# Year                                   NaN
# Genre                             Strategy
# Publisher                         Nintendo
# NA_Sales                              0.44
# EU_Sales                              0.13
# JP_Sales                               0.0
# Other_Sales                           0.06
# Global_Sales                          0.63
# Critic_Score                          86.0
# Critic_Count                          55.0
# User_Score                             8.7
# User_Count                            96.0
# Developer              Intelligent Systems
# Rating                                E10+
# Name: 8374, dtype: object
#
# Index: 8424, Ligne complète:
# Rank                                     3240
# Name            Metal Gear Solid 2: Substance
# Platform                                   XB
# Year                                      NaN
# Genre                                  Action
# Publisher        Konami Digital Entertainment
# NA_Sales                                 0.38
# EU_Sales                                 0.22
# JP_Sales                                  0.0
# Other_Sales                              0.03
# Global_Sales                             0.62
# Critic_Score                             87.0
# Critic_Count                             28.0
# User_Score                                8.5
# User_Count                               39.0
# Developer                                KCEJ
# Rating                                      M
# Name: 8424, dtype: object
#
# Index: 8705, Ligne complète:
# Rank                                    3348
# Name                      The Golden Compass
# Platform                                 Wii
# Year                                     NaN
# Genre                                 Action
# Publisher                               Sega
# NA_Sales                                0.26
# EU_Sales                                0.28
# JP_Sales                                 0.0
# Other_Sales                             0.07
# Global_Sales                             0.6
# Critic_Score                            43.0
# Critic_Count                             7.0
# User_Score                               4.9
# User_Count                               8.0
# Developer       Artificial Mind and Movement
# Rating                                  E10+
# Name: 8705, dtype: object
#
# Index: 8909, Ligne complète:
# Rank                       3423
# Name              Madden NFL 06
# Platform                   X360
# Year                        NaN
# Genre                    Sports
# Publisher       Electronic Arts
# NA_Sales                   0.54
# EU_Sales                    0.0
# JP_Sales                   0.01
# Other_Sales                0.03
# Global_Sales               0.59
# Critic_Score               88.0
# Critic_Count               29.0
# User_Score                    8
# User_Count                121.0
# Developer             EA Sports
# Rating                        E
# Name: 8909, dtype: object
#
# Index: 9039, Ligne complète:
# Rank                               3470
# Name            NASCAR: Dirt to Daytona
# Platform                            PS2
# Year                                NaN
# Genre                            Racing
# Publisher                       Unknown
# NA_Sales                           0.28
# EU_Sales                           0.22
# JP_Sales                            0.0
# Other_Sales                        0.07
# Global_Sales                       0.58
# Critic_Score                       84.0
# Critic_Count                       10.0
# User_Score                          8.8
# User_Count                         19.0
# Developer            Monster Games Inc.
# Rating                                E
# Name: 9039, dtype: object
#
# Index: 9101, Ligne complète:
# Rank                       3503
# Name            Madden NFL 2002
# Platform                     XB
# Year                        NaN
# Genre                    Sports
# Publisher               Unknown
# NA_Sales                   0.53
# EU_Sales                   0.02
# JP_Sales                    0.0
# Other_Sales                0.03
# Global_Sales               0.58
# Critic_Score               94.0
# Critic_Count               23.0
# User_Score                  7.9
# User_Count                 46.0
# Developer             EA Sports
# Rating                        E
# Name: 9101, dtype: object
#
# Index: 9639, Ligne complète:
# Rank                             3717
# Name            Def Jam: Fight for NY
# Platform                           XB
# Year                              NaN
# Genre                        Fighting
# Publisher             Electronic Arts
# NA_Sales                         0.43
# EU_Sales                          0.1
# JP_Sales                          0.0
# Other_Sales                      0.02
# Global_Sales                     0.54
# Critic_Score                     83.0
# Critic_Count                     46.0
# User_Score                        8.9
# User_Count                       73.0
# Developer                   Aki Corp.
# Rating                              M
# Name: 9639, dtype: object
#
# Index: 9730, Ligne complète:
# Rank                         3755
# Name            NBA Street Vol. 2
# Platform                       GC
# Year                          NaN
# Genre                      Sports
# Publisher         Electronic Arts
# NA_Sales                     0.41
# EU_Sales                     0.11
# JP_Sales                      0.0
# Other_Sales                  0.01
# Global_Sales                 0.54
# Critic_Score                 90.0
# Critic_Count                 31.0
# User_Score                    8.8
# User_Count                   70.0
# Developer         Electronic Arts
# Rating                          E
# Name: 9730, dtype: object
#
# Index: 10048, Ligne complète:
# Rank                     3882
# Name            Fishing Derby
# Platform                 2600
# Year                      NaN
# Genre                  Sports
# Publisher          Activision
# NA_Sales                 0.48
# EU_Sales                 0.03
# JP_Sales                  0.0
# Other_Sales              0.01
# Global_Sales             0.51
# Critic_Score              NaN
# Critic_Count              NaN
# User_Score                NaN
# User_Count                NaN
# Developer                 NaN
# Rating                    NaN
# Name: 10048, dtype: object
#
# Index: 10234, Ligne complète:
# Rank                                    3954
# Name                                     Wet
# Platform                                X360
# Year                                     NaN
# Genre                                Shooter
# Publisher                 Bethesda Softworks
# NA_Sales                                0.23
# EU_Sales                                0.21
# JP_Sales                                0.01
# Other_Sales                             0.05
# Global_Sales                             0.5
# Critic_Score                            70.0
# Critic_Count                            61.0
# User_Score                               6.4
# User_Count                              55.0
# Developer       Artificial Mind and Movement
# Rating                                     M
# Name: 10234, dtype: object
#
# Index: 10770, Ligne complète:
# Rank                          4147
# Name            Sonic the Hedgehog
# Platform                       PS3
# Year                           NaN
# Genre                     Platform
# Publisher                      NaN
# NA_Sales                       0.0
# EU_Sales                      0.48
# JP_Sales                       0.0
# Other_Sales                    0.0
# Global_Sales                  0.48
# Critic_Score                   NaN
# Critic_Count                   NaN
# User_Score                     NaN
# User_Count                     NaN
# Developer                      NaN
# Rating                         NaN
# Name: 10770, dtype: object
#
# Index: 10780, Ligne complète:
# Rank                   4153
# Name                 Karate
# Platform               2600
# Year                    NaN
# Genre              Fighting
# Publisher       Ultravision
# NA_Sales               0.44
# EU_Sales               0.03
# JP_Sales                0.0
# Other_Sales             0.0
# Global_Sales           0.47
# Critic_Score            NaN
# Critic_Count            NaN
# User_Score              NaN
# User_Count              NaN
# Developer               NaN
# Rating                  NaN
# Name: 10780, dtype: object
#
# Index: 10889, Ligne complète:
# Rank                               4201
# Name            Tiger Woods PGA Tour 07
# Platform                            Wii
# Year                                NaN
# Genre                            Sports
# Publisher               Electronic Arts
# NA_Sales                           0.43
# EU_Sales                            0.0
# JP_Sales                            0.0
# Other_Sales                        0.04
# Global_Sales                       0.47
# Critic_Score                       79.0
# Critic_Count                       33.0
# User_Score                            6
# User_Count                          8.0
# Developer             EA Redwood Shores
# Rating                                E
# Name: 10889, dtype: object
#
# Index: 10969, Ligne complète:
# Rank                    4234
# Name            Circus Atari
# Platform                2600
# Year                     NaN
# Genre                 Action
# Publisher              Atari
# NA_Sales                0.43
# EU_Sales                0.03
# JP_Sales                 0.0
# Other_Sales              0.0
# Global_Sales            0.46
# Critic_Score             NaN
# Critic_Count             NaN
# User_Score               NaN
# User_Count               NaN
# Developer                NaN
# Rating                   NaN
# Name: 10969, dtype: object
#
# Index: 11218, Ligne complète:
# Rank                                                         4332
# Name            The Chronicles of Riddick: Escape from Butcher...
# Platform                                                       XB
# Year                                                          NaN
# Genre                                                     Shooter
# Publisher                                           Vivendi Games
# NA_Sales                                                     0.32
# EU_Sales                                                     0.11
# JP_Sales                                                      0.0
# Other_Sales                                                  0.02
# Global_Sales                                                 0.45
# Critic_Score                                                 89.0
# Critic_Count                                                 84.0
# User_Score                                                    8.9
# User_Count                                                   85.0
# Developer                                              Starbreeze
# Rating                                                          M
# Name: 11218, dtype: object
#
# Index: 11344, Ligne complète:
# Rank                                             4380
# Name            Maze Craze: A Game of Cops 'n Robbers
# Platform                                         2600
# Year                                              NaN
# Genre                                          Action
# Publisher                                       Atari
# NA_Sales                                         0.42
# EU_Sales                                         0.02
# JP_Sales                                          0.0
# Other_Sales                                       0.0
# Global_Sales                                     0.45
# Critic_Score                                      NaN
# Critic_Count                                      NaN
# User_Score                                        NaN
# User_Count                                        NaN
# Developer                                         NaN
# Rating                                            NaN
# Name: 11344, dtype: object
#
# Index: 11347, Ligne complète:
# Rank                                    4382
# Name                 Silent Hill: Homecoming
# Platform                                X360
# Year                                     NaN
# Genre                                 Action
# Publisher       Konami Digital Entertainment
# NA_Sales                                0.25
# EU_Sales                                0.16
# JP_Sales                                 0.0
# Other_Sales                             0.04
# Global_Sales                            0.45
# Critic_Score                            70.0
# Critic_Count                            54.0
# User_Score                               6.9
# User_Count                             180.0
# Developer                 Double Helix Games
# Rating                                     M
# Name: 11347, dtype: object
#
# Index: 11559, Ligne complète:
# Rank                      4471
# Name            Super Breakout
# Platform                  2600
# Year                       NaN
# Genre                   Puzzle
# Publisher                Atari
# NA_Sales                  0.41
# EU_Sales                  0.03
# JP_Sales                   0.0
# Other_Sales                0.0
# Global_Sales              0.44
# Critic_Score               NaN
# Critic_Count               NaN
# User_Score                 NaN
# User_Count                 NaN
# Developer                  NaN
# Rating                     NaN
# Name: 11559, dtype: object
#
# Index: 11563, Ligne complète:
# Rank                                             4474
# Name            Robert Ludlum's The Bourne Conspiracy
# Platform                                         X360
# Year                                              NaN
# Genre                                          Action
# Publisher                               Vivendi Games
# NA_Sales                                         0.26
# EU_Sales                                         0.14
# JP_Sales                                          0.0
# Other_Sales                                      0.04
# Global_Sales                                     0.44
# Critic_Score                                     71.0
# Critic_Count                                     72.0
# User_Score                                        7.2
# User_Count                                       63.0
# Developer                           High Moon Studios
# Rating                                              T
# Name: 11563, dtype: object
#
# Index: 11722, Ligne complète:
# Rank                    4538
# Name            NHL Slapshot
# Platform                 Wii
# Year                     NaN
# Genre                 Sports
# Publisher            Unknown
# NA_Sales                 0.4
# EU_Sales                 0.0
# JP_Sales                 0.0
# Other_Sales             0.02
# Global_Sales            0.43
# Critic_Score            76.0
# Critic_Count            25.0
# User_Score               8.1
# User_Count               7.0
# Developer          EA Sports
# Rating                     E
# Name: 11722, dtype: object
#
# Index: 12086, Ligne complète:
# Rank                       4685
# Name                       TERA
# Platform                     PC
# Year                        NaN
# Genre              Role-Playing
# Publisher               Unknown
# NA_Sales                   0.24
# EU_Sales                   0.12
# JP_Sales                    0.0
# Other_Sales                0.05
# Global_Sales               0.41
# Critic_Score               77.0
# Critic_Count               41.0
# User_Score                  6.8
# User_Count                742.0
# Developer       Bluehole Studio
# Rating                        M
# Name: 12086, dtype: object
#
# Index: 12382, Ligne complète:
# Rank                                              4793
# Name                      LEGO Harry Potter: Years 5-7
# Platform                                           3DS
# Year                                               NaN
# Genre                                           Action
# Publisher       Warner Bros. Interactive Entertainment
# NA_Sales                                          0.18
# EU_Sales                                          0.19
# JP_Sales                                           0.0
# Other_Sales                                       0.04
# Global_Sales                                       0.4
# Critic_Score                                      76.0
# Critic_Count                                       8.0
# User_Score                                         7.8
# User_Count                                        13.0
# Developer                            Traveller's Tales
# Rating                                            E10+
# Name: 12382, dtype: object
#
# Index: 12410, Ligne complète:
# Rank                        4799
# Name            NFL GameDay 2003
# Platform                     PS2
# Year                         NaN
# Genre                     Sports
# Publisher                Unknown
# NA_Sales                     0.2
# EU_Sales                    0.15
# JP_Sales                     0.0
# Other_Sales                 0.05
# Global_Sales                 0.4
# Critic_Score                60.0
# Critic_Count                23.0
# User_Score                   tbd
# User_Count                   NaN
# Developer             989 Sports
# Rating                         E
# Name: 12410, dtype: object
#
# Index: 12575, Ligne complète:
# Rank                                    4860
# Name                 Silent Hill: Homecoming
# Platform                                 PS3
# Year                                     NaN
# Genre                                 Action
# Publisher       Konami Digital Entertainment
# NA_Sales                                0.18
# EU_Sales                                0.15
# JP_Sales                                 0.0
# Other_Sales                             0.06
# Global_Sales                             0.4
# Critic_Score                            70.0
# Critic_Count                            54.0
# User_Score                               6.9
# User_Count                             180.0
# Developer                 Double Helix Games
# Rating                                     M
# Name: 12575, dtype: object
#
# Index: 12591, Ligne complète:
# Rank                                       4867
# Name            Harvest Moon: Save the Homeland
# Platform                                    PS2
# Year                                        NaN
# Genre                                Simulation
# Publisher                               Unknown
# NA_Sales                                   0.19
# EU_Sales                                   0.15
# JP_Sales                                    0.0
# Other_Sales                                0.05
# Global_Sales                                0.4
# Critic_Score                               76.0
# Critic_Count                               14.0
# User_Score                                  8.8
# User_Count                                 72.0
# Developer           Victor Interactive Software
# Rating                                        E
# Name: 12591, dtype: object
#
# Index: 12774, Ligne complète:
# Rank                                             4936
# Name            Robert Ludlum's The Bourne Conspiracy
# Platform                                          PS3
# Year                                              NaN
# Genre                                          Action
# Publisher                               Vivendi Games
# NA_Sales                                         0.18
# EU_Sales                                         0.14
# JP_Sales                                          0.0
# Other_Sales                                      0.06
# Global_Sales                                     0.39
# Critic_Score                                     71.0
# Critic_Count                                     72.0
# User_Score                                        7.2
# User_Count                                       63.0
# Developer                           High Moon Studios
# Rating                                              T
# Name: 12774, dtype: object
#
# Index: 13082, Ligne complète:
# Rank               5063
# Name            Hangman
# Platform           2600
# Year                NaN
# Genre            Puzzle
# Publisher         Atari
# NA_Sales           0.35
# EU_Sales           0.02
# JP_Sales            0.0
# Other_Sales         0.0
# Global_Sales       0.38
# Critic_Score        NaN
# Critic_Count        NaN
# User_Score          NaN
# User_Count          NaN
# Developer           NaN
# Rating              NaN
# Name: 13082, dtype: object
#
# Index: 13118, Ligne complète:
# Rank                                    5080
# Name                      The Golden Compass
# Platform                                 PSP
# Year                                     NaN
# Genre                                 Action
# Publisher                               Sega
# NA_Sales                                0.11
# EU_Sales                                0.16
# JP_Sales                                 0.0
# Other_Sales                              0.1
# Global_Sales                            0.38
# Critic_Score                            43.0
# Critic_Count                             7.0
# User_Score                               4.9
# User_Count                               8.0
# Developer       Artificial Mind and Movement
# Rating                                  E10+
# Name: 13118, dtype: object
#
# Index: 13346, Ligne complète:
# Rank                       5164
# Name              NBA Live 2003
# Platform                     XB
# Year                        NaN
# Genre                    Sports
# Publisher       Electronic Arts
# NA_Sales                   0.31
# EU_Sales                   0.04
# JP_Sales                    0.0
# Other_Sales                0.01
# Global_Sales               0.36
# Critic_Score               83.0
# Critic_Count               22.0
# User_Score                  8.3
# User_Count                 28.0
# Developer             EA Canada
# Rating                        E
# Name: 13346, dtype: object
#
# Index: 13368, Ligne complète:
# Rank                   5173
# Name            Bejeweled 3
# Platform                 DS
# Year                    NaN
# Genre                Puzzle
# Publisher           Unknown
# NA_Sales               0.32
# EU_Sales               0.02
# JP_Sales                0.0
# Other_Sales            0.03
# Global_Sales           0.36
# Critic_Score           75.0
# Critic_Count            9.0
# User_Score              tbd
# User_Count              NaN
# Developer            PopCap
# Rating                    E
# Name: 13368, dtype: object
#
# Index: 13423, Ligne complète:
# Rank                                                 5197
# Name            Cubix Robots for Everyone: Clash 'n' Bash
# Platform                                              GBA
# Year                                                  NaN
# Genre                                              Action
# Publisher                                         Unknown
# NA_Sales                                             0.26
# EU_Sales                                              0.1
# JP_Sales                                              0.0
# Other_Sales                                          0.01
# Global_Sales                                         0.36
# Critic_Score                                          NaN
# Critic_Count                                          NaN
# User_Score                                            NaN
# User_Count                                            NaN
# Developer                                             NaN
# Rating                                                NaN
# Name: 13423, dtype: object
#
# Index: 13424, Ligne complète:
# Rank                     5198
# Name                Tropico 4
# Platform                 X360
# Year                      NaN
# Genre                Strategy
# Publisher       Kalypso Media
# NA_Sales                  0.2
# EU_Sales                 0.13
# JP_Sales                  0.0
# Other_Sales              0.03
# Global_Sales             0.36
# Critic_Score             77.0
# Critic_Count             18.0
# User_Score                7.5
# User_Count               37.0
# Developer           Haemimont
# Rating                      T
# Name: 13424, dtype: object
#
# Index: 13518, Ligne complète:
# Rank                          5242
# Name            Tomb Raider (2013)
# Platform                        PC
# Year                           NaN
# Genre                       Action
# Publisher              Square Enix
# NA_Sales                      0.06
# EU_Sales                      0.25
# JP_Sales                       0.0
# Other_Sales                   0.05
# Global_Sales                  0.36
# Critic_Score                   NaN
# Critic_Count                   NaN
# User_Score                     NaN
# User_Count                     NaN
# Developer                      NaN
# Rating                         NaN
# Name: 13518, dtype: object
#
# Index: 13652, Ligne complète:
# Rank                                                     5304
# Name            Dragon Ball Z: Budokai Tenkaichi 2 (JP sales)
# Platform                                                  Wii
# Year                                                      NaN
# Genre                                                  Action
# Publisher                                                 NaN
# NA_Sales                                                 0.15
# EU_Sales                                                 0.05
# JP_Sales                                                 0.14
# Other_Sales                                              0.01
# Global_Sales                                             0.35
# Critic_Score                                              NaN
# Critic_Count                                              NaN
# User_Score                                                NaN
# User_Count                                                NaN
# Developer                                                 NaN
# Rating                                                    NaN
# Name: 13652, dtype: object
#
# Index: 14148, Ligne complète:
# Rank                    5510
# Name             Custom Robo
# Platform                 N64
# Year                     NaN
# Genre           Role-Playing
# Publisher           Nintendo
# NA_Sales                 0.0
# EU_Sales                 0.0
# JP_Sales                0.29
# Other_Sales             0.04
# Global_Sales            0.33
# Critic_Score            65.0
# Critic_Count            31.0
# User_Score               8.1
# User_Count              27.0
# Developer         Noise Inc.
# Rating                     T
# Name: 14148, dtype: object
#
# Index: 14415, Ligne complète:
# Rank                        5620
# Name            Final Fantasy XI
# Platform                     PS2
# Year                         NaN
# Genre               Role-Playing
# Publisher                Unknown
# NA_Sales                    0.08
# EU_Sales                    0.06
# JP_Sales                    0.15
# Other_Sales                 0.02
# Global_Sales                0.32
# Critic_Score                85.0
# Critic_Count                49.0
# User_Score                   6.9
# User_Count                  66.0
# Developer            Square Enix
# Rating                         T
# Name: 14415, dtype: object
#
# Index: 14429, Ligne complète:
# Rank                      5627
# Name               Singularity
# Platform                  X360
# Year                       NaN
# Genre                  Shooter
# Publisher              Unknown
# NA_Sales                  0.24
# EU_Sales                  0.05
# JP_Sales                   0.0
# Other_Sales               0.02
# Global_Sales              0.32
# Critic_Score              76.0
# Critic_Count              70.0
# User_Score                 7.7
# User_Count               169.0
# Developer       Raven Software
# Rating                       M
# Name: 14429, dtype: object
#
# Index: 14495, Ligne complète:
# Rank                  5659
# Name              Dragster
# Platform              2600
# Year                   NaN
# Genre               Racing
# Publisher       Activision
# NA_Sales               0.3
# EU_Sales              0.02
# JP_Sales               0.0
# Other_Sales            0.0
# Global_Sales          0.32
# Critic_Score           NaN
# Critic_Count           NaN
# User_Score             NaN
# User_Count             NaN
# Developer              NaN
# Rating                 NaN
# Name: 14495, dtype: object
#
# Index: 14517, Ligne complète:
# Rank                              5671
# Name            All-Star Baseball 2005
# Platform                           PS2
# Year                               NaN
# Genre                           Sports
# Publisher                      Unknown
# NA_Sales                          0.16
# EU_Sales                          0.12
# JP_Sales                           0.0
# Other_Sales                       0.04
# Global_Sales                      0.32
# Critic_Score                      72.0
# Critic_Count                      13.0
# User_Score                         8.6
# User_Count                        21.0
# Developer                      Acclaim
# Rating                               E
# Name: 14517, dtype: object
#
# Index: 14732, Ligne complète:
# Rank                                              5771
# Name            Star Wars Jedi Knight II: Jedi Outcast
# Platform                                            XB
# Year                                               NaN
# Genre                                          Shooter
# Publisher                                   Activision
# NA_Sales                                          0.23
# EU_Sales                                          0.07
# JP_Sales                                           0.0
# Other_Sales                                       0.01
# Global_Sales                                      0.31
# Critic_Score                                      81.0
# Critic_Count                                      24.0
# User_Score                                         6.8
# User_Count                                        15.0
# Developer                            Vicarious Visions
# Rating                                               T
# Name: 14732, dtype: object
#
# Index: 14798, Ligne complète:
# Rank                    5800
# Name            Slot Machine
# Platform                2600
# Year                     NaN
# Genre                 Action
# Publisher              Atari
# NA_Sales                0.29
# EU_Sales                0.02
# JP_Sales                 0.0
# Other_Sales              0.0
# Global_Sales            0.31
# Critic_Score             NaN
# Critic_Count             NaN
# User_Score               NaN
# User_Count               NaN
# Developer                NaN
# Rating                   NaN
# Name: 14798, dtype: object
#
# Index: 14869, Ligne complète:
# Rank                       5840
# Name            Shrek the Third
# Platform                     DS
# Year                        NaN
# Genre                    Action
# Publisher            Activision
# NA_Sales                   0.26
# EU_Sales                   0.02
# JP_Sales                    0.0
# Other_Sales                0.02
# Global_Sales                0.3
# Critic_Score                NaN
# Critic_Count                NaN
# User_Score                  NaN
# User_Count                  NaN
# Developer                   NaN
# Rating                      NaN
# Name: 14869, dtype: object
#
# ...
# Genre                          Sports
# Publisher                        Sega
# NA_Sales                          0.0
# EU_Sales                         0.01
# JP_Sales                          0.0
# Other_Sales                       0.0
# Global_Sales                     0.02
# Critic_Score                      NaN
# Critic_Count                      NaN
# User_Score                        NaN
# User_Count                        NaN
# Developer                         NaN
# Rating                            NaN
# Name: 33868, dtype: object
#
# Index: 33994, Ligne complète:
# Rank                                   15814
# Name            Ferrari: The Race Experience
# Platform                                 Wii
# Year                                     NaN
# Genre                                 Racing
# Publisher           System 3 Arcade Software
# NA_Sales                                 0.0
# EU_Sales                                0.01
# JP_Sales                                 0.0
# Other_Sales                              0.0
# Global_Sales                            0.02
# Critic_Score                            54.0
# Critic_Count                             4.0
# User_Score                               NaN
# User_Count                               NaN
# Developer                           System 3
# Rating                                     E
# Name: 33994, dtype: object
#
# Index: 34078, Ligne complète:
# Rank                                        15868
# Name            PDC World Championship Darts 2008
# Platform                                       DS
# Year                                          NaN
# Genre                                      Sports
# Publisher                                 Unknown
# NA_Sales                                     0.01
# EU_Sales                                      0.0
# JP_Sales                                      0.0
# Other_Sales                                   0.0
# Global_Sales                                 0.02
# Critic_Score                                 51.0
# Critic_Count                                 18.0
# User_Score                                    5.4
# User_Count                                    7.0
# Developer                      Oxygen Interactive
# Rating                                       E10+
# Name: 34078, dtype: object
#
# Index: 34102, Ligne complète:
# Rank                                      15879
# Name            Dinotopia: The Sunstone Odyssey
# Platform                                     GC
# Year                                        NaN
# Genre                                    Action
# Publisher                               Unknown
# NA_Sales                                   0.01
# EU_Sales                                    0.0
# JP_Sales                                    0.0
# Other_Sales                                 0.0
# Global_Sales                               0.02
# Critic_Score                               50.0
# Critic_Count                                4.0
# User_Score                                  tbd
# User_Count                                  NaN
# Developer                         Vicious Cycle
# Rating                                        T
# Name: 34102, dtype: object
#
# Index: 34105, Ligne complète:
# Rank                             15881
# Name            Dance! It's Your Stage
# Platform                           Wii
# Year                               NaN
# Genre                             Misc
# Publisher            DTP Entertainment
# NA_Sales                           0.0
# EU_Sales                          0.01
# JP_Sales                           0.0
# Other_Sales                        0.0
# Global_Sales                      0.02
# Critic_Score                       NaN
# Critic_Count                       NaN
# User_Score                         NaN
# User_Count                         NaN
# Developer                          NaN
# Rating                             NaN
# Name: 34105, dtype: object
#
# Index: 34138, Ligne complète:
# Rank                  15903
# Name            Jet Impulse
# Platform                 DS
# Year                    NaN
# Genre            Simulation
# Publisher          Nintendo
# NA_Sales                0.0
# EU_Sales                0.0
# JP_Sales               0.02
# Other_Sales             0.0
# Global_Sales           0.02
# Critic_Score            NaN
# Critic_Count            NaN
# User_Score              NaN
# User_Count              NaN
# Developer               NaN
# Rating                  NaN
# Name: 34138, dtype: object
#
# Index: 34154, Ligne complète:
# Rank                                               15918
# Name                                        Dream Dancer
# Platform                                              DS
# Year                                                 NaN
# Genre                                               Misc
# Publisher                                            NaN
# NA_Sales                                            0.01
# EU_Sales                                             0.0
# JP_Sales                                             0.0
# Other_Sales                                          0.0
# Global_Sales                                        0.02
# Critic_Score                                         NaN
# Critic_Count                                         NaN
# User_Score                                           tbd
# User_Count                                           NaN
# Developer       CyberPlanet Interactive Public Co., Ltd.
# Rating                                                 E
# Name: 34154, dtype: object
#
# Index: 34359, Ligne complète:
# Rank                                        16060
# Name            PDC World Championship Darts 2008
# Platform                                      PSP
# Year                                          NaN
# Genre                                      Sports
# Publisher                      Oxygen Interactive
# NA_Sales                                     0.01
# EU_Sales                                      0.0
# JP_Sales                                      0.0
# Other_Sales                                   0.0
# Global_Sales                                 0.01
# Critic_Score                                 51.0
# Critic_Count                                 18.0
# User_Score                                    5.4
# User_Count                                    7.0
# Developer                      Oxygen Interactive
# Rating                                       E10+
# Name: 34359, dtype: object
#
# Index: 34362, Ligne complète:
# Rank                                        16061
# Name            WRC: FIA World Rally Championship
# Platform                                       PC
# Year                                          NaN
# Genre                                      Racing
# Publisher                        Black Bean Games
# NA_Sales                                      0.0
# EU_Sales                                     0.01
# JP_Sales                                      0.0
# Other_Sales                                   0.0
# Global_Sales                                 0.01
# Critic_Score                                 68.0
# Critic_Count                                 24.0
# User_Score                                    4.5
# User_Count                                    4.0
# Developer                         Milestone S.r.l
# Rating                                        NaN
# Name: 34362, dtype: object
#
# Index: 34377, Ligne complète:
# Rank                                   16068
# Name            Aquaman: Battle for Atlantis
# Platform                                  XB
# Year                                     NaN
# Genre                                 Action
# Publisher                            Unknown
# NA_Sales                                0.01
# EU_Sales                                 0.0
# JP_Sales                                 0.0
# Other_Sales                              0.0
# Global_Sales                            0.01
# Critic_Score                            26.0
# Critic_Count                            13.0
# User_Score                               2.7
# User_Count                              15.0
# Developer                      Lucky Chicken
# Rating                                     T
# Name: 34377, dtype: object
#
# Index: 34569, Ligne complète:
# Rank                                      16194
# Name            Homeworld Remastered Collection
# Platform                                     PC
# Year                                        NaN
# Genre                                  Strategy
# Publisher                                   NaN
# NA_Sales                                    0.0
# EU_Sales                                   0.01
# JP_Sales                                    0.0
# Other_Sales                                 0.0
# Global_Sales                               0.01
# Critic_Score                               86.0
# Critic_Count                               49.0
# User_Score                                  8.2
# User_Count                                324.0
# Developer                      Gearbox Software
# Rating                                     E10+
# Name: 34569, dtype: object
#
# Index: 34574, Ligne complète:
# Rank                                   16197
# Name                                  Shorts
# Platform                                  DS
# Year                                     NaN
# Genre                               Platform
# Publisher                            Unknown
# NA_Sales                                0.01
# EU_Sales                                 0.0
# JP_Sales                                 0.0
# Other_Sales                              0.0
# Global_Sales                            0.01
# Critic_Score                             NaN
# Critic_Count                             NaN
# User_Score                               tbd
# User_Count                               NaN
# Developer       Artificial Mind and Movement
# Rating                                  E10+
# Name: 34574, dtype: object
#
# Index: 34578, Ligne complète:
# Rank                                             16201
# Name            AKB1/48: Idol to Guam de Koishitara...
# Platform                                          X360
# Year                                               NaN
# Genre                                             Misc
# Publisher                                          NaN
# NA_Sales                                           0.0
# EU_Sales                                           0.0
# JP_Sales                                          0.01
# Other_Sales                                        0.0
# Global_Sales                                      0.01
# Critic_Score                                       NaN
# Critic_Count                                       NaN
# User_Score                                         NaN
# User_Count                                         NaN
# Developer                                          NaN
# Rating                                             NaN
# Name: 34578, dtype: object
#
# Index: 34626, Ligne complète:
# Rank                                  16232
# Name            Brothers in Arms: Furious 4
# Platform                               X360
# Year                                    NaN
# Genre                               Shooter
# Publisher                               NaN
# NA_Sales                               0.01
# EU_Sales                                0.0
# JP_Sales                                0.0
# Other_Sales                             0.0
# Global_Sales                           0.01
# Critic_Score                            NaN
# Critic_Count                            NaN
# User_Score                              NaN
# User_Count                              NaN
# Developer                  Gearbox Software
# Rating                                    M
# Name: 34626, dtype: object
#
# Index: 34657, Ligne complète:
# Rank                                   16249
# Name            Agarest Senki: Re-appearance
# Platform                                 PS3
# Year                                     NaN
# Genre                           Role-Playing
# Publisher                       Idea Factory
# NA_Sales                                 0.0
# EU_Sales                                 0.0
# JP_Sales                                0.01
# Other_Sales                              0.0
# Global_Sales                            0.01
# Critic_Score                             NaN
# Critic_Count                             NaN
# User_Score                               NaN
# User_Count                               NaN
# Developer                                NaN
# Rating                                   NaN
# Name: 34657, dtype: object
#
# Index: 34740, Ligne complète:
# Rank                                 16310
# Name                         Freaky Flyers
# Platform                                GC
# Year                                   NaN
# Genre                               Racing
# Publisher                          Unknown
# NA_Sales                              0.01
# EU_Sales                               0.0
# JP_Sales                               0.0
# Other_Sales                            0.0
# Global_Sales                          0.01
# Critic_Score                          66.0
# Critic_Count                          20.0
# User_Score                             tbd
# User_Count                             NaN
# Developer       Midway Studios - San Diego
# Rating                                   T
# Name: 34740, dtype: object
#
# Index: 34765, Ligne complète:
# Rank                         16330
# Name                     Inversion
# Platform                        PC
# Year                           NaN
# Genre                      Shooter
# Publisher       Namco Bandai Games
# NA_Sales                      0.01
# EU_Sales                       0.0
# JP_Sales                       0.0
# Other_Sales                    0.0
# Global_Sales                  0.01
# Critic_Score                  56.0
# Critic_Count                  23.0
# User_Score                     5.4
# User_Count                    43.0
# Developer        Saber Interactive
# Rating                           M
# Name: 34765, dtype: object
#
# Index: 34828, Ligne complète:
# Rank                                  16369
# Name            Hakuouki: Shinsengumi Kitan
# Platform                                PS3
# Year                                    NaN
# Genre                             Adventure
# Publisher                           Unknown
# NA_Sales                               0.01
# EU_Sales                                0.0
# JP_Sales                                0.0
# Other_Sales                             0.0
# Global_Sales                           0.01
# Critic_Score                            NaN
# Critic_Count                            NaN
# User_Score                              NaN
# User_Count                              NaN
# Developer                               NaN
# Rating                                  NaN
# Name: 34828, dtype: object
#
# Index: 34932, Ligne complète:
# Rank                                   16430
# Name                            Virtua Quest
# Platform                                  GC
# Year                                     NaN
# Genre                           Role-Playing
# Publisher                            Unknown
# NA_Sales                                0.01
# EU_Sales                                 0.0
# JP_Sales                                 0.0
# Other_Sales                              0.0
# Global_Sales                            0.01
# Critic_Score                            53.0
# Critic_Count                            17.0
# User_Score                               7.6
# User_Count                               5.0
# Developer       Artificial Mind and Movement
# Rating                                     T
# Name: 34932, dtype: object
#
# Index: 35034, Ligne complète:
# Rank                 16496
# Name            The Smurfs
# Platform               3DS
# Year                   NaN
# Genre               Action
# Publisher          Unknown
# NA_Sales               0.0
# EU_Sales              0.01
# JP_Sales               0.0
# Other_Sales            0.0
# Global_Sales          0.01
# Critic_Score           NaN
# Critic_Count           NaN
# User_Score             tbd
# User_Count             NaN
# Developer         Land Ho!
# Rating                   E
# Name: 35034, dtype: object

# %%
# Tri par valeurs et par ordre croissant de Year

dfvg['Year'].value_counts().sort_index()
# Out:
# Year
# 1977.0       2
# 1978.0       2
# 1980.0      14
# 1981.0      47
# 1982.0      37
# 1983.0      17
# 1984.0      14
# 1985.0      14
# 1986.0      21
# 1987.0      16
# 1988.0      15
# 1989.0      17
# 1990.0      16
# 1991.0      41
# 1992.0      43
# 1993.0      60
# 1994.0     121
# 1995.0     219
# 1996.0     263
# 1997.0     290
# 1998.0     380
# 1999.0     340
# 2000.0     349
# 2001.0     485
# 2002.0     839
# 2003.0     779
# 2004.0     766
# 2005.0     945
# 2006.0    1013
# 2007.0    1209
# 2008.0    1437
# 2009.0    1434
# 2010.0    1264
# 2011.0    1150
# 2012.0     658
# 2013.0     547
# 2014.0     582
# 2015.0     614
# 2016.0     344
# 2017.0       3
# 2020.0       1
# Name: count, dtype: int64

# %% [markdown]
# # Data Viz' de vgsales

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# COUNPLOT
# Nombre de jeux par Genre

plt.figure(figsize = (12, 6))

sns.countplot(x = 'Genre', data = dfvg)

plt.xlabel('Genre')
plt.ylabel('Nombre de jeux')
plt.title('Nombre de jeux par genre')

plt.show()

# %%
# BOXPLOT
# Nombre de jeux par Année

plt.figure(figsize = (10, 6))

sns.boxplot(x = "Year", data = dfvg)

plt.xlabel('Années')
plt.ylabel('Nombre de jeux')
plt.title('Nombre de jeux par année')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# STRIP PLOT
# Ventes Globales par Année

plt.figure(figsize = (10, 6))

sns.catplot(x = "Genre", y = "Global_Sales", data = dfvg)
plt.xticks(rotation = 45)

plt.xlabel('Genre')
plt.ylabel('Ventes Globales')
plt.title('Ventes Globales par Genre')

plt.show()

# %%
# sns.pairplot(dfvg)

# Environ une minute pour s'exécuter

# %%
# BOXENPLOT
# Score des Critiques par Genre

sns.boxenplot(x = "Genre", y = "Critic_Score", data = dfvg)

plt.xlabel('Genre')
plt.ylabel('Score des Critiques')
plt.xticks(rotation = 45)
plt.yticks(range(0, 101, 10))
plt.title('Score des Critiques par Genre')

plt.show()

# %%
# CORRELATION
# Visualisation sur les relations entre le score des critiques et le ventes

# %% [markdown]
# # Test Téléchargement du merge

# %%
# Test du téléchargement/de l'exportation du merge

# from google.colab import files
# dfvg.to_csv('mergetest.csv')
# files.download('mergetest.csv')

# %% [markdown]
# # Import du merge (cleanfusion) de vgsales.csv et de all_video_games.csv

# %%
# Import du merge de vgsales et all_video_games
# Le fichier all_video_games.csv provient de Kaggle
# URL : https://www.kaggle.com/datasets/beridzeg45/video-games

cleanfusion = pd.read_csv("cleanfusion.csv")
cleanfusion.head()
# Out:
#    Unnamed: 0  Rank                      Name Platform    Year         Genre  \
# 0           0     1                Wii Sports      Wii  2006.0        Sports
# 1           1     2         Super Mario Bros.      NES  1985.0      Platform
# 2           2     3            Mario Kart Wii      Wii  2008.0        Racing
# 3           3     4         Wii Sports Resort      Wii  2009.0        Sports
# 4           4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing
#
#   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0  Nintendo     41.49     29.02      3.77         8.46         82.74
# 1  Nintendo     29.08      3.58      6.81         0.77         40.24
# 2  Nintendo     15.85     12.88      3.79         3.31         35.82
# 3  Nintendo     15.75     11.01      3.28         2.96         33.00
# 4  Nintendo     11.27      8.89     10.22         1.00         31.37
#
#   Developer  User_Score  User_Count Rating
# 0  Nintendo         7.9       474.0      E
# 1  Nintendo         8.3       138.0      E
# 2  Nintendo         8.6      1073.0      E
# 3  Nintendo         8.4       334.0      E
# 4       NaN         NaN         NaN    NaN

# %%
cleanfusion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    16598 non-null  int64
#  1   Rank          16598 non-null  int64
#  2   Name          16598 non-null  object
#  3   Platform      16598 non-null  object
#  4   Year          16327 non-null  float64
#  5   Genre         16598 non-null  object
#  6   Publisher     16540 non-null  object
#  7   NA_Sales      16598 non-null  float64
#  8   EU_Sales      16598 non-null  float64
#  9   JP_Sales      16598 non-null  float64
#  10  Other_Sales   16598 non-null  float64
#  11  Global_Sales  16598 non-null  float64
#  12  Developer     7538 non-null   object
#  13  User_Score    6498 non-null   float64
#  14  User_Count    6215 non-null   float64
#  15  Rating        7463 non-null   object
# dtypes: float64(8), int64(2), object(6)
# memory usage: 2.0+ MB

# %%
cleanfusion.isna().sum()
# Out:
# Unnamed: 0          0
# Rank                0
# Name                0
# Platform            0
# Year              271
# Genre               0
# Publisher          58
# NA_Sales            0
# EU_Sales            0
# JP_Sales            0
# Other_Sales         0
# Global_Sales        0
# Developer        9060
# User_Score      10100
# User_Count      10383
# Rating           9135
# dtype: int64

# %% [markdown]
# # Fusion et nettoyage de dfvg (vgsales) et cleanfusion (all_video_games)

# %%
# Fusionner dfvg et cleanfusion sur la colonne Name avec des suffixes personnalisés

cf_merged = pd.merge(dfvg, cleanfusion, on='Name', how='outer', suffixes=('_dfvg', '_cleanfusion'))

# Liste des colonnes dupliquées à combiner

columns_to_combine = ["Platform", "Year", "Genre", "Publisher", "NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales", "Global_Sales", "Developer", "User_Score", "User_Count", "Rating"]  # Ajout de toutes les colonnes à vérifier

for col in columns_to_combine:
    # Combiner les colonnes dupliquées
    cf_merged[col] = cf_merged[f"{col}_dfvg"].combine_first(cf_merged[f"{col}_cleanfusion"])
    # Supprimer les colonnes dupliquées après combinaison
    cf_merged.drop(columns=[f"{col}_dfvg", f"{col}_cleanfusion"], inplace=True)

cf_merged = cf_merged.sort_values(by='Rank_dfvg')
cf_merged.head()
# Out:
#    Rank_dfvg               Name  Critic_Score  Critic_Count  Unnamed: 0  \
# 0          1         Wii Sports          76.0          51.0           0
# 1          2  Super Mario Bros.           NaN           NaN           1
# 2          2  Super Mario Bros.           NaN           NaN         200
# 5          3     Mario Kart Wii          82.0          73.0           2
# 6          4  Wii Sports Resort          80.0          73.0           3
#
#    Rank_cleanfusion Platform    Year     Genre Publisher  NA_Sales  EU_Sales  \
# 0                 1      Wii  2006.0    Sports  Nintendo     41.49     29.02
# 1                 2      NES  1985.0  Platform  Nintendo     29.08      3.58
# 2               201      NES  1985.0  Platform  Nintendo     29.08      3.58
# 5                 3      Wii  2008.0    Racing  Nintendo     15.85     12.88
# 6                 4      Wii  2009.0    Sports  Nintendo     15.75     11.01
#
#    JP_Sales  Other_Sales  Global_Sales Developer User_Score  User_Count Rating
# 0      3.77         8.46         82.74  Nintendo          8       322.0      E
# 1      6.81         0.77         40.24  Nintendo        8.3       138.0      E
# 2      6.81         0.77         40.24  Nintendo        8.3       138.0      E
# 5      3.79         3.31         35.82  Nintendo        8.3       709.0      E
# 6      3.28         2.96         33.00  Nintendo          8       192.0      E

# %%
print(cf_merged.info())
print("--------------------------------")
print(cf_merged.isna().sum())
print("--------------------------------")
print(cf_merged.duplicated().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35228 entries, 0 to 34511
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Rank_dfvg         35228 non-null  int64
#  1   Name              35228 non-null  object
#  2   Critic_Score      21684 non-null  float64
#  3   Critic_Count      21684 non-null  float64
#  4   Unnamed: 0        35228 non-null  int64
#  5   Rank_cleanfusion  35228 non-null  int64
#  6   Platform          35228 non-null  object
#  7   Year              34977 non-null  float64
#  8   Genre             35228 non-null  object
#  9   Publisher         35173 non-null  object
#  10  NA_Sales          35228 non-null  float64
#  11  EU_Sales          35228 non-null  float64
#  12  JP_Sales          35228 non-null  float64
#  13  Other_Sales       35228 non-null  float64
#  14  Global_Sales      35228 non-null  float64
#  15  Developer         26762 non-null  object
#  16  User_Score        26560 non-null  object
#  17  User_Count        22798 non-null  float64
#  18  Rating            26572 non-null  object
# dtypes: float64(9), int64(3), object(7)
# memory usage: 5.4+ MB
# None
# --------------------------------
# Rank_dfvg               0
# Name                    0
# Critic_Score        13544
# Critic_Count        13544
# Unnamed: 0              0
# Rank_cleanfusion        0
# Platform                0
# Year                  251
# Genre                   0
# Publisher              55
# NA_Sales                0
# EU_Sales                0
# JP_Sales                0
# Other_Sales             0
# Global_Sales            0
# Developer            8466
# User_Score           8668
# User_Count          12430
# Rating               8656
# dtype: int64
# --------------------------------
# 0

# %%
# Supprimer les doublons et conserver la première occurrence basés sur les colonnes Name, Platform et Year

cf_unique = cf_merged.drop_duplicates(subset=['Name', 'Platform', 'Year'], keep='first')
print(cf_unique)
# Out:
#        Rank_dfvg                                              Name  \
# 0              1                                        Wii Sports
# 1              2                                 Super Mario Bros.
# 5              3                                    Mario Kart Wii
# 6              4                                 Wii Sports Resort
# 7              5                          Pokemon Red/Pokemon Blue
# ...          ...                                               ...
# 35226      16596                Woody Woodpecker in Crazy Castle 5
# 16953      16597                     Men in Black II: Alien Escape
# 27865      16598  SCORE International Baja 1000: The Official Game
# 35227      16599                                        Know How 2
# 34510      16600                                  Spirits & Spells
#
#        Critic_Score  Critic_Count  Unnamed: 0  Rank_cleanfusion Platform  \
# 0              76.0          51.0           0                 1      Wii
# 1               NaN           NaN           1                 2      NES
# 5              82.0          73.0           2                 3      Wii
# 6              80.0          73.0           3                 4      Wii
# 7               NaN           NaN           4                 5       GB
# ...             ...           ...         ...               ...      ...
# 35226           NaN           NaN       16593             16596      GBA
# 16953          50.0          19.0       16594             16597       GC
# 27865           NaN           NaN       10620             10622      PS2
# 35227           NaN           NaN       16596             16599       DS
# 34510           NaN           NaN       15675             15678      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0      2006.0        Sports    Nintendo     41.49     29.02      3.77
# 1      1985.0      Platform    Nintendo     29.08      3.58      6.81
# 5      2008.0        Racing    Nintendo     15.85     12.88      3.79
# 6      2009.0        Sports    Nintendo     15.75     11.01      3.28
# 7      1996.0  Role-Playing    Nintendo     11.27      8.89     10.22
# ...       ...           ...         ...       ...       ...       ...
# 35226  2002.0      Platform       Kemco      0.01      0.00      0.00
# 16953  2003.0       Shooter  Infogrames      0.01      0.00      0.00
# 27865  2008.0        Racing  Activision      0.00      0.00      0.00
# 35227  2010.0        Puzzle    7G//AMES      0.00      0.01      0.00
# 34510  2003.0      Platform     Wanadoo      0.01      0.00      0.00
#
#        Other_Sales  Global_Sales                 Developer User_Score  \
# 0             8.46         82.74                  Nintendo          8
# 1             0.77         40.24                  Nintendo        8.3
# 5             3.31         35.82                  Nintendo        8.3
# 6             2.96         33.00                  Nintendo          8
# 7             1.00         31.37                       NaN        NaN
# ...            ...           ...                       ...        ...
# 35226         0.00          0.01                       NaN        NaN
# 16953         0.00          0.01           Melbourne House        7.3
# 27865         0.00          0.01                       NaN        NaN
# 35227         0.00          0.01                       NaN        NaN
# 34510         0.00          0.01  DreamCatcher Interactive        NaN
#
#        User_Count Rating
# 0           322.0      E
# 1           138.0      E
# 5           709.0      E
# 6           192.0      E
# 7             NaN    NaN
# ...           ...    ...
# 35226         NaN    NaN
# 16953         6.0      T
# 27865         NaN    NaN
# 35227         NaN    NaN
# 34510         NaN      E
#
# [16682 rows x 19 columns]

# %%
cf_unique.head()
# Out:
#    Rank_dfvg                      Name  Critic_Score  Critic_Count  \
# 0          1                Wii Sports          76.0          51.0
# 1          2         Super Mario Bros.           NaN           NaN
# 5          3            Mario Kart Wii          82.0          73.0
# 6          4         Wii Sports Resort          80.0          73.0
# 7          5  Pokemon Red/Pokemon Blue           NaN           NaN
#
#    Unnamed: 0  Rank_cleanfusion Platform    Year         Genre Publisher  \
# 0           0                 1      Wii  2006.0        Sports  Nintendo
# 1           1                 2      NES  1985.0      Platform  Nintendo
# 5           2                 3      Wii  2008.0        Racing  Nintendo
# 6           3                 4      Wii  2009.0        Sports  Nintendo
# 7           4                 5       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales Developer  \
# 0     41.49     29.02      3.77         8.46         82.74  Nintendo
# 1     29.08      3.58      6.81         0.77         40.24  Nintendo
# 5     15.85     12.88      3.79         3.31         35.82  Nintendo
# 6     15.75     11.01      3.28         2.96         33.00  Nintendo
# 7     11.27      8.89     10.22         1.00         31.37       NaN
#
#   User_Score  User_Count Rating
# 0          8       322.0      E
# 1        8.3       138.0      E
# 5        8.3       709.0      E
# 6          8       192.0      E
# 7        NaN         NaN    NaN

# %%
cf_unique.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16682 entries, 0 to 34510
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Rank_dfvg         16682 non-null  int64
#  1   Name              16682 non-null  object
#  2   Critic_Score      8397 non-null   float64
#  3   Critic_Count      8397 non-null   float64
#  4   Unnamed: 0        16682 non-null  int64
#  5   Rank_cleanfusion  16682 non-null  int64
#  6   Platform          16682 non-null  object
#  7   Year              16493 non-null  float64
#  8   Genre             16682 non-null  object
#  9   Publisher         16627 non-null  object
#  10  NA_Sales          16682 non-null  float64
#  11  EU_Sales          16682 non-null  float64
#  12  JP_Sales          16682 non-null  float64
#  13  Other_Sales       16682 non-null  float64
#  14  Global_Sales      16682 non-null  float64
#  15  Developer         10777 non-null  object
#  16  User_Score        10650 non-null  object
#  17  User_Count        8679 non-null   float64
#  18  Rating            10642 non-null  object
# dtypes: float64(9), int64(3), object(7)
# memory usage: 2.5+ MB

# %%
# Nouvel ordre des colonnes

new_order = ["Name", "Platform", "Year", "Genre", "Publisher", "NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales", "Global_Sales", "Critic_Score", "Critic_Count", "User_Score", "User_Count", "Developer", "Rating"]

# Réorganiser les colonnes du DataFrame

cf = cf_unique[new_order]
cf.head()
# Out:
#                        Name Platform    Year         Genre Publisher  \
# 0                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 5            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 6         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 7  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.49     29.02      3.77         8.46         82.74          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 5     15.85     12.88      3.79         3.31         35.82          82.0
# 6     15.75     11.01      3.28         2.96         33.00          80.0
# 7     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 1           NaN        8.3       138.0  Nintendo      E
# 5          73.0        8.3       709.0  Nintendo      E
# 6          73.0          8       192.0  Nintendo      E
# 7           NaN        NaN         NaN       NaN    NaN

# %%
print(cf.info())
print("--------------------------------")
print(cf.isna().sum())
print("--------------------------------")
print(cf.duplicated().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16682 entries, 0 to 34510
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          16682 non-null  object
#  1   Platform      16682 non-null  object
#  2   Year          16493 non-null  float64
#  3   Genre         16682 non-null  object
#  4   Publisher     16627 non-null  object
#  5   NA_Sales      16682 non-null  float64
#  6   EU_Sales      16682 non-null  float64
#  7   JP_Sales      16682 non-null  float64
#  8   Other_Sales   16682 non-null  float64
#  9   Global_Sales  16682 non-null  float64
#  10  Critic_Score  8397 non-null   float64
#  11  Critic_Count  8397 non-null   float64
#  12  User_Score    10650 non-null  object
#  13  User_Count    8679 non-null   float64
#  14  Developer     10777 non-null  object
#  15  Rating        10642 non-null  object
# dtypes: float64(9), object(7)
# memory usage: 2.2+ MB
# None
# --------------------------------
# Name               0
# Platform           0
# Year             189
# Genre              0
# Publisher         55
# NA_Sales           0
# EU_Sales           0
# JP_Sales           0
# Other_Sales        0
# Global_Sales       0
# Critic_Score    8285
# Critic_Count    8285
# User_Score      6032
# User_Count      8003
# Developer       5905
# Rating          6040
# dtype: int64
# --------------------------------
# 0

# %%
# Vérification des différences de NaN et de doublons entre le nouveau jeu de données merge et dfvg

print(dfvg.info())
print("--------------------------------")
print(dfvg.isna().sum())
print("--------------------------------")
print(dfvg.duplicated().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16597 entries, 0 to 35184
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16597 non-null  int64
#  1   Name          16597 non-null  object
#  2   Platform      16597 non-null  object
#  3   Year          16408 non-null  float64
#  4   Genre         16597 non-null  object
#  5   Publisher     16542 non-null  object
#  6   NA_Sales      16597 non-null  float64
#  7   EU_Sales      16597 non-null  float64
#  8   JP_Sales      16597 non-null  float64
#  9   Other_Sales   16597 non-null  float64
#  10  Global_Sales  16597 non-null  float64
#  11  Critic_Score  8335 non-null   float64
#  12  Critic_Count  8335 non-null   float64
#  13  User_Score    9978 non-null   object
#  14  User_Count    7843 non-null   float64
#  15  Developer     10051 non-null  object
#  16  Rating        9912 non-null   object
# dtypes: float64(9), int64(1), object(7)
# memory usage: 2.8+ MB
# None
# --------------------------------
# Rank               0
# Name               0
# Platform           0
# Year             189
# Genre              0
# Publisher         55
# NA_Sales           0
# EU_Sales           0
# JP_Sales           0
# Other_Sales        0
# Global_Sales       0
# Critic_Score    8262
# Critic_Count    8262
# User_Score      6619
# User_Count      8754
# Developer       6546
# Rating          6685
# dtype: int64
# --------------------------------
# 0

# %% [markdown]
# # Fusion de cdmerge (Cleaned_Data) avec notre jeu de données merge (cf)

# %%
# Jeu de données Cleaned_Data trouvé sur Kaggle
# URL : https://www.kaggle.com/datasets/thedevastator/global-video-game-sales-ratings

cdmerge = pd.read_csv("cdmerge.csv")
cdmerge.head()
# Out:
#    Unnamed: 0  Rank                      Name Platform    Year         Genre  \
# 0           0   1.0                Wii Sports      Wii  2006.0        Sports
# 1           1   2.0         Super Mario Bros.      NES  1985.0      Platform
# 2           2   3.0            Mario Kart Wii      Wii  2008.0        Racing
# 3           3   4.0         Wii Sports Resort      Wii  2009.0        Sports
# 4           4   5.0  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing
#
#   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0  Nintendo     41.49     29.02      3.77         8.46         82.74
# 1  Nintendo     29.08      3.58      6.81         0.77         40.24
# 2  Nintendo     15.85     12.88      3.79         3.31         35.82
# 3  Nintendo     15.75     11.01      3.28         2.96         33.00
# 4  Nintendo     11.27      8.89     10.22         1.00         31.37
#
#    Critic_Score  Critic_Count  User_Score  User_Count Developer Rating
# 0           NaN           NaN         NaN         NaN       NaN    NaN
# 1           NaN           NaN         NaN         NaN       NaN    NaN
# 2           NaN           NaN         NaN         NaN       NaN    NaN
# 3           NaN           NaN         NaN         NaN       NaN    NaN
# 4           NaN           NaN         NaN         NaN       NaN    NaN

# %%
# Suppression des colonnes Unnamed: 0 et Rank

cdmerge.drop(columns=["Rank"], inplace=True)
cdmerge.head()
# Out:
#    Unnamed: 0                      Name Platform    Year         Genre  \
# 0           0                Wii Sports      Wii  2006.0        Sports
# 1           1         Super Mario Bros.      NES  1985.0      Platform
# 2           2            Mario Kart Wii      Wii  2008.0        Racing
# 3           3         Wii Sports Resort      Wii  2009.0        Sports
# 4           4  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing
#
#   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0  Nintendo     41.49     29.02      3.77         8.46         82.74
# 1  Nintendo     29.08      3.58      6.81         0.77         40.24
# 2  Nintendo     15.85     12.88      3.79         3.31         35.82
# 3  Nintendo     15.75     11.01      3.28         2.96         33.00
# 4  Nintendo     11.27      8.89     10.22         1.00         31.37
#
#    Critic_Score  Critic_Count  User_Score  User_Count Developer Rating
# 0           NaN           NaN         NaN         NaN       NaN    NaN
# 1           NaN           NaN         NaN         NaN       NaN    NaN
# 2           NaN           NaN         NaN         NaN       NaN    NaN
# 3           NaN           NaN         NaN         NaN       NaN    NaN
# 4           NaN           NaN         NaN         NaN       NaN    NaN

# %%
print(cdmerge.isna().sum())
print("----------------")
print(cdmerge.head())
# Out:
# Unnamed: 0          0
# Name                0
# Platform         2890
# Year              271
# Genre               0
# Publisher          58
# NA_Sales            0
# EU_Sales            0
# JP_Sales            0
# Other_Sales         0
# Global_Sales        0
# Critic_Score    12585
# Critic_Count    12585
# User_Score      12585
# User_Count      12585
# Developer       12589
# Rating          12653
# dtype: int64
# ----------------
#    Unnamed: 0                      Name Platform    Year         Genre  \
# 0           0                Wii Sports      Wii  2006.0        Sports
# 1           1         Super Mario Bros.      NES  1985.0      Platform
# 2           2            Mario Kart Wii      Wii  2008.0        Racing
# 3           3         Wii Sports Resort      Wii  2009.0        Sports
# 4           4  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing
#
#   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0  Nintendo     41.49     29.02      3.77         8.46         82.74
# 1  Nintendo     29.08      3.58      6.81         0.77         40.24
# 2  Nintendo     15.85     12.88      3.79         3.31         35.82
# 3  Nintendo     15.75     11.01      3.28         2.96         33.00
# 4  Nintendo     11.27      8.89     10.22         1.00         31.37
#
#    Critic_Score  Critic_Count  User_Score  User_Count Developer Rating
# 0           NaN           NaN         NaN         NaN       NaN    NaN
# 1           NaN           NaN         NaN         NaN       NaN    NaN
# 2           NaN           NaN         NaN         NaN       NaN    NaN
# 3           NaN           NaN         NaN         NaN       NaN    NaN
# 4           NaN           NaN         NaN         NaN       NaN    NaN

# %%
# Créer une nouvelle colonne d'indexation

cdmerge['Index'] = range(1, len(cdmerge) + 1)

# Réorganiser les colonnes pour que la nouvelle colonne soit à la première position

cols_cdmerge = ['Index'] + [col for col in cdmerge.columns if col != 'Index']
cdmerge = cdmerge[cols_cdmerge]

print(cdmerge)
# Out:
#        Index  Unnamed: 0                        Name Platform    Year  \
# 0          1           0                  Wii Sports      Wii  2006.0
# 1          2           1           Super Mario Bros.      NES  1985.0
# 2          3           2              Mario Kart Wii      Wii  2008.0
# 3          4           3           Wii Sports Resort      Wii  2009.0
# 4          5           4    Pokemon Red/Pokemon Blue       GB  1996.0
# ...      ...         ...                         ...      ...     ...
# 19488  19489       19488                        Zubo      NaN  2008.0
# 19489  19490       19489               Zumba Fitness      NaN  2010.0
# 19490  19491       19490  Zumba Fitness: World Party      NaN  2013.0
# 19491  19492       19491          Zumba Fitness Core      NaN  2012.0
# 19492  19493       19492          Zumba Fitness Rush      NaN  2012.0
#
#               Genre              Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0            Sports               Nintendo     41.49     29.02      3.77
# 1          Platform               Nintendo     29.08      3.58      6.81
# 2            Racing               Nintendo     15.85     12.88      3.79
# 3            Sports               Nintendo     15.75     11.01      3.28
# 4      Role-Playing               Nintendo     11.27      8.89     10.22
# ...             ...                    ...       ...       ...       ...
# 19488          Misc        Electronic Arts      0.08      0.02      0.00
# 19489        Sports              505 Games      1.74      0.45      0.00
# 19490          Misc  Majesco Entertainment      0.17      0.05      0.00
# 19491          Misc              505 Games      0.00      0.05      0.00
# 19492        Sports              505 Games      0.00      0.16      0.00
#
#        Other_Sales  Global_Sales  Critic_Score  Critic_Count  User_Score  \
# 0             8.46         82.74           NaN           NaN         NaN
# 1             0.77         40.24           NaN           NaN         NaN
# 2             3.31         35.82           NaN           NaN         NaN
# 3             2.96         33.00           NaN           NaN         NaN
# 4             1.00         31.37           NaN           NaN         NaN
# ...            ...           ...           ...           ...         ...
# 19488         0.01          0.11          75.0          19.0         7.6
# 19489         0.18          2.37          42.0          10.0         5.5
# 19490         0.02          0.24          73.0           5.0         6.2
# 19491         0.00          0.05          77.0           6.0         6.7
# 19492         0.02          0.18          73.0           7.0         6.2
#
#        User_Count                 Developer Rating
# 0             NaN                       NaN    NaN
# 1             NaN                       NaN    NaN
# 2             NaN                       NaN    NaN
# 3             NaN                       NaN    NaN
# 4             NaN                       NaN    NaN
# ...           ...                       ...    ...
# 19488        75.0           EA Bright Light   E10+
# 19489        16.0  Pipeworks Software, Inc.      E
# 19490        40.0                  Zoe Mode      E
# 19491         6.0                  Zoe Mode   E10+
# 19492         5.0    Majesco Games, Majesco   E10+
#
# [19493 rows x 18 columns]

# %%
# Fusionner cf et cdmerge sur la colonne Name avec des suffixes personnalisés

dfinal = pd.merge(cf, cdmerge, on='Name', how='outer', suffixes=('_cf', '_cdmerge'))

# Liste des colonnes dupliquées à combiner

columns_to_combine2 = ["Platform", "Year", "Genre", "Publisher", "NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales", "Global_Sales", "Critic_Score", "Critic_Count", "Developer", "User_Score", "User_Count", "Rating"]  # Ajout de toutes les colonnes à vérifier

for col in columns_to_combine2:
    # Combiner les colonnes dupliquées
    dfinal[col] = dfinal[f"{col}_cf"].combine_first(dfinal[f"{col}_cdmerge"])
    # Supprimer les colonnes dupliquées après combinaison
    dfinal.drop(columns=[f"{col}_cf", f"{col}_cdmerge"], inplace=True)

dfinal = dfinal.sort_values(by='Index')
dfinal.head()
# Out:
#                 Name  Index  Unnamed: 0 Platform    Year     Genre Publisher  \
# 0         Wii Sports      1           0      Wii  2006.0    Sports  Nintendo
# 2  Super Mario Bros.      2           1      NES  1985.0  Platform  Nintendo
# 4  Super Mario Bros.      2           1       GB  1999.0  Platform  Nintendo
# 6     Mario Kart Wii      3           2      Wii  2008.0    Racing  Nintendo
# 8  Wii Sports Resort      4           3      Wii  2009.0    Sports  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.49     29.02      3.77         8.46         82.74          76.0
# 2     29.08      3.58      6.81         0.77         40.24           NaN
# 4      3.40      1.30      0.15         0.22          5.07           NaN
# 6     15.85     12.88      3.79         3.31         35.82          82.0
# 8     15.75     11.01      3.28         2.96         33.00          80.0
#
#    Critic_Count Developer User_Score  User_Count Rating
# 0          51.0  Nintendo          8       322.0      E
# 2           NaN  Nintendo        8.3       138.0      E
# 4           NaN  Nintendo        8.3       138.0      E
# 6          73.0  Nintendo        8.3       709.0      E
# 8          73.0  Nintendo          8       192.0      E

# %%
dfinal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 43671 entries, 0 to 32673
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          43671 non-null  object
#  1   Index         43671 non-null  int64
#  2   Unnamed: 0    43671 non-null  int64
#  3   Platform      43599 non-null  object
#  4   Year          43420 non-null  float64
#  5   Genre         43671 non-null  object
#  6   Publisher     43616 non-null  object
#  7   NA_Sales      43671 non-null  float64
#  8   EU_Sales      43671 non-null  float64
#  9   JP_Sales      43671 non-null  float64
#  10  Other_Sales   43671 non-null  float64
#  11  Global_Sales  43671 non-null  float64
#  12  Critic_Score  30547 non-null  float64
#  13  Critic_Count  30547 non-null  float64
#  14  Developer     35267 non-null  object
#  15  User_Score    35062 non-null  object
#  16  User_Count    31558 non-null  float64
#  17  Rating        35044 non-null  object
# dtypes: float64(9), int64(2), object(7)
# memory usage: 6.3+ MB

# %%
print(dfinal.isna().sum())
print("--------------------------------")
print(dfinal.duplicated().sum())
# Out:
# Name                0
# Index               0
# Unnamed: 0          0
# Platform           72
# Year              251
# Genre               0
# Publisher          55
# NA_Sales            0
# EU_Sales            0
# JP_Sales            0
# Other_Sales         0
# Global_Sales        0
# Critic_Score    13124
# Critic_Count    13124
# Developer        8404
# User_Score       8609
# User_Count      12113
# Rating           8627
# dtype: int64
# --------------------------------
# 155

# %%
# Suppression des doublons

dfinal = dfinal.drop_duplicates()

# Vérification

print(dfinal.duplicated().sum())
# Out:
# 0

# %%
dfinal.head(20)
# Out:
#                            Name  Index  Unnamed: 0 Platform    Year  \
# 0                    Wii Sports      1           0      Wii  2006.0
# 2             Super Mario Bros.      2           1      NES  1985.0
# 4             Super Mario Bros.      2           1       GB  1999.0
# 6                Mario Kart Wii      3           2      Wii  2008.0
# 8             Wii Sports Resort      4           3      Wii  2009.0
# 10     Pokemon Red/Pokemon Blue      5           4       GB  1996.0
# 13                       Tetris      6           5      NES  1988.0
# 11                       Tetris      6           5       GB  1989.0
# 15        New Super Mario Bros.      7           6       DS  2006.0
# 17                     Wii Play      8           7      Wii  2006.0
# 19    New Super Mario Bros. Wii      9           8      Wii  2009.0
# 21                    Duck Hunt     10           9      NES  1984.0
# 22                   Nintendogs     11          10       DS  2005.0
# 23                Mario Kart DS     12          11       DS  2005.0
# 25  Pokemon Gold/Pokemon Silver     13          12       GB  1999.0
# 26                      Wii Fit     14          13      Wii  2007.0
# 28                 Wii Fit Plus     15          14      Wii  2009.0
# 30           Kinect Adventures!     16          15     X360  2010.0
# 42           Grand Theft Auto V     17          16     X360  2013.0
# 52           Grand Theft Auto V     17          16      PS4  2014.0
#
#            Genre               Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0         Sports                Nintendo     41.49     29.02      3.77
# 2       Platform                Nintendo     29.08      3.58      6.81
# 4       Platform                Nintendo      3.40      1.30      0.15
# 6         Racing                Nintendo     15.85     12.88      3.79
# 8         Sports                Nintendo     15.75     11.01      3.28
# 10  Role-Playing                Nintendo     11.27      8.89     10.22
# 13        Puzzle                Nintendo      2.97      0.69      1.81
# 11        Puzzle                Nintendo     23.20      2.26      4.22
# 15      Platform                Nintendo     11.38      9.23      6.50
# 17          Misc                Nintendo     14.03      9.20      2.93
# 19      Platform                Nintendo     14.59      7.06      4.70
# 21       Shooter                Nintendo     26.93      0.63      0.28
# 22    Simulation                Nintendo      9.07     11.00      1.93
# 23        Racing                Nintendo      9.81      7.57      4.13
# 25  Role-Playing                Nintendo      9.00      6.18      7.20
# 26        Sports                Nintendo      8.94      8.03      3.60
# 28        Sports                Nintendo      9.09      8.59      2.53
# 30          Misc  Microsoft Game Studios     14.97      4.94      0.24
# 42        Action    Take-Two Interactive      9.63      5.31      0.06
# 52        Action    Take-Two Interactive      3.80      5.81      0.36
#
#     Other_Sales  Global_Sales  Critic_Score  Critic_Count  \
# 0          8.46         82.74          76.0          51.0
# 2          0.77         40.24           NaN           NaN
# 4          0.22          5.07           NaN           NaN
# 6          3.31         35.82          82.0          73.0
# 8          2.96         33.00          80.0          73.0
# 10         1.00         31.37           NaN           NaN
# 13         0.11          5.58           NaN           NaN
# 11         0.58         30.26           NaN           NaN
# 15         2.90         30.01          89.0          65.0
# 17         2.85         29.02          58.0          41.0
# 19         2.26         28.62          87.0          80.0
# 21         0.47         28.31           NaN           NaN
# 22         2.75         24.76           NaN           NaN
# 23         1.92         23.42          91.0          64.0
# 25         0.71         23.10           NaN           NaN
# 26         2.15         22.72          80.0          63.0
# 28         1.79         22.00          80.0          33.0
# 30         1.67         21.82          61.0          45.0
# 42         1.38         16.38          97.0          50.0
# 52         2.02         11.98          97.0          50.0
#
#               Developer User_Score  User_Count Rating
# 0              Nintendo          8       322.0      E
# 2              Nintendo        8.3       138.0      E
# 4              Nintendo        8.3       138.0      E
# 6              Nintendo        8.3       709.0      E
# 8              Nintendo          8       192.0      E
# 10                  NaN        NaN         NaN    NaN
# 13                  NaN        NaN         NaN    NaN
# 11                  NaN        NaN         NaN    NaN
# 15             Nintendo        8.5       431.0      E
# 17             Nintendo        6.6       129.0      E
# 19             Nintendo        8.4       594.0      E
# 21                  NaN        NaN         NaN    NaN
# 22                  NaN        NaN         NaN    NaN
# 23             Nintendo        8.6       464.0      E
# 25                  NaN        NaN         NaN    NaN
# 26             Nintendo        7.7       146.0      E
# 28             Nintendo        7.4        52.0      E
# 30  Good Science Studio        6.3       106.0      E
# 42       Rockstar North        8.2      3994.0      M
# 52       Rockstar North        8.2      3994.0      M

# %%
doublons_dfinal = dfinal[dfinal.duplicated(keep=False)]

# Identifier les doublons sur toutes les colonnes du merge "df1"

doublons_dfinal = dfinal.duplicated(subset=["Name",	"Platform", "Year",	"Genre", "Publisher",	"NA_Sales",	"EU_Sales",	"JP_Sales",	"Other_Sales", "Global_Sales"])

print(doublons_dfinal)
# Out:
# 0        False
# 2        False
# 4        False
# 6        False
# 8        False
#          ...
# 29091     True
# 29088     True
# 38622     True
# 38625     True
# 32673     True
# Length: 43516, dtype: bool

# %%
# Vérification des doublons par colonnes

nombre_doublons_subset = dfinal.duplicated(subset=['Name', 'Platform', 'Year']).sum()
print(f"Nombre de doublons basés sur 'Name', 'Platform' et 'Year': {nombre_doublons_subset}")
print(nombre_doublons_subset)

# Suppression des doublons

dfinal = dfinal.drop_duplicates(subset=['Name', 'Platform', 'Year'])
# Out:
# Nombre de doublons basés sur 'Name', 'Platform' et 'Year': 26786
# 26786

# %%
dfinal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16730 entries, 0 to 43669
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          16730 non-null  object
#  1   Index         16730 non-null  int64
#  2   Unnamed: 0    16730 non-null  int64
#  3   Platform      16682 non-null  object
#  4   Year          16541 non-null  float64
#  5   Genre         16730 non-null  object
#  6   Publisher     16676 non-null  object
#  7   NA_Sales      16730 non-null  float64
#  8   EU_Sales      16730 non-null  float64
#  9   JP_Sales      16730 non-null  float64
#  10  Other_Sales   16730 non-null  float64
#  11  Global_Sales  16730 non-null  float64
#  12  Critic_Score  8448 non-null   float64
#  13  Critic_Count  8448 non-null   float64
#  14  Developer     10825 non-null  object
#  15  User_Score    10698 non-null  object
#  16  User_Count    8729 non-null   float64
#  17  Rating        10688 non-null  object
# dtypes: float64(9), int64(2), object(7)
# memory usage: 2.4+ MB

# %%
# Suppression des colonnes "Index", "Unnamed: 0" et "Developer"
dfinal.drop(columns=["Index"], inplace=True)
dfinal.drop(columns=["Unnamed: 0"], inplace=True)
dfinal.drop(columns=["Developer"], inplace=True)

# %%
dfinal.head()
# Out:
#                 Name Platform    Year     Genre Publisher  NA_Sales  EU_Sales  \
# 0         Wii Sports      Wii  2006.0    Sports  Nintendo     41.49     29.02
# 2  Super Mario Bros.      NES  1985.0  Platform  Nintendo     29.08      3.58
# 4  Super Mario Bros.       GB  1999.0  Platform  Nintendo      3.40      1.30
# 6     Mario Kart Wii      Wii  2008.0    Racing  Nintendo     15.85     12.88
# 8  Wii Sports Resort      Wii  2009.0    Sports  Nintendo     15.75     11.01
#
#    JP_Sales  Other_Sales  Global_Sales  Critic_Score  Critic_Count User_Score  \
# 0      3.77         8.46         82.74          76.0          51.0          8
# 2      6.81         0.77         40.24           NaN           NaN        8.3
# 4      0.15         0.22          5.07           NaN           NaN        8.3
# 6      3.79         3.31         35.82          82.0          73.0        8.3
# 8      3.28         2.96         33.00          80.0          73.0          8
#
#    User_Count Rating
# 0       322.0      E
# 2       138.0      E
# 4       138.0      E
# 6       709.0      E
# 8       192.0      E

# %%
# Test du téléchargement/de l'exportation du merge nommé dfinal

from google.colab import files
dfinal.to_csv('dfinal.csv')
files.download('dfinal.csv')

# %%
# sns.pairplot(dfinal)

# %% [markdown]
# # Test d'un fichier csv webscrapé sur Metacritic pour le fusionner

# %%
webscrap_puzzle = pd.read_csv("webscrap_puzzle.csv")
webscrap_puzzle.head()

# %%
print(webscrap_puzzle.info())
print("--------------------------------")
print(webscrap_puzzle.isna().sum())
print("--------------------------------")
print(webscrap_puzzle.duplicated().sum())
webscrap_puzzle = webscrap_puzzle.rename(columns={"c-finderProductCard_titleHeading": "Index"})
webscrap_puzzle = webscrap_puzzle.rename(columns={"c-finderProductCard_titleHeading 2": "Name"})
webscrap_puzzle = webscrap_puzzle.rename(columns={"u-text-uppercase": "Year"})
webscrap_puzzle = webscrap_puzzle.rename(columns={"c-finderProductCard_meta 2": "Rating"})
webscrap_puzzle = webscrap_puzzle.rename(columns={"c-siteReviewScore": "Critic_Score"})
webscrap_puzzle.head()

# Test non concluant, Metacritic bloque le webscraping
